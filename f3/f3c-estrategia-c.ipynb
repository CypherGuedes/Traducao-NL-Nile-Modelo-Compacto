# %% [markdown]
# # F3-C - Estratégia C: tradução por Representação Intermediária
#
# Este notebook executa a Estratégia C da Fase 3. A entrada em linguagem natural é traduzida primeiro para uma Representação Intermediária (IR) e, em seguida, a IR gerada pelo modelo aluno é convertida em uma expressão Nile.
#
# A F3-C avalia duas variantes sobre as mesmas 450 combinações experimentais:
#
# ```text
# sem_ac:       NL → IR → Nile
# primeira_ac:  NL → IR → Nile → primeira autocorreção, somente quando PSR=0
# ```
#
# Não existe zero-shot nesta estratégia. A grade contém:
#
# ```text
# k=1, k=3 e k=5
# seleção aleatória, lexical e semântica
# 5 folds × 10 testes
# ```
#
# Assim, são executados 450 fluxos-base e produzidos 900 registros finais:
#
# ```text
# 9 condições sem autocorreção × 50 exemplos = 450 registros
# 9 condições com primeira autocorreção × 50 exemplos = 450 registros
# ```
#
# A IR do exemplo de teste não é retirada da referência da F1. Ela é produzida pelo Qwen2.5-1.5B-Instruct no primeiro estágio. O segundo estágio recebe exclusivamente essa IR gerada, mesmo quando ela não passa pelo JSON Schema. Essa decisão preserva o comportamento real do fluxo e impede a substituição silenciosa da saída do modelo pela IR correta.
#
# A primeira autocorreção atua somente sobre a saída Nile rejeitada sintaticamente. A IR não é corrigida, regenerada nem substituída. O prompt de autocorreção pode receber a IR gerada como artefato auxiliar, mas nunca recebe a IR de referência, a Nile de referência, R1, R2 ou R3 do exemplo de teste.
#
# A cadeia principal é:
#
# ```text
# entrada em linguagem natural
#         ↓
# prompt NL → IR com demonstrações de treino
#         ↓
# IR gerada pelo modelo aluno
#         ↓
# validação determinística pelo JSON Schema
#         ↓
# prompt IR gerada → Nile com demonstrações de treino
#         ↓
# Nile inicial
#         ├── variante sem_ac: avaliar diretamente
#         │
#         └── variante primeira_ac:
#                 PSR=1 → preservar
#                 PSR=0 → corrigir com feedback do parser
#         ↓
# PSR, EM, ED, NED, SLA-S e SLA-F
#         ↓
# f3c_traducao_com_ir.zip
# ```
#
# As demonstrações são selecionadas somente no conjunto de treino de cada fold. Exemplos com Nile, IR ou assinatura formal equivalente à referência do teste já foram excluídos pelo F3-modelo. Em todas as tabelas e gráficos, os métodos aparecem na ordem Aleatória, Lexical e Semântica.
#
# | Bloco | Etapa | Função metodológica | Resultado principal |
# |---:|---|---|---|
# | 1 | Configuração | Fixar estratégia, variantes, caminhos e padrão visual | Ambiente da F3-C |
# | 2 | Auditoria da entrada | Localizar e verificar o F3-modelo | Base operacional íntegra |
# | 3 | Carga integrada | Ativar parser, IR, métricas, folds e seleções | Recursos comuns carregados |
# | 4 | Plano | Construir os 450 fluxos-base | `f3c_plano_execucao.csv` |
# | 5 | Modelo aluno | Carregar o Qwen2.5-1.5B-Instruct | Modelo pronto |
# | 6 | NL → IR | Montar, auditar, executar e validar 450 IRs | IRs geradas e auditadas |
# | 7 | IR → Nile | Montar, auditar e executar 450 traduções Nile | Variante `sem_ac` |
# | 8 | Primeira autocorreção | Corrigir somente as Nile com PSR=0 e consolidar 900 resultados | Variantes finais |
# | 9 | Análise | Produzir resumos, comparações e doze gráficos | Resultados interpretáveis |
# | 10 | Empacotamento | Aplicar barreiras finais, manifesto e ZIP | Pacote operacional da F3-C |

# %% [markdown]
# ## Bloco 1 - Configuração inicial
#
# ### Objetivo
#
# Este bloco prepara o ambiente da F3-C e centraliza todas as decisões que devem permanecer fixas durante a execução. A configuração separa os 450 fluxos-base dos 900 registros finais, porque cada fluxo gera uma saída sem autocorreção e uma saída correspondente à primeira autocorreção.
#
# ### Configurações principais
#
# O bloco define:
#
# - estratégia `F3-C`;
# - variantes `sem_ac` e `primeira_ac`;
# - conjunto CAMPI com 50 exemplos e cinco folds;
# - nove condições por variante e dezoito condições finais;
# - `k=1`, `k=3` e `k=5`;
# - métodos aleatório, lexical e semântico;
# - ordem oficial de exibição: Aleatória, Lexical e Semântica;
# - 450 fluxos-base e 900 registros finais;
# - máximo de 512 novos tokens para IR;
# - máximo de 256 novos tokens para Nile e autocorreção;
# - geração determinística, sem amostragem;
# - checkpoints independentes para IR, Nile e autocorreção;
# - retomada por fingerprint e modo de teste rápido.
#
# ### Artefatos finais
#
# Os caminhos dos planos, prompts, auditorias, gerações, resultados, comparações, gráficos, manifesto e ZIP são definidos antes da execução. Os checkpoints permanecem fora do pacote final.
#
# ### Reprodutibilidade
#
# Cada geração recebe uma semente derivada da semente global, do estágio, do fold, do ID, do método e de `k`. O fingerprint também incorpora o prompt, o modelo e o limite de saída do estágio.
#
# ### Resultado esperado
#
# O ambiente estará preparado, sem carregar dados ou o modelo. O Bloco 1 não apresenta tabelas.
#
# ### Apresentação do tempo
#
# Os tempos continuam armazenados internamente em segundos para preservar precisão, cálculos e reprodutibilidade. Nas tabelas do notebook, eles são apresentados em formato legível, como `01h 02min 16s` ou `10min 15s`.

# %%
# ----------------------------------------------------------
# 1.1 Importação das bibliotecas principais
# ----------------------------------------------------------

import gc
import gzip
import hashlib
import importlib.metadata
import json
import os
import platform
import re
import shutil
import sys
import time
import traceback
import zipfile
from datetime import datetime, timezone
from pathlib import Path

import numpy as np
import pandas as pd
from IPython.display import HTML, display


# ----------------------------------------------------------
# 1.2 Identificação da estratégia
# ----------------------------------------------------------

FASE = "F3-C"
ESTRATEGIA = "F3-C"
VARIANTES = ["sem_ac", "primeira_ac"]
NOME_ESTRATEGIA = "Tradução por Representação Intermediária"
DATASET = "CAMPI"

TOTAL_EXEMPLOS_ESPERADO = 50
TOTAL_FOLDS_ESPERADO = 5
TOTAL_CONDICOES_BASE = 9
TOTAL_CONDICOES_ESPERADO = 18
TOTAL_FLUXOS_BASE_ESPERADO = 450
TOTAL_REGISTROS_ESPERADO = 900
SEED_GLOBAL = 42

K_FEWSHOT = [1, 3, 5]
VALORES_K = [1, 3, 5]
METODOS_FEWSHOT = [
    "random_seed42",
    "lexical_tfidf",
    "semantic_embeddings",
]

ORDEM_METODOS_EXIBICAO = [
    "random_seed42",
    "lexical_tfidf",
    "semantic_embeddings",
]
ORDEM_METODOS_MAPA = {
    metodo: posicao
    for posicao, metodo in enumerate(ORDEM_METODOS_EXIBICAO)
}

ORDEM_VARIANTES_EXIBICAO = ["sem_ac", "primeira_ac"]
ORDEM_VARIANTES_MAPA = {
    variante: posicao
    for posicao, variante in enumerate(ORDEM_VARIANTES_EXIBICAO)
}

ROTULOS_VARIANTES = {
    "sem_ac": "Sem autocorreção",
    "primeira_ac": "Primeira autocorreção",
}

ROTULOS_METODOS = {
    "random_seed42": "Aleatória",
    "lexical_tfidf": "Lexical",
    "semantic_embeddings": "Semântica",
}

CORES_METODOS = {
    "random_seed42": "#f2c94c",
    "lexical_tfidf": "#2ca02c",
    "semantic_embeddings": "#1f77b4",
}

METRICAS = ["psr", "em", "ed", "ned", "sla_s", "sla_f"]
ROTULOS_METRICAS = {
    "psr": "PSR",
    "em": "EM",
    "ed": "ED",
    "ned": "NED",
    "sla_s": "SLA-S",
    "sla_f": "SLA-F",
}

AUTOCORRIGIR_APENAS_SINTATICAMENTE_INVALIDAS = True


# ----------------------------------------------------------
# 1.3 Modelo aluno e geração
# ----------------------------------------------------------

MODELO_ALUNO = "Qwen2.5-1.5B-Instruct"
MODELO_HF_ID = "Qwen/Qwen2.5-1.5B-Instruct"
MODELO_LOCAL_HINTS = ["qwen2.5", "1.5b", "instruct"]

USAR_CUDA = True
PERMITIR_DOWNLOAD_HUGGINGFACE = True
MAX_NEW_TOKENS_IR = 512
MAX_NEW_TOKENS_NILE = 256
DO_SAMPLE = False
LIMITE_CONTEXTO_FALLBACK = 32768


# ----------------------------------------------------------
# 1.4 Controle de execução
# ----------------------------------------------------------

REINICIAR_EXECUCAO = False
MODO_TESTE_RAPIDO = False
TOTAL_REGISTROS_TESTE_RAPIDO = 5
INTERVALO_SNAPSHOT = 25


# ----------------------------------------------------------
# 1.5 Diretórios principais
# ----------------------------------------------------------

KAGGLE_INPUT = Path("/kaggle/input")
RAIZ_TRABALHO = (
    Path("/kaggle/working")
    if Path("/kaggle/working").exists()
    else Path("/mnt/data/f3c_working")
)

F3C_DIR = RAIZ_TRABALHO / "f3c_traducao_com_ir"
ENTRADAS_DIR = F3C_DIR / "entradas"
INTERMEDIARIOS_DIR = F3C_DIR / "intermediarios"
GRAFICOS_DIR = F3C_DIR / "graficos"
PACOTE_DIR = F3C_DIR / "pacote"
F3_MODELO_DIR = ENTRADAS_DIR / "f3_modelo_operacional"

if REINICIAR_EXECUCAO and F3C_DIR.exists():
    shutil.rmtree(F3C_DIR)

for diretorio in [
    F3C_DIR,
    ENTRADAS_DIR,
    INTERMEDIARIOS_DIR,
    GRAFICOS_DIR,
    PACOTE_DIR,
]:
    diretorio.mkdir(parents=True, exist_ok=True)


# ----------------------------------------------------------
# 1.6 Caminhos dos artefatos da F3-C
# ----------------------------------------------------------

CONFIG_PATH = PACOTE_DIR / "f3c_config.json"
PLANO_PATH = PACOTE_DIR / "f3c_plano_execucao.csv"

PROMPTS_IR_PATH = PACOTE_DIR / "f3c_prompts_ir.jsonl.gz"
TOKEN_AUDIT_IR_PATH = PACOTE_DIR / "f3c_token_audit_ir.csv"
CHECKPOINT_IR_PATH = INTERMEDIARIOS_DIR / "f3c_checkpoint_ir.jsonl"
GENERATIONS_IR_PATH = PACOTE_DIR / "f3c_generations_ir.jsonl.gz"
IR_VALIDATION_PATH = PACOTE_DIR / "f3c_ir_validation.csv"

PROMPTS_NILE_PATH = PACOTE_DIR / "f3c_prompts_nile.jsonl.gz"
TOKEN_AUDIT_NILE_PATH = PACOTE_DIR / "f3c_token_audit_nile.csv"
CHECKPOINT_NILE_PATH = INTERMEDIARIOS_DIR / "f3c_checkpoint_nile.jsonl"
GENERATIONS_NILE_PATH = PACOTE_DIR / "f3c_generations_nile.jsonl.gz"
INITIAL_EVALUATION_PATH = PACOTE_DIR / "f3c_initial_evaluation.csv"

PROMPTS_AC_PATH = PACOTE_DIR / "f3c_prompts_autocorrection.jsonl.gz"
TOKEN_AUDIT_AC_PATH = PACOTE_DIR / "f3c_token_audit_autocorrection.csv"
CHECKPOINT_AC_PATH = INTERMEDIARIOS_DIR / "f3c_checkpoint_autocorrection.jsonl"
GENERATIONS_AC_PATH = PACOTE_DIR / "f3c_generations_autocorrection.jsonl.gz"
PROMPT_AUDIT_PATH = PACOTE_DIR / "f3c_prompt_audit.csv"

RESULTS_JSONL_PATH = PACOTE_DIR / "f3c_results.jsonl"
RESULTS_CSV_PATH = PACOTE_DIR / "f3c_results.csv"
SUMMARY_PATH = PACOTE_DIR / "f3c_summary.csv"
SUMMARY_FOLD_PATH = PACOTE_DIR / "f3c_summary_by_fold.csv"
IR_SUMMARY_PATH = PACOTE_DIR / "f3c_ir_summary.csv"
INVALID_SEM_AC_PATH = PACOTE_DIR / "f3c_invalid_outputs_sem_ac.csv"
INVALID_PRIMEIRA_AC_PATH = PACOTE_DIR / "f3c_invalid_outputs_primeira_ac.csv"
FINAL_AC_ELIGIBLE_PATH = PACOTE_DIR / "f3c_final_autocorrection_eligible.csv"
ANALYSIS_EXAMPLE_PATH = PACOTE_DIR / "f3c_analysis_by_example.csv"
EXECUTION_AUDIT_PATH = PACOTE_DIR / "f3c_execution_audit.csv"
COMPARISON_PATH = PACOTE_DIR / "f3c_comparison_sem_ac.csv"
GAINS_PATH = PACOTE_DIR / "f3c_gains.csv"
MANIFEST_PATH = PACOTE_DIR / "manifest.json"
ZIP_FINAL_PATH = RAIZ_TRABALHO / "f3c_traducao_com_ir.zip"


# ----------------------------------------------------------
# 1.7 Funções de leitura, escrita e hashing
# ----------------------------------------------------------

def canonical_json(data):
    return json.dumps(
        data,
        ensure_ascii=False,
        sort_keys=True,
        separators=(",", ":"),
    )


def sha256_text(text):
    return hashlib.sha256(str(text).encode("utf-8")).hexdigest()


def sha256_file(path, chunk_size=1024 * 1024):
    path = Path(path)
    digest = hashlib.sha256()
    with path.open("rb") as handle:
        for chunk in iter(lambda: handle.read(chunk_size), b""):
            digest.update(chunk)
    return digest.hexdigest()


def read_json(path):
    with Path(path).open("r", encoding="utf-8") as handle:
        return json.load(handle)


def json_safe(data):
    if isinstance(data, dict):
        return {str(key): json_safe(value) for key, value in data.items()}
    if isinstance(data, (list, tuple)):
        return [json_safe(value) for value in data]
    if isinstance(data, np.generic):
        return json_safe(data.item())
    if isinstance(data, float) and not np.isfinite(data):
        return None
    return data


def write_json(data, path):
    path = Path(path)
    path.parent.mkdir(parents=True, exist_ok=True)
    with path.open("w", encoding="utf-8") as handle:
        json.dump(json_safe(data), handle, ensure_ascii=False, indent=2, allow_nan=False)
        handle.write("\n")


def read_jsonl(path):
    records = []
    path = Path(path)
    if not path.exists():
        return records
    opener = gzip.open if path.suffix == ".gz" else open
    with opener(path, "rt", encoding="utf-8") as handle:
        for line_number, line in enumerate(handle, start=1):
            if not line.strip():
                continue
            try:
                record = json.loads(line)
            except json.JSONDecodeError as exc:
                raise ValueError(
                    f"JSONL inválido em {path}, linha {line_number}: {exc}"
                ) from exc
            if not isinstance(record, dict):
                raise TypeError(
                    f"Registro não é objeto em {path}, linha {line_number}."
                )
            records.append(record)
    return records


def write_jsonl(records, path):
    path = Path(path)
    path.parent.mkdir(parents=True, exist_ok=True)
    with path.open("w", encoding="utf-8") as handle:
        for record in records:
            handle.write(json.dumps(record, ensure_ascii=False, separators=(",", ":")))
            handle.write("\n")


def append_jsonl(record, path):
    path = Path(path)
    path.parent.mkdir(parents=True, exist_ok=True)
    with path.open("a", encoding="utf-8") as handle:
        handle.write(json.dumps(record, ensure_ascii=False, separators=(",", ":")))
        handle.write("\n")
        handle.flush()
        os.fsync(handle.fileno())


def write_jsonl_gz(records, path):
    path = Path(path)
    path.parent.mkdir(parents=True, exist_ok=True)
    with gzip.open(path, "wt", encoding="utf-8") as handle:
        for record in records:
            handle.write(json.dumps(record, ensure_ascii=False, separators=(",", ":")))
            handle.write("\n")


def package_version(name):
    try:
        return importlib.metadata.version(name)
    except Exception:
        return None


def clean_runtime_caches(root):
    root = Path(root)
    for cache in root.rglob("__pycache__"):
        if cache.is_dir():
            shutil.rmtree(cache, ignore_errors=True)
    for suffix in ("*.pyc", "*.pyo"):
        for item in root.rglob(suffix):
            item.unlink(missing_ok=True)


# ----------------------------------------------------------
# 1.8 Padrão visual das tabelas
# ----------------------------------------------------------

CONTADOR_TABELAS = 0

ROTULOS_COLUNAS = {
    "execution_id": "ID da execução",
    "fold": "fold",
    "id": "ID",
    "test_id": "ID de teste",
    "strategy": "estratégia",
    "variant": "variante",
    "stage": "etapa",
    "pipeline_id": "ID do fluxo",
    "ir_valid": "validade da IR",
    "ir_extracted": "IR extraída",
    "eligible_for_autocorrection": "elegível à autocorreção",
    "autocorrection_applied": "autocorreção aplicada",
    "regime": "regime",
    "selection_method": "método de seleção",
    "selection_label": "rótulo do método",
    "k": "k",
    "records": "registros",
    "total": "total",
    "status": "status",
    "item": "item",
    "value": "valor",
    "file": "arquivo",
    "path": "caminho",
    "size_bytes": "tamanho em bytes",
    "sha256": "SHA-256",
    "prompt_tokens": "tokens do prompt",
    "generated_tokens": "tokens gerados",
    "elapsed_seconds": "tempo decorrido",
    "elapsed_primary_seconds": "tempo médio NL → IR",
    "elapsed_secondary_seconds": "tempo médio IR → Nile",
    "elapsed_autocorrection_seconds": "tempo médio de autocorreção",
    "syntax_valid": "validade sintática",
    "psr": "PSR",
    "em": "EM",
    "ed": "ED",
    "ned": "NED",
    "sla_s": "SLA-S",
    "sla_f": "SLA-F",
}


def _display_value(value):
    if isinstance(value, (bool, np.bool_)):
        return "sim" if value else "não"
    if value is None:
        return "-"
    try:
        if not isinstance(value, str) and pd.isna(value):
            return "-"
    except Exception:
        pass
    return value


def formatar_duracao(segundos):
    if segundos is None:
        return "-"

    try:
        if pd.isna(segundos):
            return "-"
    except Exception:
        pass

    total_segundos = max(
        0,
        int(round(float(segundos))),
    )
    horas, restante = divmod(total_segundos, 3600)
    minutos, segundos_restantes = divmod(restante, 60)

    if horas > 0:
        return (
            f"{horas:02d}h "
            f"{minutos:02d}min "
            f"{segundos_restantes:02d}s"
        )

    if minutos > 0:
        return (
            f"{minutos:02d}min "
            f"{segundos_restantes:02d}s"
        )

    return f"{segundos_restantes:02d}s"


def exibir_tabela(df, titulo=None, altura_px=None, mostrar_indice=False):
    global CONTADOR_TABELAS
    if df is None:
        print("Tabela não disponível.")
        return
    if not isinstance(df, pd.DataFrame):
        df = pd.DataFrame(df)
    if df.empty:
        print("Tabela vazia.")
        return

    CONTADOR_TABELAS += 1
    tabela = df.copy()
    for coluna in tabela.columns:
        if str(coluna).endswith("_seconds"):
            tabela[coluna] = tabela[coluna].apply(formatar_duracao)
        else:
            tabela[coluna] = tabela[coluna].apply(_display_value)
    tabela = tabela.rename(
        columns={
            coluna: ROTULOS_COLUNAS.get(coluna, str(coluna).replace("_", " "))
            for coluna in tabela.columns
        }
    )

    titulo_final = f"Tabela {CONTADOR_TABELAS}"
    if titulo:
        titulo_final += f". {titulo}"

    html_tabela = tabela.to_html(
        escape=True,
        index=mostrar_indice,
        border=0,
        justify="left",
        classes="tabela_saida",
    )
    altura_css = (
        "overflow-y: visible;"
        if altura_px is None
        else f"max-height: {altura_px}px; overflow-y: auto;"
    )

    display(HTML(f"""
    <div style="font-weight:600;font-size:15px;margin:8px 0 6px;color:#f1f1f1;">
        {titulo_final}
    </div>
    <div class="container_tabela_saida" style="display:inline-block;max-width:100%;overflow-x:auto;{altura_css}border:none;margin:8px 0 12px;">
        <style>
            .container_tabela_saida table.tabela_saida {{
                border-collapse:collapse !important;
                table-layout:auto !important;
                width:auto !important;
                font-family:Arial,sans-serif !important;
                font-size:13px !important;
                background:#111 !important;
                color:#f1f1f1 !important;
                border:1px solid #555 !important;
            }}
            .container_tabela_saida table.tabela_saida thead th {{
                position:sticky !important;
                top:0 !important;
                z-index:2 !important;
                background:#2b2b2b !important;
                color:#fff !important;
                padding:7px !important;
                text-align:left !important;
                white-space:nowrap !important;
                border:1px solid #777 !important;
                border-bottom:2px solid #888 !important;
            }}
            .container_tabela_saida table.tabela_saida tbody td {{
                padding:7px !important;
                vertical-align:top !important;
                text-align:left !important;
                white-space:nowrap !important;
                border:1px solid #555 !important;
            }}
            .container_tabela_saida table.tabela_saida tbody tr:nth-child(even) td {{background:#1b1b1b !important;}}
            .container_tabela_saida table.tabela_saida tbody tr:nth-child(odd) td {{background:#111 !important;}}
        </style>
        {html_tabela}
    </div>
    """))


# ----------------------------------------------------------
# 1.9 Registro da configuração inicial
# ----------------------------------------------------------

configuracao_inicial = {
    "phase": FASE,
    "strategy": ESTRATEGIA,
    "variants": VARIANTES,
    "dataset": DATASET,
    "expected_examples": TOTAL_EXEMPLOS_ESPERADO,
    "expected_folds": TOTAL_FOLDS_ESPERADO,
    "expected_base_conditions": TOTAL_CONDICOES_BASE,
    "expected_conditions": TOTAL_CONDICOES_ESPERADO,
    "expected_base_pipelines": TOTAL_FLUXOS_BASE_ESPERADO,
    "expected_records": TOTAL_REGISTROS_ESPERADO,
    "seed": SEED_GLOBAL,
    "k_values": VALORES_K,
    "selection_methods": METODOS_FEWSHOT,
    "student_model": {
        "name": MODELO_ALUNO,
        "model_id": MODELO_HF_ID,
        "do_sample": DO_SAMPLE,
        "max_new_tokens_ir": MAX_NEW_TOKENS_IR,
        "max_new_tokens_nile": MAX_NEW_TOKENS_NILE,
    },
    "resume": {
        "restart": REINICIAR_EXECUCAO,
        "checkpoints": {
            "ir": str(CHECKPOINT_IR_PATH),
            "nile": str(CHECKPOINT_NILE_PATH),
            "autocorrection": str(CHECKPOINT_AC_PATH),
        },
    },
    "quick_test": {
        "enabled": MODO_TESTE_RAPIDO,
        "base_pipelines": TOTAL_REGISTROS_TESTE_RAPIDO,
    },
}
write_json(configuracao_inicial, CONFIG_PATH)

print("Bloco 1 concluído.")
print(f"Estratégia: {ESTRATEGIA} - {NOME_ESTRATEGIA}")
print(f"Fluxos-base esperados: {TOTAL_FLUXOS_BASE_ESPERADO}")
print(f"Registros finais esperados: {TOTAL_REGISTROS_ESPERADO}")
print(f"Execução oficial: {'não' if MODO_TESTE_RAPIDO else 'sim'}")
print(f"Retomada de checkpoints: {'não' if REINICIAR_EXECUCAO else 'sim'}")
print(f"Diretório de trabalho: {F3C_DIR}")
print("Status: OK")
# Out:
# Bloco 1 concluído.
# Estratégia: F3-C - Tradução por Representação Intermediária
# Fluxos-base esperados: 450
# Registros finais esperados: 900
# Execução oficial: sim
# Retomada de checkpoints: sim
# Diretório de trabalho: /kaggle/working/f3c_traducao_com_ir
# Status: OK

# %% [markdown]
# ## Bloco 2 - Localização e auditoria do F3-modelo
#
# ### Objetivo
#
# Este bloco localiza o pacote operacional congelado pelo F3-modelo e confirma que a F3-C está utilizando a mesma base, os mesmos folds, as mesmas seleções few-shot, os mesmos templates e os mesmos módulos formais das estratégias anteriores.
#
# ### Formatos aceitos
#
# A entrada pode estar:
#
# - montada como diretório pelo Kaggle;
# - disponível como `f3_modelo_operacional.zip`.
#
# Quando um ZIP é localizado, seu conteúdo é extraído para a área de trabalho. A raiz operacional é identificada pelo manifesto e pelos arquivos obrigatórios, sem depender de uma pasta externa específica.
#
# ### Auditoria de integridade
#
# Para cada arquivo inventariado no manifesto, o bloco confere:
#
# - existência;
# - tamanho em bytes;
# - SHA-256.
#
# ### Compromissos metodológicos
#
# Também são confirmados:
#
# - conjunto CAMPI;
# - 74 condições globais e 3.700 registros planejados;
# - 450 seleções cumulativas;
# - ausência de vazamento por ID, Nile, IR ou equivalência formal;
# - cobertura dos 50 exemplos na auditoria de prompts;
# - presença dos templates NL → IR, IR → Nile e autocorreção;
# - presença do JSON Schema e do núcleo determinístico da IR.
#
# ### Resultado esperado
#
# A F3-C só avança quando todos os arquivos e compromissos são confirmados.

# %%
# ----------------------------------------------------------
# 2.1 Funções de localização do pacote operacional
# ----------------------------------------------------------

def candidate_roots():
    roots = []
    for root in [KAGGLE_INPUT, Path("/mnt/data"), Path.cwd()]:
        if root.exists() and root not in roots:
            roots.append(root)
    return roots


def inspect_zip_candidate(zip_path, phase, required_files):
    try:
        with zipfile.ZipFile(zip_path, "r") as package:
            members = [name for name in package.namelist() if not name.endswith("/")]
            manifests = [name for name in members if name.endswith("manifest.json")]
            for manifest_member in manifests:
                try:
                    manifest = json.loads(package.read(manifest_member).decode("utf-8"))
                except Exception:
                    continue
                if manifest.get("phase") != phase:
                    continue
                prefix = manifest_member.removesuffix("manifest.json")
                if all(prefix + name in members for name in required_files):
                    return {
                        "manifest": manifest,
                        "prefix": prefix,
                    }
    except (zipfile.BadZipFile, OSError):
        return None
    return None


def locate_operational_source(phase, required_files, zip_tokens):
    candidates = []
    for root in candidate_roots():
        for manifest_path in root.rglob("manifest.json"):
            parent = manifest_path.parent
            if parent == F3C_DIR or F3C_DIR in parent.parents:
                continue
            if not all((parent / name).is_file() for name in required_files):
                continue
            try:
                manifest = read_json(manifest_path)
            except Exception:
                continue
            if manifest.get("phase") == phase:
                candidates.append({
                    "type": "diretorio",
                    "path": parent,
                    "created_at": manifest.get("created_at_utc", ""),
                })

        for zip_path in root.rglob("*.zip"):
            normalized = "_".join(
                part for part in re.sub(r"[^a-z0-9]+", "_", zip_path.name.lower()).split("_")
                if part
            )
            if not any(token in normalized for token in zip_tokens):
                continue
            inspection = inspect_zip_candidate(zip_path, phase, required_files)
            if inspection is not None:
                candidates.append({
                    "type": "zip",
                    "path": zip_path,
                    "created_at": inspection["manifest"].get("created_at_utc", ""),
                    "prefix": inspection["prefix"],
                })

    if not candidates:
        raise FileNotFoundError(
            f"Nenhuma fonte operacional válida da fase {phase} foi localizada."
        )

    candidates.sort(
        key=lambda item: (
            item.get("created_at", ""),
            1 if item["type"] == "diretorio" else 0,
            str(item["path"]),
        ),
        reverse=True,
    )
    return candidates[0]


def materialize_source(source, destination, phase, required_files):
    if source["type"] == "diretorio":
        return Path(source["path"])

    if destination.exists():
        shutil.rmtree(destination)
    destination.mkdir(parents=True, exist_ok=True)
    with zipfile.ZipFile(source["path"], "r") as package:
        package.extractall(destination)

    candidates = [destination]
    candidates.extend(path for path in destination.rglob("*") if path.is_dir())
    valid = []
    for candidate in candidates:
        manifest_path = candidate / "manifest.json"
        if not manifest_path.is_file():
            continue
        if not all((candidate / name).is_file() for name in required_files):
            continue
        try:
            manifest = read_json(manifest_path)
        except Exception:
            continue
        if manifest.get("phase") == phase:
            valid.append((manifest.get("created_at_utc", ""), candidate))

    if not valid:
        raise FileNotFoundError(
            f"O ZIP extraído não contém uma raiz operacional válida da fase {phase}."
        )
    valid.sort(key=lambda item: (item[0], str(item[1])), reverse=True)
    return valid[0][1]


# ----------------------------------------------------------
# 2.2 Localização do F3-modelo
# ----------------------------------------------------------

F3_MODELO_REQUIRED = [
    "f3_common.py",
    "f3_config.json",
    "f3_equivalencia_formal.csv",
    "f3_exemplos_fewshot.jsonl",
    "f3_grid.csv",
    "f3_prompt_audit.csv",
    "f3_result_schema.json",
    "f3_selecao_fewshot.csv",
    "inputs/campi_canonical.csv",
    "inputs/folds.csv",
    "inputs/ir_core.py",
    "inputs/ir_references.jsonl",
    "inputs/ir_schema.json",
    "inputs/nile_core.py",
    "inputs/nile_metrics.py",
    "inputs/nile_subset.lark",
    "inputs/rationales_references.jsonl",
    "prompts/f3_autocorrecao_nile.txt",
    "prompts/f3c_gerar_ir_teste.txt",
    "prompts/f3c_gerar_nile_a_partir_ir.txt",
]

FONTE_F3_MODELO = locate_operational_source(
    "F3-modelo",
    F3_MODELO_REQUIRED,
    ["f3_modelo_operacional"],
)
F3_MODELO_DIR = materialize_source(
    FONTE_F3_MODELO,
    F3_MODELO_DIR,
    "F3-modelo",
    F3_MODELO_REQUIRED,
)


# ----------------------------------------------------------
# 2.3 Auditoria do manifesto e dos hashes
# ----------------------------------------------------------

manifest_path = F3_MODELO_DIR / "manifest.json"
if not manifest_path.is_file():
    raise FileNotFoundError(manifest_path)

f3_modelo_manifest = read_json(manifest_path)
f3_modelo_manifest_sha256 = sha256_file(manifest_path)

if f3_modelo_manifest.get("phase") != "F3-modelo":
    raise ValueError("O manifesto localizado não pertence à F3-modelo.")
if f3_modelo_manifest.get("dataset") != DATASET:
    raise ValueError("O conjunto registrado no F3-modelo não é CAMPI.")

file_rows = []
for item in f3_modelo_manifest.get("files", []):
    relative = item["file"]
    path = F3_MODELO_DIR / relative
    exists = path.is_file()
    actual_size = int(path.stat().st_size) if exists else None
    actual_hash = sha256_file(path) if exists else None
    compatible = (
        exists
        and actual_size == int(item["size_bytes"])
        and actual_hash == item["sha256"]
    )
    file_rows.append({
        "file": relative,
        "size_bytes": actual_size,
        "sha256": actual_hash,
        "status": "compatível" if compatible else "incompatível",
    })

file_audit_df = pd.DataFrame(file_rows)
if file_audit_df.empty or not file_audit_df["status"].eq("compatível").all():
    problems = file_audit_df.loc[
        file_audit_df["status"] != "compatível",
        "file",
    ]
    raise ValueError(
        "A auditoria do F3-modelo encontrou divergências: "
        + ", ".join(problems.astype(str).tolist())
    )

selection_manifest = f3_modelo_manifest.get("selection", {})
prompt_manifest = f3_modelo_manifest.get("prompt_audit", {})
grid_manifest = f3_modelo_manifest.get("experimental_grid", {})
method_manifest = f3_modelo_manifest.get("method", {})

checks = {
    "74 condições globais": grid_manifest.get("configurations") == 74,
    "3.700 registros globais": grid_manifest.get("main_records") == 3700,
    "zero vazamento por ID": selection_manifest.get("id_leakage_records") == 0,
    "zero Nile idêntica": selection_manifest.get("same_nile_records") == 0,
    "zero IR idêntica": selection_manifest.get("same_ir_records") == 0,
    "zero equivalência formal": selection_manifest.get("formal_equivalence_records") == 0,
    "zero vazamento nos prompts": prompt_manifest.get("leakage_records") == 0,
    "auditoria cobre todos os testes": method_manifest.get("prompt_audit_covers_all_test_examples") is True,
}
failed = [name for name, passed in checks.items() if not passed]
if failed:
    raise ValueError("Compromissos metodológicos não confirmados: " + ", ".join(failed))

source_summary_df = pd.DataFrame([
    {"item": "fonte localizada", "value": str(FONTE_F3_MODELO["path"])},
    {"item": "tipo da fonte", "value": FONTE_F3_MODELO["type"]},
    {"item": "diretório operacional", "value": str(F3_MODELO_DIR)},
    {"item": "arquivos inventariados", "value": len(file_audit_df)},
    {"item": "SHA-256 do manifesto", "value": f3_modelo_manifest_sha256},
    {"item": "vazamentos registrados", "value": 0},
])

exibir_tabela(source_summary_df, "Auditoria do pacote F3-modelo")
exibir_tabela(
    file_audit_df[["file", "size_bytes", "status"]],
    "Arquivos inventariados no F3-modelo",
    altura_px=420,
)

print("Bloco 2 concluído.")
print(f"Entrada operacional: {F3_MODELO_DIR}")
print("Integridade dos arquivos: confirmada")
print("Proteções contra vazamento: confirmadas")
print("Status: OK")
# Out:
#     <div style="font-weight:600;font-size:15px;margin:8px 0 6px;color:#f1f1f1;">
#         Tabela 1. Auditoria do pacote F3-modelo
#     </div>
#     <div class="container_tabela_saida" style="display:inline-block;max-width:100%;overflow-x:auto;overflow-y: visible;border:none;margin:8px 0 12px;">
#         <style>
#             .container_tabela_saida table.tabela_saida {
#                 border-collapse:collapse !important;
#                 table-layout:auto !important;
#                 width:auto !important;
#                 font-family:Arial,sans-serif !important;
#                 font-size:13px !important;
#                 background:#111 !important;
#                 color:#f1f1f1 !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida thead th {
#                 position:sticky !important;
#                 top:0 !important;
#                 z-index:2 !important;
#                 background:#2b2b2b !important;
#                 color:#fff !important;
#                 padding:7px !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #777 !important;
#                 border-bottom:2px solid #888 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody td {
#                 padding:7px !important;
#                 vertical-align:top !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(even) td {background:#1b1b1b !important;}
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(odd) td {background:#111 !important;}
#         </style>
#         <table class="dataframe tabela_saida">
#   <thead>
#     <tr style="text-align: left;">
#       <th>item</th>
#       <th>valor</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>fonte localizada</td>
#       <td>/kaggle/input/datasets/thiagoarajoguedes/f3-modelo-operacional</td>
#     </tr>
#     <tr>
#       <td>tipo da fonte</td>
#       <td>diretorio</td>
#     </tr>
#     <tr>
#       <td>diretório operacional</td>
#       <td>/kaggle/input/datasets/thiagoarajoguedes/f3-modelo-operacional</td>
#     </tr>
#     <tr>
#       <td>arquivos inventariados</td>
#       <td>29</td>
#     </tr>
#     <tr>
#       <td>SHA-256 do manifesto</td>
#       <td>bc798e1d152332a85747ffdc97390015e6b4e294e300e6a9a3b4664c1787f835</td>
#     </tr>
#     <tr>
#       <td>vazamentos registrados</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
#     <div style="font-weight:600;font-size:15px;margin:8px 0 6px;color:#f1f1f1;">
#         Tabela 2. Arquivos inventariados no F3-modelo
#     </div>
#     <div class="container_tabela_saida" style="display:inline-block;max-width:100%;overflow-x:auto;max-height: 420px; overflow-y: auto;border:none;margin:8px 0 12px;">
#         <style>
#             .container_tabela_saida table.tabela_saida {
#                 border-collapse:collapse !important;
#                 table-layout:auto !important;
#                 width:auto !important;
#                 font-family:Arial,sans-serif !important;
#                 font-size:13px !important;
#                 background:#111 !important;
#                 color:#f1f1f1 !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida thead th {
#                 position:sticky !important;
#                 top:0 !important;
#                 z-index:2 !important;
#                 background:#2b2b2b !important;
#                 color:#fff !important;
#                 padding:7px !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #777 !important;
#                 border-bottom:2px solid #888 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody td {
#                 padding:7px !important;
#                 vertical-align:top !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(even) td {background:#1b1b1b !important;}
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(odd) td {background:#111 !important;}
#         </style>
#         <table class="dataframe tabela_saida">
#   <thead>
#     <tr style="text-align: left;">
#       <th>arquivo</th>
#       <th>tamanho em bytes</th>
#       <th>status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>f3_common.py</td>
#       <td>19714</td>
#       <td>compatível</td>
#     </tr>
#     <tr>
#       <td>f3_config.json</td>
#       <td>4319</td>
#       <td>compatível</td>
#     </tr>
#     <tr>
#       <td>f3_equivalencia_formal.csv</td>
#       <td>11601</td>
#       <td>compatível</td>
#     </tr>
#     <tr>
#       <td>f3_exemplos_fewshot.jsonl</td>
#       <td>170191</td>
#       <td>compatível</td>
#     </tr>
#     <tr>
#       <td>f3_grid.csv</td>
#       <td>5909</td>
#       <td>compatível</td>
#     </tr>
#     <tr>
#       <td>f3_input_audit.csv</td>
#       <td>844</td>
#       <td>compatível</td>
#     </tr>
#     <tr>
#       <td>f3_prompt_audit.csv</td>
#       <td>642966</td>
#       <td>compatível</td>
#     </tr>
#     <tr>
#       <td>f3_prompt_templates.json</td>
#       <td>4764</td>
#       <td>compatível</td>
#     </tr>
#     <tr>
#       <td>f3_result_schema.json</td>
#       <td>5649</td>
#       <td>compatível</td>
#     </tr>
#     <tr>
#       <td>f3_selecao_fewshot.csv</td>
#       <td>101374</td>
#       <td>compatível</td>
#     </tr>
#     <tr>
#       <td>inputs/campi_canonical.csv</td>
#       <td>21184</td>
#       <td>compatível</td>
#     </tr>
#     <tr>
#       <td>inputs/f0_manifest.json</td>
#       <td>5534</td>
#       <td>compatível</td>
#     </tr>
#     <tr>
#       <td>inputs/f1_manifest.json</td>
#       <td>2956</td>
#       <td>compatível</td>
#     </tr>
#     <tr>
#       <td>inputs/f2_manifest.json</td>
#       <td>4791</td>
#       <td>compatível</td>
#     </tr>
#     <tr>
#       <td>inputs/folds.csv</td>
#       <td>11200</td>
#       <td>compatível</td>
#     </tr>
#     <tr>
#       <td>inputs/ir_core.py</td>
#       <td>4812</td>
#       <td>compatível</td>
#     </tr>
#     <tr>
#       <td>inputs/ir_references.jsonl</td>
#       <td>17967</td>
#       <td>compatível</td>
#     </tr>
#     <tr>
#       <td>inputs/ir_schema.json</td>
#       <td>9174</td>
#       <td>compatível</td>
#     </tr>
#     <tr>
#       <td>inputs/nile_core.py</td>
#       <td>20106</td>
#       <td>compatível</td>
#     </tr>
#     <tr>
#       <td>inputs/nile_metrics.py</td>
#       <td>10022</td>
#       <td>compatível</td>
#     </tr>
#     <tr>
#       <td>inputs/nile_subset.lark</td>
#       <td>1332</td>
#       <td>compatível</td>
#     </tr>
#     <tr>
#       <td>inputs/rationales_references.jsonl</td>
#       <td>36029</td>
#       <td>compatível</td>
#     </tr>
#     <tr>
#       <td>prompts/f3_autocorrecao_nile.txt</td>
#       <td>2121</td>
#       <td>compatível</td>
#     </tr>
#     <tr>
#       <td>prompts/f3a_traducao_direta.txt</td>
#       <td>1774</td>
#       <td>compatível</td>
#     </tr>
#     <tr>
#       <td>prompts/f3c_gerar_ir_teste.txt</td>
#       <td>2039</td>
#       <td>compatível</td>
#     </tr>
#     <tr>
#       <td>prompts/f3c_gerar_nile_a_partir_ir.txt</td>
#       <td>1786</td>
#       <td>compatível</td>
#     </tr>
#     <tr>
#       <td>prompts/f3d_traducao_com_r3.txt</td>
#       <td>1921</td>
#       <td>compatível</td>
#     </tr>
#     <tr>
#       <td>prompts/f3e_gerar_ir_com_r1.txt</td>
#       <td>2162</td>
#       <td>compatível</td>
#     </tr>
#     <tr>
#       <td>prompts/f3e_gerar_nile_com_r2.txt</td>
#       <td>1918</td>
#       <td>compatível</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
# Bloco 2 concluído.
# Entrada operacional: /kaggle/input/datasets/thiagoarajoguedes/f3-modelo-operacional
# Integridade dos arquivos: confirmada
# Proteções contra vazamento: confirmadas
# Status: OK

# %% [markdown]
# ## Bloco 3 - Carga da base comum, da IR e dos módulos formais
#
# ### Objetivo
#
# Este bloco integra os 50 exemplos do CAMPI, as IRs de referência, as justificativas preservadas, os folds, as seleções few-shot e os módulos determinísticos necessários à execução e à avaliação.
#
# ### Módulos ativados
#
# São importados de maneira controlada:
#
# - `f3_common.py`, com montagem de prompts, extração e geração;
# - `nile_core.py`, com parser e AST;
# - `nile_metrics.py`, com PSR, EM, ED, NED, SLA-S e SLA-F;
# - `ir_core.py`, com validação e transformações da IR.
#
# ### Estruturas carregadas
#
# O bloco carrega:
#
# - CAMPI canônico;
# - cinco folds;
# - grade experimental;
# - mapa de 450 seleções cumulativas;
# - auditoria detalhada das posições few-shot;
# - 50 IRs de referência;
# - 50 conjuntos R1, R2 e R3;
# - JSON Schema da IR;
# - schema comum dos resultados da Fase 3;
# - templates da F3-C e da autocorreção.
#
# ### Barreiras
#
# São verificadas:
#
# - 50 referências Nile sintaticamente válidas;
# - 50 IRs válidas pelo JSON Schema;
# - 40 exemplos de treino e 10 de teste por fold;
# - cada ID em teste uma única vez;
# - 450 seleções cumulativas;
# - nenhuma demonstração fora do treino;
# - nenhuma demonstração com o mesmo ID, Nile, IR ou assinatura formal do teste;
# - exatamente 18 linhas da F3-C na grade.
#
# ### Resultado esperado
#
# A base integrada estará pronta para construir os 450 fluxos-base sem acessar artefatos de referência durante a inferência do teste.

# %%
# ----------------------------------------------------------
# 3.1 Importação controlada dos módulos
# ----------------------------------------------------------

import importlib.util
from jsonschema import Draft202012Validator


def import_module_from_path(module_name, path):
    path = Path(path)
    spec = importlib.util.spec_from_file_location(module_name, path)
    if spec is None or spec.loader is None:
        raise ImportError(f"Não foi possível importar {module_name} de {path}.")
    module = importlib.util.module_from_spec(spec)
    sys.modules[module_name] = module
    spec.loader.exec_module(module)
    return module


f3_common = import_module_from_path("f3_common_runtime", F3_MODELO_DIR / "f3_common.py")
nile_core = import_module_from_path("nile_core_runtime", F3_MODELO_DIR / "inputs/nile_core.py")
nile_metrics = import_module_from_path("nile_metrics_runtime", F3_MODELO_DIR / "inputs/nile_metrics.py")
ir_core = import_module_from_path("ir_core_runtime", F3_MODELO_DIR / "inputs/ir_core.py")


# ----------------------------------------------------------
# 3.2 Carga dos artefatos
# ----------------------------------------------------------

f3_config = read_json(F3_MODELO_DIR / "f3_config.json")
result_schema = read_json(F3_MODELO_DIR / "f3_result_schema.json")
ir_schema = read_json(F3_MODELO_DIR / "inputs/ir_schema.json")
result_validator = Draft202012Validator(result_schema)

campi_df = pd.read_csv(F3_MODELO_DIR / "inputs/campi_canonical.csv")
folds_df = pd.read_csv(F3_MODELO_DIR / "inputs/folds.csv")
grid_df = pd.read_csv(F3_MODELO_DIR / "f3_grid.csv")
selection_detail_df = pd.read_csv(F3_MODELO_DIR / "f3_selecao_fewshot.csv")
formal_equivalence_df = pd.read_csv(F3_MODELO_DIR / "f3_equivalencia_formal.csv")
prompt_audit_base_df = pd.read_csv(F3_MODELO_DIR / "f3_prompt_audit.csv")

ir_records = f3_common.read_jsonl(F3_MODELO_DIR / "inputs/ir_references.jsonl")
rationale_records = f3_common.read_jsonl(F3_MODELO_DIR / "inputs/rationales_references.jsonl")
selection_map = f3_common.load_selection_map(F3_MODELO_DIR / "f3_exemplos_fewshot.jsonl")

template_ir = (F3_MODELO_DIR / "prompts/f3c_gerar_ir_teste.txt").read_text(encoding="utf-8")
template_nile = (F3_MODELO_DIR / "prompts/f3c_gerar_nile_a_partir_ir.txt").read_text(encoding="utf-8")
template_autocorrection = (F3_MODELO_DIR / "prompts/f3_autocorrecao_nile.txt").read_text(encoding="utf-8")
grammar_text = (F3_MODELO_DIR / "inputs/nile_subset.lark").read_text(encoding="utf-8")
validator = nile_core.NileValidator(grammar_text)


# ----------------------------------------------------------
# 3.3 Integração por ID
# ----------------------------------------------------------

ir_by_id = {record["id"]: record["ir"] for record in ir_records}
rationale_by_id = {record["id"]: record for record in rationale_records}

records_by_id = {}
for row in campi_df.to_dict(orient="records"):
    item_id = str(row["id"])
    if item_id not in ir_by_id or item_id not in rationale_by_id:
        raise KeyError(f"Artefatos auxiliares ausentes para {item_id}.")
    records_by_id[item_id] = {
        "id": item_id,
        "nl": str(row["nl"]),
        "nile": str(row["nile_canonical"]),
        "ir": ir_by_id[item_id],
        "r1": rationale_by_id[item_id]["r1"],
        "r2": rationale_by_id[item_id]["r2"],
        "r3": rationale_by_id[item_id]["r3"],
    }

expected_ids = [f"campi_{index:03d}" for index in range(1, TOTAL_EXEMPLOS_ESPERADO + 1)]
if sorted(records_by_id) != expected_ids:
    raise ValueError("Os IDs integrados não correspondem aos 50 exemplos esperados.")


# ----------------------------------------------------------
# 3.4 Auditoria dos folds, seleções e grade
# ----------------------------------------------------------

fold_counts = (
    folds_df
    .groupby(["fold", "split"])
    .size()
    .unstack(fill_value=0)
    .rename_axis(columns=None)
    .reset_index()
)
if len(fold_counts) != TOTAL_FOLDS_ESPERADO:
    raise ValueError("Quantidade de folds divergente.")
if not fold_counts["train"].eq(40).all() or not fold_counts["test"].eq(10).all():
    raise ValueError("Cada fold deve conter 40 registros de treino e 10 de teste.")

test_occurrences = folds_df.loc[folds_df["split"] == "test", "id"].value_counts()
if set(test_occurrences.index) != set(expected_ids) or not test_occurrences.eq(1).all():
    raise ValueError("Cada exemplo deve aparecer em teste exatamente uma vez.")

if len(selection_map) != 450:
    raise ValueError(f"Esperadas 450 seleções cumulativas; encontradas {len(selection_map)}.")

selection_boolean_columns = [
    "pertence ao treino",
    "vazamento do teste",
    "Nile idêntica à do teste",
    "IR idêntica à do teste",
    "equivalência formal com o teste",
    "elegível",
]
for column in selection_boolean_columns:
    if column not in selection_detail_df.columns:
        raise KeyError(f"Coluna de auditoria ausente: {column}")

if not selection_detail_df["pertence ao treino"].astype(bool).all():
    raise ValueError("Há demonstração fora do conjunto de treino.")
if selection_detail_df["vazamento do teste"].astype(bool).any():
    raise ValueError("Há demonstração com o mesmo ID do teste.")
if selection_detail_df["Nile idêntica à do teste"].astype(bool).any():
    raise ValueError("Há demonstração com Nile idêntica à referência do teste.")
if selection_detail_df["IR idêntica à do teste"].astype(bool).any():
    raise ValueError("Há demonstração com IR idêntica à referência do teste.")
if selection_detail_df["equivalência formal com o teste"].astype(bool).any():
    raise ValueError("Há demonstração formalmente equivalente ao teste.")
if not selection_detail_df["elegível"].astype(bool).all():
    raise ValueError("Há demonstração marcada como não elegível.")

f3c_grid_df = grid_df.loc[grid_df["estratégia"] == ESTRATEGIA].copy()
if len(f3c_grid_df) != TOTAL_CONDICOES_ESPERADO:
    raise ValueError("A grade da F3-C não possui 18 condições.")
if set(f3c_grid_df["variante"]) != set(VARIANTES):
    raise ValueError("As variantes da F3-C estão divergentes.")
if set(f3c_grid_df["k"].astype(int)) != set(K_FEWSHOT):
    raise ValueError("Os valores de k da F3-C estão divergentes.")
if set(f3c_grid_df["método de seleção"]) != set(METODOS_FEWSHOT):
    raise ValueError("Os métodos da F3-C estão divergentes.")


# ----------------------------------------------------------
# 3.5 Validação das referências Nile e IR
# ----------------------------------------------------------

formal_rows = []
for item_id, record in records_by_id.items():
    nile_validation = validator.validate(record["nile"])
    ir_validation = ir_core.validate_ir(record["ir"], ir_schema)
    self_metrics = nile_metrics.evaluate_pair(record["nile"], record["nile"], validator)
    formal_rows.append({
        "id": item_id,
        "syntax_valid": bool(nile_validation.get("syntax_valid", False)),
        "ir_valid": bool(ir_validation.get("schema_valid", False)),
        "psr": self_metrics["psr"],
        "em": self_metrics["em"],
        "ed": self_metrics["ed"],
        "ned": self_metrics["ned"],
        "sla_s": self_metrics["sla_s"],
        "sla_f": self_metrics["sla_f"],
    })

formal_validation_df = pd.DataFrame(formal_rows)
if not formal_validation_df[["syntax_valid", "ir_valid"]].all().all():
    raise ValueError("Há referência formal inválida na base integrada.")
if not formal_validation_df["psr"].eq(1).all() or not formal_validation_df["em"].eq(1).all():
    raise ValueError("A autocomparação das referências falhou.")
if not formal_validation_df["ed"].eq(0).all() or not formal_validation_df["ned"].eq(0).all():
    raise ValueError("A distância da autocomparação não é zero.")
if not formal_validation_df["sla_s"].eq(1).all() or not formal_validation_df["sla_f"].eq(1).all():
    raise ValueError("A aderência da autocomparação não é perfeita.")

resource_summary_df = pd.DataFrame([
    {"item": "exemplos integrados", "value": len(records_by_id)},
    {"item": "folds", "value": folds_df["fold"].nunique()},
    {"item": "condições da F3-C", "value": len(f3c_grid_df)},
    {"item": "seleções cumulativas", "value": len(selection_map)},
    {"item": "posições few-shot auditadas", "value": len(selection_detail_df)},
    {"item": "referências Nile sintaticamente válidas", "value": int(formal_validation_df["syntax_valid"].sum())},
    {"item": "referências IR válidas", "value": int(formal_validation_df["ir_valid"].sum())},
])

exibir_tabela(resource_summary_df, "Recursos carregados para a F3-C")
exibir_tabela(fold_counts, "Distribuição de treino e teste por fold")

print("Bloco 3 concluído.")
print("Base integrada: 50 exemplos")
print("IR, validador Nile e métricas: aprovados")
print("Seleções few-shot: sem vazamento")
print("Status: OK")
# Out:
#     <div style="font-weight:600;font-size:15px;margin:8px 0 6px;color:#f1f1f1;">
#         Tabela 3. Recursos carregados para a F3-C
#     </div>
#     <div class="container_tabela_saida" style="display:inline-block;max-width:100%;overflow-x:auto;overflow-y: visible;border:none;margin:8px 0 12px;">
#         <style>
#             .container_tabela_saida table.tabela_saida {
#                 border-collapse:collapse !important;
#                 table-layout:auto !important;
#                 width:auto !important;
#                 font-family:Arial,sans-serif !important;
#                 font-size:13px !important;
#                 background:#111 !important;
#                 color:#f1f1f1 !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida thead th {
#                 position:sticky !important;
#                 top:0 !important;
#                 z-index:2 !important;
#                 background:#2b2b2b !important;
#                 color:#fff !important;
#                 padding:7px !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #777 !important;
#                 border-bottom:2px solid #888 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody td {
#                 padding:7px !important;
#                 vertical-align:top !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(even) td {background:#1b1b1b !important;}
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(odd) td {background:#111 !important;}
#         </style>
#         <table class="dataframe tabela_saida">
#   <thead>
#     <tr style="text-align: left;">
#       <th>item</th>
#       <th>valor</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>exemplos integrados</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <td>folds</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <td>condições da F3-C</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <td>seleções cumulativas</td>
#       <td>450</td>
#     </tr>
#     <tr>
#       <td>posições few-shot auditadas</td>
#       <td>750</td>
#     </tr>
#     <tr>
#       <td>referências Nile sintaticamente válidas</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <td>referências IR válidas</td>
#       <td>50</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
#     <div style="font-weight:600;font-size:15px;margin:8px 0 6px;color:#f1f1f1;">
#         Tabela 4. Distribuição de treino e teste por fold
#     </div>
#     <div class="container_tabela_saida" style="display:inline-block;max-width:100%;overflow-x:auto;overflow-y: visible;border:none;margin:8px 0 12px;">
#         <style>
#             .container_tabela_saida table.tabela_saida {
#                 border-collapse:collapse !important;
#                 table-layout:auto !important;
#                 width:auto !important;
#                 font-family:Arial,sans-serif !important;
#                 font-size:13px !important;
#                 background:#111 !important;
#                 color:#f1f1f1 !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida thead th {
#                 position:sticky !important;
#                 top:0 !important;
#                 z-index:2 !important;
#                 background:#2b2b2b !important;
#                 color:#fff !important;
#                 padding:7px !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #777 !important;
#                 border-bottom:2px solid #888 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody td {
#                 padding:7px !important;
#                 vertical-align:top !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(even) td {background:#1b1b1b !important;}
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(odd) td {background:#111 !important;}
#         </style>
#         <table class="dataframe tabela_saida">
#   <thead>
#     <tr style="text-align: left;">
#       <th>fold</th>
#       <th>test</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>10</td>
#       <td>40</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>10</td>
#       <td>40</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>10</td>
#       <td>40</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>10</td>
#       <td>40</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>10</td>
#       <td>40</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
# Bloco 3 concluído.
# Base integrada: 50 exemplos
# IR, validador Nile e métricas: aprovados
# Seleções few-shot: sem vazamento
# Status: OK

# %% [markdown]
# ## Bloco 4 - Construção do plano dos 450 fluxos-base
#
# ### Objetivo
#
# Este bloco transforma os folds e as seleções congeladas em um plano explícito para os 450 fluxos NL → IR → Nile.
#
# ### Formação das condições
#
# Para cada fold e exemplo de teste, são combinados:
#
# - `k=1`, `k=3` e `k=5`;
# - seleção Aleatória, Lexical e Semântica.
#
# Cada combinação contém 50 testes, totalizando nove condições e 450 fluxos-base.
#
# ### Demonstrações
#
# O mesmo conjunto de IDs selecionados é utilizado nos dois estágios:
#
# - no primeiro estágio, cada demonstração apresenta NL e IR;
# - no segundo estágio, cada demonstração apresenta IR e Nile.
#
# A primeira autocorreção também reutiliza as demonstrações IR → Nile da condição correspondente.
#
# ### Congelamento
#
# O plano registra fold, ID, método, `k`, demonstrações, escores, hashes das referências e ID estável do fluxo. As duas variantes finais são derivadas desse mesmo plano.
#
# ### Resultado esperado
#
# O arquivo `f3c_plano_execucao.csv` conterá exatamente 450 linhas, com 50 registros em cada condição.

# %%
# ----------------------------------------------------------
# 4.1 Construção dos fluxos-base
# ----------------------------------------------------------

plan_records = []
for fold in range(1, TOTAL_FOLDS_ESPERADO + 1):
    test_ids = (
        folds_df.loc[
            (folds_df["fold"] == fold) & (folds_df["split"] == "test"),
            "id",
        ]
        .astype(str)
        .sort_values()
        .tolist()
    )
    if len(test_ids) != 10:
        raise ValueError(f"O fold {fold} não possui 10 testes.")

    for k in K_FEWSHOT:
        for method in ORDEM_METODOS_EXIBICAO:
            for test_id in test_ids:
                selection_key = (fold, test_id, method, k)
                if selection_key not in selection_map:
                    raise KeyError(f"Seleção ausente: {selection_key}")
                selection = selection_map[selection_key]
                selected_ids = list(selection["selected_ids"])
                scores = list(selection.get("scores", []))
                if len(selected_ids) != k or len(scores) != k:
                    raise ValueError(f"Seleção incompatível para {selection_key}.")

                record = records_by_id[test_id]
                pipeline_id = (
                    f"f3c|fold={fold}|id={test_id}|method={method}|k={k}"
                )
                plan_records.append({
                    "pipeline_id": pipeline_id,
                    "fold": fold,
                    "id": test_id,
                    "selection_method": method,
                    "selection_label": ROTULOS_METODOS[method],
                    "k": k,
                    "demonstration_ids": selected_ids,
                    "demonstration_scores": scores,
                    "nl_sha256": sha256_text(record["nl"]),
                    "reference_nile_sha256": sha256_text(record["nile"]),
                    "reference_ir_sha256": sha256_text(canonical_json(record["ir"])),
                    "variants": VARIANTES,
                })

if len(plan_records) != TOTAL_FLUXOS_BASE_ESPERADO:
    raise ValueError(
        f"Esperados {TOTAL_FLUXOS_BASE_ESPERADO} fluxos; "
        f"encontrados {len(plan_records)}."
    )

plan_df = pd.DataFrame(plan_records)
if plan_df["pipeline_id"].duplicated().any():
    raise ValueError("Há ID de fluxo duplicado.")

condition_counts = (
    plan_df.groupby(["selection_method", "selection_label", "k"], dropna=False)
    .size()
    .reset_index(name="records")
)
condition_counts["_ordem_metodo"] = condition_counts["selection_method"].map(ORDEM_METODOS_MAPA)
condition_counts = (
    condition_counts
    .sort_values(["k", "_ordem_metodo"])
    .drop(columns="_ordem_metodo")
    .reset_index(drop=True)
)
if len(condition_counts) != TOTAL_CONDICOES_BASE or not condition_counts["records"].eq(50).all():
    raise ValueError("As nove condições-base não possuem 50 registros cada.")

plan_export_df = plan_df.copy()
plan_export_df["demonstration_ids"] = plan_export_df["demonstration_ids"].apply(canonical_json)
plan_export_df["demonstration_scores"] = plan_export_df["demonstration_scores"].apply(canonical_json)
plan_export_df["variants"] = plan_export_df["variants"].apply(canonical_json)
plan_export_df.to_csv(PLANO_PATH, index=False, encoding="utf-8")

plan_summary_df = pd.DataFrame([
    {"item": "condições-base", "value": len(condition_counts)},
    {"item": "fluxos-base", "value": len(plan_records)},
    {"item": "variantes finais", "value": len(VARIANTES)},
    {"item": "registros finais previstos", "value": len(plan_records) * len(VARIANTES)},
    {"item": "mínimo de demonstrações", "value": int(plan_df["k"].min())},
    {"item": "máximo de demonstrações", "value": int(plan_df["k"].max())},
])

exibir_tabela(plan_summary_df, "Resumo do plano da F3-C")
exibir_tabela(condition_counts, "Fluxos por método e k")
exibir_tabela(
    plan_export_df[[
        "pipeline_id",
        "fold",
        "id",
        "selection_label",
        "k",
        "demonstration_ids",
    ]].head(20),
    "Primeiros fluxos planejados",
    altura_px=420,
)

print("Bloco 4 concluído.")
print(f"Fluxos-base: {len(plan_records)}")
print(f"Registros finais previstos: {len(plan_records) * len(VARIANTES)}")
print("Ordem dos métodos: Aleatória, Lexical e Semântica")
print("Status: OK")
# Out:
#     <div style="font-weight:600;font-size:15px;margin:8px 0 6px;color:#f1f1f1;">
#         Tabela 5. Resumo do plano da F3-C
#     </div>
#     <div class="container_tabela_saida" style="display:inline-block;max-width:100%;overflow-x:auto;overflow-y: visible;border:none;margin:8px 0 12px;">
#         <style>
#             .container_tabela_saida table.tabela_saida {
#                 border-collapse:collapse !important;
#                 table-layout:auto !important;
#                 width:auto !important;
#                 font-family:Arial,sans-serif !important;
#                 font-size:13px !important;
#                 background:#111 !important;
#                 color:#f1f1f1 !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida thead th {
#                 position:sticky !important;
#                 top:0 !important;
#                 z-index:2 !important;
#                 background:#2b2b2b !important;
#                 color:#fff !important;
#                 padding:7px !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #777 !important;
#                 border-bottom:2px solid #888 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody td {
#                 padding:7px !important;
#                 vertical-align:top !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(even) td {background:#1b1b1b !important;}
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(odd) td {background:#111 !important;}
#         </style>
#         <table class="dataframe tabela_saida">
#   <thead>
#     <tr style="text-align: left;">
#       <th>item</th>
#       <th>valor</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>condições-base</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <td>fluxos-base</td>
#       <td>450</td>
#     </tr>
#     <tr>
#       <td>variantes finais</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>registros finais previstos</td>
#       <td>900</td>
#     </tr>
#     <tr>
#       <td>mínimo de demonstrações</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>máximo de demonstrações</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
#     <div style="font-weight:600;font-size:15px;margin:8px 0 6px;color:#f1f1f1;">
#         Tabela 6. Fluxos por método e k
#     </div>
#     <div class="container_tabela_saida" style="display:inline-block;max-width:100%;overflow-x:auto;overflow-y: visible;border:none;margin:8px 0 12px;">
#         <style>
#             .container_tabela_saida table.tabela_saida {
#                 border-collapse:collapse !important;
#                 table-layout:auto !important;
#                 width:auto !important;
#                 font-family:Arial,sans-serif !important;
#                 font-size:13px !important;
#                 background:#111 !important;
#                 color:#f1f1f1 !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida thead th {
#                 position:sticky !important;
#                 top:0 !important;
#                 z-index:2 !important;
#                 background:#2b2b2b !important;
#                 color:#fff !important;
#                 padding:7px !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #777 !important;
#                 border-bottom:2px solid #888 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody td {
#                 padding:7px !important;
#                 vertical-align:top !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(even) td {background:#1b1b1b !important;}
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(odd) td {background:#111 !important;}
#         </style>
#         <table class="dataframe tabela_saida">
#   <thead>
#     <tr style="text-align: left;">
#       <th>método de seleção</th>
#       <th>rótulo do método</th>
#       <th>k</th>
#       <th>registros</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>random_seed42</td>
#       <td>Aleatória</td>
#       <td>1</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <td>lexical_tfidf</td>
#       <td>Lexical</td>
#       <td>1</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <td>semantic_embeddings</td>
#       <td>Semântica</td>
#       <td>1</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <td>random_seed42</td>
#       <td>Aleatória</td>
#       <td>3</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <td>lexical_tfidf</td>
#       <td>Lexical</td>
#       <td>3</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <td>semantic_embeddings</td>
#       <td>Semântica</td>
#       <td>3</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <td>random_seed42</td>
#       <td>Aleatória</td>
#       <td>5</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <td>lexical_tfidf</td>
#       <td>Lexical</td>
#       <td>5</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <td>semantic_embeddings</td>
#       <td>Semântica</td>
#       <td>5</td>
#       <td>50</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
#     <div style="font-weight:600;font-size:15px;margin:8px 0 6px;color:#f1f1f1;">
#         Tabela 7. Primeiros fluxos planejados
#     </div>
#     <div class="container_tabela_saida" style="display:inline-block;max-width:100%;overflow-x:auto;max-height: 420px; overflow-y: auto;border:none;margin:8px 0 12px;">
#         <style>
#             .container_tabela_saida table.tabela_saida {
#                 border-collapse:collapse !important;
#                 table-layout:auto !important;
#                 width:auto !important;
#                 font-family:Arial,sans-serif !important;
#                 font-size:13px !important;
#                 background:#111 !important;
#                 color:#f1f1f1 !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida thead th {
#                 position:sticky !important;
#                 top:0 !important;
#                 z-index:2 !important;
#                 background:#2b2b2b !important;
#                 color:#fff !important;
#                 padding:7px !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #777 !important;
#                 border-bottom:2px solid #888 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody td {
#                 padding:7px !important;
#                 vertical-align:top !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(even) td {background:#1b1b1b !important;}
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(odd) td {background:#111 !important;}
#         </style>
#         <table class="dataframe tabela_saida">
#   <thead>
#     <tr style="text-align: left;">
#       <th>ID do fluxo</th>
#       <th>fold</th>
#       <th>ID</th>
#       <th>rótulo do método</th>
#       <th>k</th>
#       <th>demonstration ids</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>f3c|fold=1|id=campi_001|method=random_seed42|k=1</td>
#       <td>1</td>
#       <td>campi_001</td>
#       <td>Aleatória</td>
#       <td>1</td>
#       <td>["campi_043"]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=1|id=campi_002|method=random_seed42|k=1</td>
#       <td>1</td>
#       <td>campi_002</td>
#       <td>Aleatória</td>
#       <td>1</td>
#       <td>["campi_033"]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=1|id=campi_011|method=random_seed42|k=1</td>
#       <td>1</td>
#       <td>campi_011</td>
#       <td>Aleatória</td>
#       <td>1</td>
#       <td>["campi_022"]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=1|id=campi_012|method=random_seed42|k=1</td>
#       <td>1</td>
#       <td>campi_012</td>
#       <td>Aleatória</td>
#       <td>1</td>
#       <td>["campi_013"]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=1|id=campi_020|method=random_seed42|k=1</td>
#       <td>1</td>
#       <td>campi_020</td>
#       <td>Aleatória</td>
#       <td>1</td>
#       <td>["campi_008"]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=1|id=campi_023|method=random_seed42|k=1</td>
#       <td>1</td>
#       <td>campi_023</td>
#       <td>Aleatória</td>
#       <td>1</td>
#       <td>["campi_034"]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=1|id=campi_024|method=random_seed42|k=1</td>
#       <td>1</td>
#       <td>campi_024</td>
#       <td>Aleatória</td>
#       <td>1</td>
#       <td>["campi_006"]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=1|id=campi_027|method=random_seed42|k=1</td>
#       <td>1</td>
#       <td>campi_027</td>
#       <td>Aleatória</td>
#       <td>1</td>
#       <td>["campi_010"]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=1|id=campi_039|method=random_seed42|k=1</td>
#       <td>1</td>
#       <td>campi_039</td>
#       <td>Aleatória</td>
#       <td>1</td>
#       <td>["campi_006"]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=1|id=campi_044|method=random_seed42|k=1</td>
#       <td>1</td>
#       <td>campi_044</td>
#       <td>Aleatória</td>
#       <td>1</td>
#       <td>["campi_047"]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=1|id=campi_001|method=lexical_tfidf|k=1</td>
#       <td>1</td>
#       <td>campi_001</td>
#       <td>Lexical</td>
#       <td>1</td>
#       <td>["campi_030"]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=1|id=campi_002|method=lexical_tfidf|k=1</td>
#       <td>1</td>
#       <td>campi_002</td>
#       <td>Lexical</td>
#       <td>1</td>
#       <td>["campi_047"]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=1|id=campi_011|method=lexical_tfidf|k=1</td>
#       <td>1</td>
#       <td>campi_011</td>
#       <td>Lexical</td>
#       <td>1</td>
#       <td>["campi_005"]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=1|id=campi_012|method=lexical_tfidf|k=1</td>
#       <td>1</td>
#       <td>campi_012</td>
#       <td>Lexical</td>
#       <td>1</td>
#       <td>["campi_018"]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=1|id=campi_020|method=lexical_tfidf|k=1</td>
#       <td>1</td>
#       <td>campi_020</td>
#       <td>Lexical</td>
#       <td>1</td>
#       <td>["campi_009"]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=1|id=campi_023|method=lexical_tfidf|k=1</td>
#       <td>1</td>
#       <td>campi_023</td>
#       <td>Lexical</td>
#       <td>1</td>
#       <td>["campi_003"]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=1|id=campi_024|method=lexical_tfidf|k=1</td>
#       <td>1</td>
#       <td>campi_024</td>
#       <td>Lexical</td>
#       <td>1</td>
#       <td>["campi_040"]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=1|id=campi_027|method=lexical_tfidf|k=1</td>
#       <td>1</td>
#       <td>campi_027</td>
#       <td>Lexical</td>
#       <td>1</td>
#       <td>["campi_021"]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=1|id=campi_039|method=lexical_tfidf|k=1</td>
#       <td>1</td>
#       <td>campi_039</td>
#       <td>Lexical</td>
#       <td>1</td>
#       <td>["campi_037"]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=1|id=campi_044|method=lexical_tfidf|k=1</td>
#       <td>1</td>
#       <td>campi_044</td>
#       <td>Lexical</td>
#       <td>1</td>
#       <td>["campi_043"]</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
# Bloco 4 concluído.
# Fluxos-base: 450
# Registros finais previstos: 900
# Ordem dos métodos: Aleatória, Lexical e Semântica
# Status: OK

# %% [markdown]
# ## Bloco 5 - Carregamento do modelo aluno
#
# ### Objetivo
#
# Este bloco resolve a fonte do Qwen2.5-1.5B-Instruct, carrega tokenizer e modelo uma única vez e determina o limite de contexto utilizado pelas três etapas de geração.
#
# ### Fonte do modelo
#
# A prioridade é:
#
# 1. diretório local adicionado aos inputs do Kaggle;
# 2. identificador oficial do Hugging Face, quando a internet estiver habilitada.
#
# ### Configuração de geração
#
# A geração é determinística:
#
# - `do_sample=False`;
# - 512 tokens máximos para IR;
# - 256 tokens máximos para Nile;
# - 256 tokens máximos para autocorreção;
# - cache habilitado.
#
# Parâmetros de amostragem armazenados na configuração original do modelo são neutralizados para evitar avisos e garantir que não influenciem a execução.
#
# ### Resultado esperado
#
# O modelo será carregado uma única vez e reutilizado nos Blocos 6, 7 e 8.

# %%
# ----------------------------------------------------------
# 5.1 Resolução da fonte do modelo aluno
# ----------------------------------------------------------

local_model_dir = f3_common.resolve_local_model_dir(
    KAGGLE_INPUT,
    MODELO_LOCAL_HINTS,
) if KAGGLE_INPUT.exists() else None

if local_model_dir is not None:
    MODEL_SOURCE = local_model_dir
    MODEL_SOURCE_TYPE = "diretório local do Kaggle"
    LOCAL_FILES_ONLY = True
elif PERMITIR_DOWNLOAD_HUGGINGFACE:
    MODEL_SOURCE = MODELO_HF_ID
    MODEL_SOURCE_TYPE = "Hugging Face"
    LOCAL_FILES_ONLY = False
else:
    raise FileNotFoundError(
        "O modelo aluno não foi localizado em /kaggle/input e o download está desativado."
    )


# ----------------------------------------------------------
# 5.2 Carregamento do tokenizer e do modelo
# ----------------------------------------------------------

try:
    import torch
    tokenizer, model = f3_common.load_student_model(
        MODEL_SOURCE,
        use_cuda=USAR_CUDA,
        local_files_only=LOCAL_FILES_ONLY,
    )
except Exception as exc:
    raise RuntimeError(
        "Não foi possível carregar o Qwen2.5-1.5B-Instruct. "
        "Confirme que o modelo está disponível no Kaggle ou habilite a internet. "
        f"Erro original: {exc}"
    ) from exc

model_device = str(next(model.parameters()).device)
model_dtype = str(next(model.parameters()).dtype)

if hasattr(model, "generation_config"):
    model.generation_config.do_sample = False
    generation_defaults = {
        "temperature": 1.0,
        "top_p": 1.0,
        "top_k": 50,
    }
    for attribute, value in generation_defaults.items():
        if hasattr(model.generation_config, attribute):
            setattr(model.generation_config, attribute, value)

context_candidates = []
for value in [
    getattr(getattr(model, "config", None), "max_position_embeddings", None),
    getattr(getattr(model, "config", None), "max_seq_len", None),
    getattr(tokenizer, "model_max_length", None),
]:
    try:
        numeric = int(value)
    except Exception:
        continue
    if 1024 <= numeric <= 1_000_000:
        context_candidates.append(numeric)

CONTEXT_LIMIT = min(context_candidates) if context_candidates else LIMITE_CONTEXTO_FALLBACK

if torch.cuda.is_available():
    gpu_name = torch.cuda.get_device_name(0)
    gpu_memory_gb = torch.cuda.get_device_properties(0).total_memory / (1024 ** 3)
else:
    gpu_name = None
    gpu_memory_gb = None

model_summary_df = pd.DataFrame([
    {"item": "modelo", "value": MODELO_ALUNO},
    {"item": "fonte utilizada", "value": str(MODEL_SOURCE)},
    {"item": "tipo da fonte", "value": MODEL_SOURCE_TYPE},
    {"item": "dispositivo", "value": model_device},
    {"item": "precisão", "value": model_dtype},
    {"item": "limite de contexto", "value": CONTEXT_LIMIT},
    {"item": "GPU", "value": gpu_name},
    {"item": "memória da GPU em GB", "value": round(gpu_memory_gb, 2) if gpu_memory_gb else None},
])

exibir_tabela(model_summary_df, "Modelo aluno carregado")

print("Bloco 5 concluído.")
print(f"Fonte do modelo: {MODEL_SOURCE}")
print(f"Dispositivo: {model_device}")
print(f"Limite de contexto adotado: {CONTEXT_LIMIT}")
print("Geração experimental iniciará no Bloco 6.")
print("Status: OK")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/660 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
#     <div style="font-weight:600;font-size:15px;margin:8px 0 6px;color:#f1f1f1;">
#         Tabela 8. Modelo aluno carregado
#     </div>
#     <div class="container_tabela_saida" style="display:inline-block;max-width:100%;overflow-x:auto;overflow-y: visible;border:none;margin:8px 0 12px;">
#         <style>
#             .container_tabela_saida table.tabela_saida {
#                 border-collapse:collapse !important;
#                 table-layout:auto !important;
#                 width:auto !important;
#                 font-family:Arial,sans-serif !important;
#                 font-size:13px !important;
#                 background:#111 !important;
#                 color:#f1f1f1 !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida thead th {
#                 position:sticky !important;
#                 top:0 !important;
#                 z-index:2 !important;
#                 background:#2b2b2b !important;
#                 color:#fff !important;
#                 padding:7px !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #777 !important;
#                 border-bottom:2px solid #888 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody td {
#                 padding:7px !important;
#                 vertical-align:top !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(even) td {background:#1b1b1b !important;}
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(odd) td {background:#111 !important;}
#         </style>
#         <table class="dataframe tabela_saida">
#   <thead>
#     <tr style="text-align: left;">
#       <th>item</th>
#       <th>valor</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>modelo</td>
#       <td>Qwen2.5-1.5B-Instruct</td>
#     </tr>
#     <tr>
#       <td>fonte utilizada</td>
#       <td>Qwen/Qwen2.5-1.5B-Instruct</td>
#     </tr>
#     <tr>
#       <td>tipo da fonte</td>
#       <td>Hugging Face</td>
#     </tr>
#     <tr>
#       <td>dispositivo</td>
#       <td>cuda:0</td>
#     </tr>
#     <tr>
#       <td>precisão</td>
#       <td>torch.float16</td>
#     </tr>
#     <tr>
#       <td>limite de contexto</td>
#       <td>32768</td>
#     </tr>
#     <tr>
#       <td>GPU</td>
#       <td>Tesla T4</td>
#     </tr>
#     <tr>
#       <td>memória da GPU em GB</td>
#       <td>14.56</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
# Bloco 5 concluído.
# Fonte do modelo: Qwen/Qwen2.5-1.5B-Instruct
# Dispositivo: cuda:0
# Limite de contexto adotado: 32768
# Geração experimental iniciará no Bloco 6.
# Status: OK

# %% [markdown]
# ## Bloco 6 - Geração e validação da Representação Intermediária
#
# ### Objetivo
#
# Este bloco executa o primeiro estágio dos 450 fluxos: NL → IR.
#
# ### Montagem dos prompts
#
# Cada prompt recebe:
#
# - JSON Schema completo da IR;
# - entrada em linguagem natural do teste;
# - `k` demonstrações NL → IR selecionadas no treino.
#
# Não são incluídas a Nile de referência, a IR de referência, R1, R2 ou R3 do teste.
#
# ### Auditoria de tokens e vazamento
#
# A contagem usa o mesmo chat template e o mesmo `input_ids` empregados na inferência. São verificadas:
#
# - ausência de placeholders;
# - ausência dos artefatos de referência do teste;
# - limite de contexto;
# - fingerprint individual do prompt.
#
# ### Execução incremental
#
# Cada geração aparece individualmente com fold, ID, método, `k`, etapa e status. A barra de progresso apresenta percentual, tempo decorrido e estimativa restante. Checkpoints compatíveis são reutilizados.
#
# ### Validação da IR
#
# A resposta é submetida a:
#
# 1. remoção controlada de cercas de código;
# 2. extração de objeto JSON balanceado;
# 3. validação pelo JSON Schema da F1.
#
# Uma IR inválida não é substituída pela referência. O segundo estágio receberá o JSON extraído ou, quando a extração falhar, o texto bruto produzido pelo modelo.
#
# ### Resultado esperado
#
# O bloco produzirá 450 prompts, 450 gerações e 450 registros de validação da IR.

# %%
# ----------------------------------------------------------
# 6.1 Funções comuns de tokenização, progresso e execução
# ----------------------------------------------------------

from tqdm.auto import tqdm


def count_chat_tokens(prompt):
    messages = [{"role": "user", "content": prompt}]
    encoded = tokenizer.apply_chat_template(
        messages,
        add_generation_prompt=True,
        tokenize=True,
        return_dict=True,
        return_tensors="pt",
    )
    if "input_ids" not in encoded:
        raise ValueError("O tokenizer não retornou input_ids.")
    return int(encoded["input_ids"].shape[-1])


def format_execution_line(position, total, record, stage, status):
    digits = max(3, len(str(total)))
    return (
        f"[{position:0{digits}d}/{total}] "
        f"fold_{int(record['fold'])} | "
        f"{record['id']} | "
        f"{record['selection_label']} | "
        f"k={int(record['k'])} | "
        f"etapa={stage} | "
        f"status={status}"
    )


def execute_generation_stage(
    prompt_records,
    checkpoint_path,
    output_path,
    stage,
    max_new_tokens,
):
    checkpoint_latest = {}
    for record in read_jsonl(checkpoint_path):
        execution_id = record.get("execution_id")
        if execution_id:
            checkpoint_latest[execution_id] = record

    compatible = {}
    stale_count = 0
    for prompt_record in prompt_records:
        previous = checkpoint_latest.get(prompt_record["execution_id"])
        if previous is None:
            continue
        if (
            previous.get("execution_fingerprint") == prompt_record["execution_fingerprint"]
            and previous.get("status") == "generated"
            and isinstance(previous.get("response_raw"), str)
        ):
            compatible[prompt_record["execution_id"]] = previous
        else:
            stale_count += 1

    reused_count = 0
    generated_count = 0
    total = len(prompt_records)
    progress = tqdm(
        total=total,
        desc=f"F3-C {stage}",
        unit="registro",
        dynamic_ncols=True,
        mininterval=0.1,
        smoothing=0.1,
        leave=True,
        bar_format=(
            "{desc}: |{bar:36}| {percentage:6.2f}% | "
            "{n_fmt}/{total_fmt} | decorrido={elapsed} | "
            "restante={remaining} | {postfix}"
        ),
    )
    progress.set_postfix_str("novas=0 | reutilizadas=0")

    try:
        for position, prompt_record in enumerate(prompt_records, start=1):
            execution_id = prompt_record["execution_id"]
            if execution_id in compatible:
                reused_count += 1
                status_line = "reutilizado"
            else:
                seed = f3_common.stable_seed(
                    SEED_GLOBAL,
                    ESTRATEGIA,
                    stage,
                    prompt_record["fold"],
                    prompt_record["id"],
                    prompt_record["selection_method"],
                    prompt_record["k"],
                )
                try:
                    generation = f3_common.generate_student_output(
                        prompt_record["prompt"],
                        tokenizer,
                        model,
                        max_new_tokens=max_new_tokens,
                        seed=seed,
                    )
                    checkpoint_record = {
                        "execution_id": execution_id,
                        "pipeline_id": prompt_record["pipeline_id"],
                        "stage": stage,
                        "execution_fingerprint": prompt_record["execution_fingerprint"],
                        "fold": int(prompt_record["fold"]),
                        "id": prompt_record["id"],
                        "selection_method": prompt_record["selection_method"],
                        "selection_label": prompt_record["selection_label"],
                        "k": int(prompt_record["k"]),
                        "model_source": str(MODEL_SOURCE),
                        "model_id": MODELO_HF_ID,
                        "generation_seed": int(seed),
                        "prompt_sha256": prompt_record["prompt_sha256"],
                        "prompt_tokens": int(generation["prompt_tokens"]),
                        "generated_tokens": int(generation["generated_tokens"]),
                        "elapsed_seconds": float(generation["elapsed_seconds"]),
                        "finish_reason": generation.get("finish_reason"),
                        "response_raw": generation["response_raw"],
                        "status": "generated",
                        "error": None,
                        "created_at_utc": datetime.now(timezone.utc).isoformat(),
                    }
                    append_jsonl(checkpoint_record, checkpoint_path)
                    compatible[execution_id] = checkpoint_record
                    generated_count += 1
                    status_line = "ok"
                except Exception as exc:
                    error_record = {
                        "execution_id": execution_id,
                        "pipeline_id": prompt_record["pipeline_id"],
                        "stage": stage,
                        "execution_fingerprint": prompt_record["execution_fingerprint"],
                        "fold": int(prompt_record["fold"]),
                        "id": prompt_record["id"],
                        "selection_method": prompt_record["selection_method"],
                        "selection_label": prompt_record["selection_label"],
                        "k": int(prompt_record["k"]),
                        "prompt_sha256": prompt_record["prompt_sha256"],
                        "response_raw": None,
                        "status": "error",
                        "error": f"{exc.__class__.__name__}: {exc}",
                        "traceback": traceback.format_exc(),
                        "created_at_utc": datetime.now(timezone.utc).isoformat(),
                    }
                    append_jsonl(error_record, checkpoint_path)
                    progress.update(1)
                    progress.set_postfix_str(
                        f"novas={generated_count} | reutilizadas={reused_count}"
                    )
                    tqdm.write(
                        format_execution_line(position, total, prompt_record, stage, "erro")
                    )
                    raise RuntimeError(
                        f"A geração falhou em {execution_id}. O checkpoint foi preservado."
                    ) from exc

            progress.update(1)
            progress.set_postfix_str(
                f"novas={generated_count} | reutilizadas={reused_count}"
            )
            tqdm.write(
                format_execution_line(position, total, prompt_record, stage, status_line)
            )

            if position % INTERVALO_SNAPSHOT == 0 or position == total:
                gc.collect()
                if "torch" in sys.modules and torch.cuda.is_available():
                    torch.cuda.empty_cache()
    finally:
        progress.close()

    generation_records = []
    missing = []
    for prompt_record in prompt_records:
        execution_id = prompt_record["execution_id"]
        generation = compatible.get(execution_id)
        if generation is None:
            missing.append(execution_id)
            continue
        if int(prompt_record["prompt_tokens"]) != int(generation["prompt_tokens"]):
            raise ValueError(
                f"Divergência de tokens em {execution_id}: "
                f"{prompt_record['prompt_tokens']} != {generation['prompt_tokens']}."
            )
        generation_records.append(generation)

    if missing:
        raise ValueError("Gerações ausentes: " + ", ".join(missing[:10]))

    write_jsonl_gz(generation_records, output_path)
    summary = {
        "stage": stage,
        "requested": total,
        "generated": generated_count,
        "reused": reused_count,
        "stale_ignored": stale_count,
        "prompt_tokens": int(sum(item["prompt_tokens"] for item in generation_records)),
        "generated_tokens": int(sum(item["generated_tokens"] for item in generation_records)),
        "elapsed_seconds": float(sum(item["elapsed_seconds"] for item in generation_records)),
    }
    return generation_records, summary


# ----------------------------------------------------------
# 6.2 Montagem e auditoria dos prompts NL → IR
# ----------------------------------------------------------

active_plan_records = (
    plan_records[:TOTAL_REGISTROS_TESTE_RAPIDO]
    if MODO_TESTE_RAPIDO
    else list(plan_records)
)

prompt_audit_records = []
prompt_ir_records = []
token_ir_rows = []
for plan in active_plan_records:
    test_record = records_by_id[plan["id"]]
    demos = f3_common.build_demos(
        plan["demonstration_ids"],
        records_by_id,
        "C_IR",
    )
    prompt = f3_common.build_prompt_c_ir(
        template_ir,
        test_record["nl"],
        demos,
        ir_schema,
    )
    prompt_tokens = count_chat_tokens(prompt)
    reserved_tokens = prompt_tokens + MAX_NEW_TOKENS_IR
    context_ok = reserved_tokens <= CONTEXT_LIMIT

    reference_ir_text = canonical_json(test_record["ir"])
    leak_nile = test_record["nile"] in prompt
    leak_ir = reference_ir_text in prompt
    leak_r1 = test_record["r1"] in prompt
    leak_r2 = test_record["r2"] in prompt
    leak_r3 = test_record["r3"] in prompt
    pending = bool(re.search(r"\{\{[A-Z0-9_]+\}\}", prompt))
    if leak_nile or leak_ir or leak_r1 or leak_r2 or leak_r3 or pending or not context_ok:
        raise ValueError(f"Falha de auditoria no prompt IR de {plan['pipeline_id']}.")

    execution_id = plan["pipeline_id"] + "|stage=ir"
    prompt_sha256 = sha256_text(prompt)
    fingerprint = sha256_text(canonical_json({
        "execution_id": execution_id,
        "prompt_sha256": prompt_sha256,
        "model_id": MODELO_HF_ID,
        "max_new_tokens": MAX_NEW_TOKENS_IR,
        "do_sample": DO_SAMPLE,
    }))
    prompt_record = {
        **plan,
        "execution_id": execution_id,
        "stage": "nl_to_ir",
        "prompt": prompt,
        "prompt_sha256": prompt_sha256,
        "prompt_tokens": prompt_tokens,
        "reserved_tokens": reserved_tokens,
        "context_ok": context_ok,
        "execution_fingerprint": fingerprint,
    }
    prompt_ir_records.append(prompt_record)
    token_ir_rows.append({
        "execution_id": execution_id,
        "pipeline_id": plan["pipeline_id"],
        "fold": plan["fold"],
        "id": plan["id"],
        "selection_method": plan["selection_method"],
        "selection_label": plan["selection_label"],
        "k": plan["k"],
        "prompt_tokens": prompt_tokens,
        "max_new_tokens": MAX_NEW_TOKENS_IR,
        "reserved_tokens": reserved_tokens,
        "context_ok": context_ok,
    })
    prompt_audit_records.append({
        "execution_id": execution_id,
        "pipeline_id": plan["pipeline_id"],
        "stage": "nl_to_ir",
        "fold": plan["fold"],
        "id": plan["id"],
        "selection_method": plan["selection_method"],
        "k": plan["k"],
        "pending_placeholders": pending,
        "test_reference_nile_exposed": leak_nile,
        "test_reference_ir_exposed": leak_ir,
        "test_r1_exposed": leak_r1,
        "test_r2_exposed": leak_r2,
        "test_r3_exposed": leak_r3,
        "ir_source": "não aplicável",
        "context_ok": context_ok,
    })

if len(prompt_ir_records) != len(active_plan_records):
    raise ValueError("Quantidade de prompts IR divergente.")

write_jsonl_gz(prompt_ir_records, PROMPTS_IR_PATH)
token_audit_ir_df = pd.DataFrame(token_ir_rows)
token_audit_ir_df.to_csv(TOKEN_AUDIT_IR_PATH, index=False, encoding="utf-8")


# ----------------------------------------------------------
# 6.3 Execução NL → IR
# ----------------------------------------------------------

ir_generation_records, ir_generation_summary = execute_generation_stage(
    prompt_ir_records,
    CHECKPOINT_IR_PATH,
    GENERATIONS_IR_PATH,
    "NL→IR",
    MAX_NEW_TOKENS_IR,
)
ir_generation_by_pipeline = {
    record["pipeline_id"]: record
    for record in ir_generation_records
}


# ----------------------------------------------------------
# 6.4 Extração e validação das IRs geradas
# ----------------------------------------------------------

ir_validation_records = []
for plan in active_plan_records:
    generation = ir_generation_by_pipeline[plan["pipeline_id"]]
    validation = f3_common.validate_generated_ir(
        generation["response_raw"],
        ir_schema,
        ir_core,
    )
    generated_ir = validation["ir"]
    generated_ir_text = validation.get("ir_text") or ""
    if generated_ir is not None:
        ir_for_secondary = canonical_json(generated_ir)
    elif generated_ir_text.strip():
        ir_for_secondary = generated_ir_text.strip()
    else:
        ir_for_secondary = str(generation["response_raw"]).strip()

    ir_validation_records.append({
        "pipeline_id": plan["pipeline_id"],
        "fold": plan["fold"],
        "id": plan["id"],
        "selection_method": plan["selection_method"],
        "selection_label": plan["selection_label"],
        "k": plan["k"],
        "generated_ir": generated_ir,
        "generated_ir_text": generated_ir_text,
        "ir_for_secondary": ir_for_secondary,
        "ir_extracted": generated_ir is not None,
        "ir_valid": bool(validation["ir_valid"]),
        "ir_errors": list(validation.get("ir_errors", [])),
        "response_primary_raw": generation["response_raw"],
        "prompt_primary_tokens": int(generation["prompt_tokens"]),
        "generated_primary_tokens": int(generation["generated_tokens"]),
        "elapsed_primary_seconds": float(generation["elapsed_seconds"]),
    })

ir_validation_df = pd.DataFrame(ir_validation_records)
ir_validation_export = ir_validation_df.copy()
ir_validation_export["generated_ir"] = ir_validation_export["generated_ir"].apply(
    lambda value: canonical_json(value) if isinstance(value, dict) else None
)
ir_validation_export["ir_errors"] = ir_validation_export["ir_errors"].apply(canonical_json)
ir_validation_export.to_csv(IR_VALIDATION_PATH, index=False, encoding="utf-8")

ir_summary_df_block = (
    ir_validation_df.groupby(["selection_method", "selection_label", "k"], dropna=False)
    .agg(
        records=("id", "count"),
        ir_extracted=("ir_extracted", "sum"),
        ir_valid=("ir_valid", "sum"),
    )
    .reset_index()
)
ir_summary_df_block["_ordem_metodo"] = ir_summary_df_block["selection_method"].map(ORDEM_METODOS_MAPA)
ir_summary_df_block = (
    ir_summary_df_block
    .sort_values(["k", "_ordem_metodo"])
    .drop(columns="_ordem_metodo")
    .reset_index(drop=True)
)

exibir_tabela(pd.DataFrame([ir_generation_summary]), "Resumo da geração NL → IR")
exibir_tabela(ir_summary_df_block, "Validade das IRs geradas por método e k")
exibir_tabela(
    ir_validation_export[[
        "pipeline_id",
        "fold",
        "id",
        "selection_label",
        "k",
        "ir_extracted",
        "ir_valid",
        "ir_errors",
    ]].tail(20),
    "Últimas IRs validadas",
    altura_px=420,
)

print("Bloco 6 concluído.")
print(f"Prompts NL → IR: {len(prompt_ir_records)}")
print(f"IRs extraídas: {int(ir_validation_df['ir_extracted'].sum())}")
print(f"IRs válidas: {int(ir_validation_df['ir_valid'].sum())}")
print("Substituições pela IR de referência: 0")
print("Status: OK")
# Out:
# F3-C NL→IR: |                                    |   0.00% | 0/450 | decorrido=00:00 | restante=? |
# [001/450] fold_1 | campi_001 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [002/450] fold_1 | campi_002 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [003/450] fold_1 | campi_011 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [004/450] fold_1 | campi_012 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [005/450] fold_1 | campi_020 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [006/450] fold_1 | campi_023 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [007/450] fold_1 | campi_024 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [008/450] fold_1 | campi_027 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [009/450] fold_1 | campi_039 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [010/450] fold_1 | campi_044 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [011/450] fold_1 | campi_001 | Lexical | k=1 | etapa=NL→IR | status=ok
# [012/450] fold_1 | campi_002 | Lexical | k=1 | etapa=NL→IR | status=ok
# [013/450] fold_1 | campi_011 | Lexical | k=1 | etapa=NL→IR | status=ok
# [014/450] fold_1 | campi_012 | Lexical | k=1 | etapa=NL→IR | status=ok
# [015/450] fold_1 | campi_020 | Lexical | k=1 | etapa=NL→IR | status=ok
# [016/450] fold_1 | campi_023 | Lexical | k=1 | etapa=NL→IR | status=ok
# [017/450] fold_1 | campi_024 | Lexical | k=1 | etapa=NL→IR | status=ok
# [018/450] fold_1 | campi_027 | Lexical | k=1 | etapa=NL→IR | status=ok
# [019/450] fold_1 | campi_039 | Lexical | k=1 | etapa=NL→IR | status=ok
# [020/450] fold_1 | campi_044 | Lexical | k=1 | etapa=NL→IR | status=ok
# [021/450] fold_1 | campi_001 | Semântica | k=1 | etapa=NL→IR | status=ok
# [022/450] fold_1 | campi_002 | Semântica | k=1 | etapa=NL→IR | status=ok
# [023/450] fold_1 | campi_011 | Semântica | k=1 | etapa=NL→IR | status=ok
# [024/450] fold_1 | campi_012 | Semântica | k=1 | etapa=NL→IR | status=ok
# [025/450] fold_1 | campi_020 | Semântica | k=1 | etapa=NL→IR | status=ok
# [026/450] fold_1 | campi_023 | Semântica | k=1 | etapa=NL→IR | status=ok
# [027/450] fold_1 | campi_024 | Semântica | k=1 | etapa=NL→IR | status=ok
# [028/450] fold_1 | campi_027 | Semântica | k=1 | etapa=NL→IR | status=ok
# [029/450] fold_1 | campi_039 | Semântica | k=1 | etapa=NL→IR | status=ok
# [030/450] fold_1 | campi_044 | Semântica | k=1 | etapa=NL→IR | status=ok
# [031/450] fold_1 | campi_001 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [032/450] fold_1 | campi_002 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [033/450] fold_1 | campi_011 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [034/450] fold_1 | campi_012 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [035/450] fold_1 | campi_020 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [036/450] fold_1 | campi_023 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [037/450] fold_1 | campi_024 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [038/450] fold_1 | campi_027 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [039/450] fold_1 | campi_039 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [040/450] fold_1 | campi_044 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [041/450] fold_1 | campi_001 | Lexical | k=3 | etapa=NL→IR | status=ok
# [042/450] fold_1 | campi_002 | Lexical | k=3 | etapa=NL→IR | status=ok
# [043/450] fold_1 | campi_011 | Lexical | k=3 | etapa=NL→IR | status=ok
# [044/450] fold_1 | campi_012 | Lexical | k=3 | etapa=NL→IR | status=ok
# [045/450] fold_1 | campi_020 | Lexical | k=3 | etapa=NL→IR | status=ok
# [046/450] fold_1 | campi_023 | Lexical | k=3 | etapa=NL→IR | status=ok
# [047/450] fold_1 | campi_024 | Lexical | k=3 | etapa=NL→IR | status=ok
# [048/450] fold_1 | campi_027 | Lexical | k=3 | etapa=NL→IR | status=ok
# [049/450] fold_1 | campi_039 | Lexical | k=3 | etapa=NL→IR | status=ok
# [050/450] fold_1 | campi_044 | Lexical | k=3 | etapa=NL→IR | status=ok
# [051/450] fold_1 | campi_001 | Semântica | k=3 | etapa=NL→IR | status=ok
# [052/450] fold_1 | campi_002 | Semântica | k=3 | etapa=NL→IR | status=ok
# [053/450] fold_1 | campi_011 | Semântica | k=3 | etapa=NL→IR | status=ok
# [054/450] fold_1 | campi_012 | Semântica | k=3 | etapa=NL→IR | status=ok
# [055/450] fold_1 | campi_020 | Semântica | k=3 | etapa=NL→IR | status=ok
# [056/450] fold_1 | campi_023 | Semântica | k=3 | etapa=NL→IR | status=ok
# [057/450] fold_1 | campi_024 | Semântica | k=3 | etapa=NL→IR | status=ok
# [058/450] fold_1 | campi_027 | Semântica | k=3 | etapa=NL→IR | status=ok
# [059/450] fold_1 | campi_039 | Semântica | k=3 | etapa=NL→IR | status=ok
# [060/450] fold_1 | campi_044 | Semântica | k=3 | etapa=NL→IR | status=ok
# [061/450] fold_1 | campi_001 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [062/450] fold_1 | campi_002 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [063/450] fold_1 | campi_011 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [064/450] fold_1 | campi_012 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [065/450] fold_1 | campi_020 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [066/450] fold_1 | campi_023 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [067/450] fold_1 | campi_024 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [068/450] fold_1 | campi_027 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [069/450] fold_1 | campi_039 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [070/450] fold_1 | campi_044 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [071/450] fold_1 | campi_001 | Lexical | k=5 | etapa=NL→IR | status=ok
# [072/450] fold_1 | campi_002 | Lexical | k=5 | etapa=NL→IR | status=ok
# [073/450] fold_1 | campi_011 | Lexical | k=5 | etapa=NL→IR | status=ok
# [074/450] fold_1 | campi_012 | Lexical | k=5 | etapa=NL→IR | status=ok
# [075/450] fold_1 | campi_020 | Lexical | k=5 | etapa=NL→IR | status=ok
# [076/450] fold_1 | campi_023 | Lexical | k=5 | etapa=NL→IR | status=ok
# [077/450] fold_1 | campi_024 | Lexical | k=5 | etapa=NL→IR | status=ok
# [078/450] fold_1 | campi_027 | Lexical | k=5 | etapa=NL→IR | status=ok
# [079/450] fold_1 | campi_039 | Lexical | k=5 | etapa=NL→IR | status=ok
# [080/450] fold_1 | campi_044 | Lexical | k=5 | etapa=NL→IR | status=ok
# [081/450] fold_1 | campi_001 | Semântica | k=5 | etapa=NL→IR | status=ok
# [082/450] fold_1 | campi_002 | Semântica | k=5 | etapa=NL→IR | status=ok
# [083/450] fold_1 | campi_011 | Semântica | k=5 | etapa=NL→IR | status=ok
# [084/450] fold_1 | campi_012 | Semântica | k=5 | etapa=NL→IR | status=ok
# [085/450] fold_1 | campi_020 | Semântica | k=5 | etapa=NL→IR | status=ok
# [086/450] fold_1 | campi_023 | Semântica | k=5 | etapa=NL→IR | status=ok
# [087/450] fold_1 | campi_024 | Semântica | k=5 | etapa=NL→IR | status=ok
# [088/450] fold_1 | campi_027 | Semântica | k=5 | etapa=NL→IR | status=ok
# [089/450] fold_1 | campi_039 | Semântica | k=5 | etapa=NL→IR | status=ok
# [090/450] fold_1 | campi_044 | Semântica | k=5 | etapa=NL→IR | status=ok
# [091/450] fold_2 | campi_006 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [092/450] fold_2 | campi_009 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [093/450] fold_2 | campi_010 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [094/450] fold_2 | campi_017 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [095/450] fold_2 | campi_028 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [096/450] fold_2 | campi_031 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [097/450] fold_2 | campi_034 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [098/450] fold_2 | campi_041 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [099/450] fold_2 | campi_043 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [100/450] fold_2 | campi_048 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [101/450] fold_2 | campi_006 | Lexical | k=1 | etapa=NL→IR | status=ok
# [102/450] fold_2 | campi_009 | Lexical | k=1 | etapa=NL→IR | status=ok
# [103/450] fold_2 | campi_010 | Lexical | k=1 | etapa=NL→IR | status=ok
# [104/450] fold_2 | campi_017 | Lexical | k=1 | etapa=NL→IR | status=ok
# [105/450] fold_2 | campi_028 | Lexical | k=1 | etapa=NL→IR | status=ok
# [106/450] fold_2 | campi_031 | Lexical | k=1 | etapa=NL→IR | status=ok
# [107/450] fold_2 | campi_034 | Lexical | k=1 | etapa=NL→IR | status=ok
# [108/450] fold_2 | campi_041 | Lexical | k=1 | etapa=NL→IR | status=ok
# [109/450] fold_2 | campi_043 | Lexical | k=1 | etapa=NL→IR | status=ok
# [110/450] fold_2 | campi_048 | Lexical | k=1 | etapa=NL→IR | status=ok
# [111/450] fold_2 | campi_006 | Semântica | k=1 | etapa=NL→IR | status=ok
# [112/450] fold_2 | campi_009 | Semântica | k=1 | etapa=NL→IR | status=ok
# [113/450] fold_2 | campi_010 | Semântica | k=1 | etapa=NL→IR | status=ok
# [114/450] fold_2 | campi_017 | Semântica | k=1 | etapa=NL→IR | status=ok
# [115/450] fold_2 | campi_028 | Semântica | k=1 | etapa=NL→IR | status=ok
# [116/450] fold_2 | campi_031 | Semântica | k=1 | etapa=NL→IR | status=ok
# [117/450] fold_2 | campi_034 | Semântica | k=1 | etapa=NL→IR | status=ok
# [118/450] fold_2 | campi_041 | Semântica | k=1 | etapa=NL→IR | status=ok
# [119/450] fold_2 | campi_043 | Semântica | k=1 | etapa=NL→IR | status=ok
# [120/450] fold_2 | campi_048 | Semântica | k=1 | etapa=NL→IR | status=ok
# [121/450] fold_2 | campi_006 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [122/450] fold_2 | campi_009 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [123/450] fold_2 | campi_010 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [124/450] fold_2 | campi_017 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [125/450] fold_2 | campi_028 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [126/450] fold_2 | campi_031 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [127/450] fold_2 | campi_034 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [128/450] fold_2 | campi_041 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [129/450] fold_2 | campi_043 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [130/450] fold_2 | campi_048 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [131/450] fold_2 | campi_006 | Lexical | k=3 | etapa=NL→IR | status=ok
# [132/450] fold_2 | campi_009 | Lexical | k=3 | etapa=NL→IR | status=ok
# [133/450] fold_2 | campi_010 | Lexical | k=3 | etapa=NL→IR | status=ok
# [134/450] fold_2 | campi_017 | Lexical | k=3 | etapa=NL→IR | status=ok
# [135/450] fold_2 | campi_028 | Lexical | k=3 | etapa=NL→IR | status=ok
# [136/450] fold_2 | campi_031 | Lexical | k=3 | etapa=NL→IR | status=ok
# [137/450] fold_2 | campi_034 | Lexical | k=3 | etapa=NL→IR | status=ok
# [138/450] fold_2 | campi_041 | Lexical | k=3 | etapa=NL→IR | status=ok
# [139/450] fold_2 | campi_043 | Lexical | k=3 | etapa=NL→IR | status=ok
# [140/450] fold_2 | campi_048 | Lexical | k=3 | etapa=NL→IR | status=ok
# [141/450] fold_2 | campi_006 | Semântica | k=3 | etapa=NL→IR | status=ok
# [142/450] fold_2 | campi_009 | Semântica | k=3 | etapa=NL→IR | status=ok
# [143/450] fold_2 | campi_010 | Semântica | k=3 | etapa=NL→IR | status=ok
# [144/450] fold_2 | campi_017 | Semântica | k=3 | etapa=NL→IR | status=ok
# [145/450] fold_2 | campi_028 | Semântica | k=3 | etapa=NL→IR | status=ok
# [146/450] fold_2 | campi_031 | Semântica | k=3 | etapa=NL→IR | status=ok
# [147/450] fold_2 | campi_034 | Semântica | k=3 | etapa=NL→IR | status=ok
# [148/450] fold_2 | campi_041 | Semântica | k=3 | etapa=NL→IR | status=ok
# [149/450] fold_2 | campi_043 | Semântica | k=3 | etapa=NL→IR | status=ok
# [150/450] fold_2 | campi_048 | Semântica | k=3 | etapa=NL→IR | status=ok
# [151/450] fold_2 | campi_006 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [152/450] fold_2 | campi_009 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [153/450] fold_2 | campi_010 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [154/450] fold_2 | campi_017 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [155/450] fold_2 | campi_028 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [156/450] fold_2 | campi_031 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [157/450] fold_2 | campi_034 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [158/450] fold_2 | campi_041 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [159/450] fold_2 | campi_043 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [160/450] fold_2 | campi_048 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [161/450] fold_2 | campi_006 | Lexical | k=5 | etapa=NL→IR | status=ok
# [162/450] fold_2 | campi_009 | Lexical | k=5 | etapa=NL→IR | status=ok
# [163/450] fold_2 | campi_010 | Lexical | k=5 | etapa=NL→IR | status=ok
# [164/450] fold_2 | campi_017 | Lexical | k=5 | etapa=NL→IR | status=ok
# [165/450] fold_2 | campi_028 | Lexical | k=5 | etapa=NL→IR | status=ok
# [166/450] fold_2 | campi_031 | Lexical | k=5 | etapa=NL→IR | status=ok
# [167/450] fold_2 | campi_034 | Lexical | k=5 | etapa=NL→IR | status=ok
# [168/450] fold_2 | campi_041 | Lexical | k=5 | etapa=NL→IR | status=ok
# [169/450] fold_2 | campi_043 | Lexical | k=5 | etapa=NL→IR | status=ok
# [170/450] fold_2 | campi_048 | Lexical | k=5 | etapa=NL→IR | status=ok
# [171/450] fold_2 | campi_006 | Semântica | k=5 | etapa=NL→IR | status=ok
# [172/450] fold_2 | campi_009 | Semântica | k=5 | etapa=NL→IR | status=ok
# [173/450] fold_2 | campi_010 | Semântica | k=5 | etapa=NL→IR | status=ok
# [174/450] fold_2 | campi_017 | Semântica | k=5 | etapa=NL→IR | status=ok
# [175/450] fold_2 | campi_028 | Semântica | k=5 | etapa=NL→IR | status=ok
# [176/450] fold_2 | campi_031 | Semântica | k=5 | etapa=NL→IR | status=ok
# [177/450] fold_2 | campi_034 | Semântica | k=5 | etapa=NL→IR | status=ok
# [178/450] fold_2 | campi_041 | Semântica | k=5 | etapa=NL→IR | status=ok
# [179/450] fold_2 | campi_043 | Semântica | k=5 | etapa=NL→IR | status=ok
# [180/450] fold_2 | campi_048 | Semântica | k=5 | etapa=NL→IR | status=ok
# [181/450] fold_3 | campi_003 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [182/450] fold_3 | campi_007 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [183/450] fold_3 | campi_014 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [184/450] fold_3 | campi_018 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [185/450] fold_3 | campi_025 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [186/450] fold_3 | campi_026 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [187/450] fold_3 | campi_033 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [188/450] fold_3 | campi_035 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [189/450] fold_3 | campi_045 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [190/450] fold_3 | campi_047 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [191/450] fold_3 | campi_003 | Lexical | k=1 | etapa=NL→IR | status=ok
# [192/450] fold_3 | campi_007 | Lexical | k=1 | etapa=NL→IR | status=ok
# [193/450] fold_3 | campi_014 | Lexical | k=1 | etapa=NL→IR | status=ok
# [194/450] fold_3 | campi_018 | Lexical | k=1 | etapa=NL→IR | status=ok
# [195/450] fold_3 | campi_025 | Lexical | k=1 | etapa=NL→IR | status=ok
# [196/450] fold_3 | campi_026 | Lexical | k=1 | etapa=NL→IR | status=ok
# [197/450] fold_3 | campi_033 | Lexical | k=1 | etapa=NL→IR | status=ok
# [198/450] fold_3 | campi_035 | Lexical | k=1 | etapa=NL→IR | status=ok
# [199/450] fold_3 | campi_045 | Lexical | k=1 | etapa=NL→IR | status=ok
# [200/450] fold_3 | campi_047 | Lexical | k=1 | etapa=NL→IR | status=ok
# [201/450] fold_3 | campi_003 | Semântica | k=1 | etapa=NL→IR | status=ok
# [202/450] fold_3 | campi_007 | Semântica | k=1 | etapa=NL→IR | status=ok
# [203/450] fold_3 | campi_014 | Semântica | k=1 | etapa=NL→IR | status=ok
# [204/450] fold_3 | campi_018 | Semântica | k=1 | etapa=NL→IR | status=ok
# [205/450] fold_3 | campi_025 | Semântica | k=1 | etapa=NL→IR | status=ok
# [206/450] fold_3 | campi_026 | Semântica | k=1 | etapa=NL→IR | status=ok
# [207/450] fold_3 | campi_033 | Semântica | k=1 | etapa=NL→IR | status=ok
# [208/450] fold_3 | campi_035 | Semântica | k=1 | etapa=NL→IR | status=ok
# [209/450] fold_3 | campi_045 | Semântica | k=1 | etapa=NL→IR | status=ok
# [210/450] fold_3 | campi_047 | Semântica | k=1 | etapa=NL→IR | status=ok
# [211/450] fold_3 | campi_003 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [212/450] fold_3 | campi_007 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [213/450] fold_3 | campi_014 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [214/450] fold_3 | campi_018 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [215/450] fold_3 | campi_025 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [216/450] fold_3 | campi_026 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [217/450] fold_3 | campi_033 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [218/450] fold_3 | campi_035 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [219/450] fold_3 | campi_045 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [220/450] fold_3 | campi_047 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [221/450] fold_3 | campi_003 | Lexical | k=3 | etapa=NL→IR | status=ok
# [222/450] fold_3 | campi_007 | Lexical | k=3 | etapa=NL→IR | status=ok
# [223/450] fold_3 | campi_014 | Lexical | k=3 | etapa=NL→IR | status=ok
# [224/450] fold_3 | campi_018 | Lexical | k=3 | etapa=NL→IR | status=ok
# [225/450] fold_3 | campi_025 | Lexical | k=3 | etapa=NL→IR | status=ok
# [226/450] fold_3 | campi_026 | Lexical | k=3 | etapa=NL→IR | status=ok
# [227/450] fold_3 | campi_033 | Lexical | k=3 | etapa=NL→IR | status=ok
# [228/450] fold_3 | campi_035 | Lexical | k=3 | etapa=NL→IR | status=ok
# [229/450] fold_3 | campi_045 | Lexical | k=3 | etapa=NL→IR | status=ok
# [230/450] fold_3 | campi_047 | Lexical | k=3 | etapa=NL→IR | status=ok
# [231/450] fold_3 | campi_003 | Semântica | k=3 | etapa=NL→IR | status=ok
# [232/450] fold_3 | campi_007 | Semântica | k=3 | etapa=NL→IR | status=ok
# [233/450] fold_3 | campi_014 | Semântica | k=3 | etapa=NL→IR | status=ok
# [234/450] fold_3 | campi_018 | Semântica | k=3 | etapa=NL→IR | status=ok
# [235/450] fold_3 | campi_025 | Semântica | k=3 | etapa=NL→IR | status=ok
# [236/450] fold_3 | campi_026 | Semântica | k=3 | etapa=NL→IR | status=ok
# [237/450] fold_3 | campi_033 | Semântica | k=3 | etapa=NL→IR | status=ok
# [238/450] fold_3 | campi_035 | Semântica | k=3 | etapa=NL→IR | status=ok
# [239/450] fold_3 | campi_045 | Semântica | k=3 | etapa=NL→IR | status=ok
# [240/450] fold_3 | campi_047 | Semântica | k=3 | etapa=NL→IR | status=ok
# [241/450] fold_3 | campi_003 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [242/450] fold_3 | campi_007 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [243/450] fold_3 | campi_014 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [244/450] fold_3 | campi_018 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [245/450] fold_3 | campi_025 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [246/450] fold_3 | campi_026 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [247/450] fold_3 | campi_033 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [248/450] fold_3 | campi_035 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [249/450] fold_3 | campi_045 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [250/450] fold_3 | campi_047 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [251/450] fold_3 | campi_003 | Lexical | k=5 | etapa=NL→IR | status=ok
# [252/450] fold_3 | campi_007 | Lexical | k=5 | etapa=NL→IR | status=ok
# [253/450] fold_3 | campi_014 | Lexical | k=5 | etapa=NL→IR | status=ok
# [254/450] fold_3 | campi_018 | Lexical | k=5 | etapa=NL→IR | status=ok
# [255/450] fold_3 | campi_025 | Lexical | k=5 | etapa=NL→IR | status=ok
# [256/450] fold_3 | campi_026 | Lexical | k=5 | etapa=NL→IR | status=ok
# [257/450] fold_3 | campi_033 | Lexical | k=5 | etapa=NL→IR | status=ok
# [258/450] fold_3 | campi_035 | Lexical | k=5 | etapa=NL→IR | status=ok
# [259/450] fold_3 | campi_045 | Lexical | k=5 | etapa=NL→IR | status=ok
# [260/450] fold_3 | campi_047 | Lexical | k=5 | etapa=NL→IR | status=ok
# [261/450] fold_3 | campi_003 | Semântica | k=5 | etapa=NL→IR | status=ok
# [262/450] fold_3 | campi_007 | Semântica | k=5 | etapa=NL→IR | status=ok
# [263/450] fold_3 | campi_014 | Semântica | k=5 | etapa=NL→IR | status=ok
# [264/450] fold_3 | campi_018 | Semântica | k=5 | etapa=NL→IR | status=ok
# [265/450] fold_3 | campi_025 | Semântica | k=5 | etapa=NL→IR | status=ok
# [266/450] fold_3 | campi_026 | Semântica | k=5 | etapa=NL→IR | status=ok
# [267/450] fold_3 | campi_033 | Semântica | k=5 | etapa=NL→IR | status=ok
# [268/450] fold_3 | campi_035 | Semântica | k=5 | etapa=NL→IR | status=ok
# [269/450] fold_3 | campi_045 | Semântica | k=5 | etapa=NL→IR | status=ok
# [270/450] fold_3 | campi_047 | Semântica | k=5 | etapa=NL→IR | status=ok
# [271/450] fold_4 | campi_005 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [272/450] fold_4 | campi_016 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [273/450] fold_4 | campi_019 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [274/450] fold_4 | campi_021 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [275/450] fold_4 | campi_032 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [276/450] fold_4 | campi_036 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [277/450] fold_4 | campi_037 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [278/450] fold_4 | campi_040 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [279/450] fold_4 | campi_046 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [280/450] fold_4 | campi_050 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [281/450] fold_4 | campi_005 | Lexical | k=1 | etapa=NL→IR | status=ok
# [282/450] fold_4 | campi_016 | Lexical | k=1 | etapa=NL→IR | status=ok
# [283/450] fold_4 | campi_019 | Lexical | k=1 | etapa=NL→IR | status=ok
# [284/450] fold_4 | campi_021 | Lexical | k=1 | etapa=NL→IR | status=ok
# [285/450] fold_4 | campi_032 | Lexical | k=1 | etapa=NL→IR | status=ok
# [286/450] fold_4 | campi_036 | Lexical | k=1 | etapa=NL→IR | status=ok
# [287/450] fold_4 | campi_037 | Lexical | k=1 | etapa=NL→IR | status=ok
# [288/450] fold_4 | campi_040 | Lexical | k=1 | etapa=NL→IR | status=ok
# [289/450] fold_4 | campi_046 | Lexical | k=1 | etapa=NL→IR | status=ok
# [290/450] fold_4 | campi_050 | Lexical | k=1 | etapa=NL→IR | status=ok
# [291/450] fold_4 | campi_005 | Semântica | k=1 | etapa=NL→IR | status=ok
# [292/450] fold_4 | campi_016 | Semântica | k=1 | etapa=NL→IR | status=ok
# [293/450] fold_4 | campi_019 | Semântica | k=1 | etapa=NL→IR | status=ok
# [294/450] fold_4 | campi_021 | Semântica | k=1 | etapa=NL→IR | status=ok
# [295/450] fold_4 | campi_032 | Semântica | k=1 | etapa=NL→IR | status=ok
# [296/450] fold_4 | campi_036 | Semântica | k=1 | etapa=NL→IR | status=ok
# [297/450] fold_4 | campi_037 | Semântica | k=1 | etapa=NL→IR | status=ok
# [298/450] fold_4 | campi_040 | Semântica | k=1 | etapa=NL→IR | status=ok
# [299/450] fold_4 | campi_046 | Semântica | k=1 | etapa=NL→IR | status=ok
# [300/450] fold_4 | campi_050 | Semântica | k=1 | etapa=NL→IR | status=ok
# [301/450] fold_4 | campi_005 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [302/450] fold_4 | campi_016 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [303/450] fold_4 | campi_019 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [304/450] fold_4 | campi_021 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [305/450] fold_4 | campi_032 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [306/450] fold_4 | campi_036 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [307/450] fold_4 | campi_037 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [308/450] fold_4 | campi_040 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [309/450] fold_4 | campi_046 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [310/450] fold_4 | campi_050 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [311/450] fold_4 | campi_005 | Lexical | k=3 | etapa=NL→IR | status=ok
# [312/450] fold_4 | campi_016 | Lexical | k=3 | etapa=NL→IR | status=ok
# [313/450] fold_4 | campi_019 | Lexical | k=3 | etapa=NL→IR | status=ok
# [314/450] fold_4 | campi_021 | Lexical | k=3 | etapa=NL→IR | status=ok
# [315/450] fold_4 | campi_032 | Lexical | k=3 | etapa=NL→IR | status=ok
# [316/450] fold_4 | campi_036 | Lexical | k=3 | etapa=NL→IR | status=ok
# [317/450] fold_4 | campi_037 | Lexical | k=3 | etapa=NL→IR | status=ok
# [318/450] fold_4 | campi_040 | Lexical | k=3 | etapa=NL→IR | status=ok
# [319/450] fold_4 | campi_046 | Lexical | k=3 | etapa=NL→IR | status=ok
# [320/450] fold_4 | campi_050 | Lexical | k=3 | etapa=NL→IR | status=ok
# [321/450] fold_4 | campi_005 | Semântica | k=3 | etapa=NL→IR | status=ok
# [322/450] fold_4 | campi_016 | Semântica | k=3 | etapa=NL→IR | status=ok
# [323/450] fold_4 | campi_019 | Semântica | k=3 | etapa=NL→IR | status=ok
# [324/450] fold_4 | campi_021 | Semântica | k=3 | etapa=NL→IR | status=ok
# [325/450] fold_4 | campi_032 | Semântica | k=3 | etapa=NL→IR | status=ok
# [326/450] fold_4 | campi_036 | Semântica | k=3 | etapa=NL→IR | status=ok
# [327/450] fold_4 | campi_037 | Semântica | k=3 | etapa=NL→IR | status=ok
# [328/450] fold_4 | campi_040 | Semântica | k=3 | etapa=NL→IR | status=ok
# [329/450] fold_4 | campi_046 | Semântica | k=3 | etapa=NL→IR | status=ok
# [330/450] fold_4 | campi_050 | Semântica | k=3 | etapa=NL→IR | status=ok
# [331/450] fold_4 | campi_005 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [332/450] fold_4 | campi_016 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [333/450] fold_4 | campi_019 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [334/450] fold_4 | campi_021 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [335/450] fold_4 | campi_032 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [336/450] fold_4 | campi_036 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [337/450] fold_4 | campi_037 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [338/450] fold_4 | campi_040 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [339/450] fold_4 | campi_046 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [340/450] fold_4 | campi_050 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [341/450] fold_4 | campi_005 | Lexical | k=5 | etapa=NL→IR | status=ok
# [342/450] fold_4 | campi_016 | Lexical | k=5 | etapa=NL→IR | status=ok
# [343/450] fold_4 | campi_019 | Lexical | k=5 | etapa=NL→IR | status=ok
# [344/450] fold_4 | campi_021 | Lexical | k=5 | etapa=NL→IR | status=ok
# [345/450] fold_4 | campi_032 | Lexical | k=5 | etapa=NL→IR | status=ok
# [346/450] fold_4 | campi_036 | Lexical | k=5 | etapa=NL→IR | status=ok
# [347/450] fold_4 | campi_037 | Lexical | k=5 | etapa=NL→IR | status=ok
# [348/450] fold_4 | campi_040 | Lexical | k=5 | etapa=NL→IR | status=ok
# [349/450] fold_4 | campi_046 | Lexical | k=5 | etapa=NL→IR | status=ok
# [350/450] fold_4 | campi_050 | Lexical | k=5 | etapa=NL→IR | status=ok
# [351/450] fold_4 | campi_005 | Semântica | k=5 | etapa=NL→IR | status=ok
# [352/450] fold_4 | campi_016 | Semântica | k=5 | etapa=NL→IR | status=ok
# [353/450] fold_4 | campi_019 | Semântica | k=5 | etapa=NL→IR | status=ok
# [354/450] fold_4 | campi_021 | Semântica | k=5 | etapa=NL→IR | status=ok
# [355/450] fold_4 | campi_032 | Semântica | k=5 | etapa=NL→IR | status=ok
# [356/450] fold_4 | campi_036 | Semântica | k=5 | etapa=NL→IR | status=ok
# [357/450] fold_4 | campi_037 | Semântica | k=5 | etapa=NL→IR | status=ok
# [358/450] fold_4 | campi_040 | Semântica | k=5 | etapa=NL→IR | status=ok
# [359/450] fold_4 | campi_046 | Semântica | k=5 | etapa=NL→IR | status=ok
# [360/450] fold_4 | campi_050 | Semântica | k=5 | etapa=NL→IR | status=ok
# [361/450] fold_5 | campi_004 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [362/450] fold_5 | campi_008 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [363/450] fold_5 | campi_013 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [364/450] fold_5 | campi_015 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [365/450] fold_5 | campi_022 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [366/450] fold_5 | campi_029 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [367/450] fold_5 | campi_030 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [368/450] fold_5 | campi_038 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [369/450] fold_5 | campi_042 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [370/450] fold_5 | campi_049 | Aleatória | k=1 | etapa=NL→IR | status=ok
# [371/450] fold_5 | campi_004 | Lexical | k=1 | etapa=NL→IR | status=ok
# [372/450] fold_5 | campi_008 | Lexical | k=1 | etapa=NL→IR | status=ok
# [373/450] fold_5 | campi_013 | Lexical | k=1 | etapa=NL→IR | status=ok
# [374/450] fold_5 | campi_015 | Lexical | k=1 | etapa=NL→IR | status=ok
# [375/450] fold_5 | campi_022 | Lexical | k=1 | etapa=NL→IR | status=ok
# [376/450] fold_5 | campi_029 | Lexical | k=1 | etapa=NL→IR | status=ok
# [377/450] fold_5 | campi_030 | Lexical | k=1 | etapa=NL→IR | status=ok
# [378/450] fold_5 | campi_038 | Lexical | k=1 | etapa=NL→IR | status=ok
# [379/450] fold_5 | campi_042 | Lexical | k=1 | etapa=NL→IR | status=ok
# [380/450] fold_5 | campi_049 | Lexical | k=1 | etapa=NL→IR | status=ok
# [381/450] fold_5 | campi_004 | Semântica | k=1 | etapa=NL→IR | status=ok
# [382/450] fold_5 | campi_008 | Semântica | k=1 | etapa=NL→IR | status=ok
# [383/450] fold_5 | campi_013 | Semântica | k=1 | etapa=NL→IR | status=ok
# [384/450] fold_5 | campi_015 | Semântica | k=1 | etapa=NL→IR | status=ok
# [385/450] fold_5 | campi_022 | Semântica | k=1 | etapa=NL→IR | status=ok
# [386/450] fold_5 | campi_029 | Semântica | k=1 | etapa=NL→IR | status=ok
# [387/450] fold_5 | campi_030 | Semântica | k=1 | etapa=NL→IR | status=ok
# [388/450] fold_5 | campi_038 | Semântica | k=1 | etapa=NL→IR | status=ok
# [389/450] fold_5 | campi_042 | Semântica | k=1 | etapa=NL→IR | status=ok
# [390/450] fold_5 | campi_049 | Semântica | k=1 | etapa=NL→IR | status=ok
# [391/450] fold_5 | campi_004 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [392/450] fold_5 | campi_008 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [393/450] fold_5 | campi_013 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [394/450] fold_5 | campi_015 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [395/450] fold_5 | campi_022 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [396/450] fold_5 | campi_029 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [397/450] fold_5 | campi_030 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [398/450] fold_5 | campi_038 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [399/450] fold_5 | campi_042 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [400/450] fold_5 | campi_049 | Aleatória | k=3 | etapa=NL→IR | status=ok
# [401/450] fold_5 | campi_004 | Lexical | k=3 | etapa=NL→IR | status=ok
# [402/450] fold_5 | campi_008 | Lexical | k=3 | etapa=NL→IR | status=ok
# [403/450] fold_5 | campi_013 | Lexical | k=3 | etapa=NL→IR | status=ok
# [404/450] fold_5 | campi_015 | Lexical | k=3 | etapa=NL→IR | status=ok
# [405/450] fold_5 | campi_022 | Lexical | k=3 | etapa=NL→IR | status=ok
# [406/450] fold_5 | campi_029 | Lexical | k=3 | etapa=NL→IR | status=ok
# [407/450] fold_5 | campi_030 | Lexical | k=3 | etapa=NL→IR | status=ok
# [408/450] fold_5 | campi_038 | Lexical | k=3 | etapa=NL→IR | status=ok
# [409/450] fold_5 | campi_042 | Lexical | k=3 | etapa=NL→IR | status=ok
# [410/450] fold_5 | campi_049 | Lexical | k=3 | etapa=NL→IR | status=ok
# [411/450] fold_5 | campi_004 | Semântica | k=3 | etapa=NL→IR | status=ok
# [412/450] fold_5 | campi_008 | Semântica | k=3 | etapa=NL→IR | status=ok
# [413/450] fold_5 | campi_013 | Semântica | k=3 | etapa=NL→IR | status=ok
# [414/450] fold_5 | campi_015 | Semântica | k=3 | etapa=NL→IR | status=ok
# [415/450] fold_5 | campi_022 | Semântica | k=3 | etapa=NL→IR | status=ok
# [416/450] fold_5 | campi_029 | Semântica | k=3 | etapa=NL→IR | status=ok
# [417/450] fold_5 | campi_030 | Semântica | k=3 | etapa=NL→IR | status=ok
# [418/450] fold_5 | campi_038 | Semântica | k=3 | etapa=NL→IR | status=ok
# [419/450] fold_5 | campi_042 | Semântica | k=3 | etapa=NL→IR | status=ok
# [420/450] fold_5 | campi_049 | Semântica | k=3 | etapa=NL→IR | status=ok
# [421/450] fold_5 | campi_004 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [422/450] fold_5 | campi_008 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [423/450] fold_5 | campi_013 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [424/450] fold_5 | campi_015 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [425/450] fold_5 | campi_022 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [426/450] fold_5 | campi_029 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [427/450] fold_5 | campi_030 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [428/450] fold_5 | campi_038 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [429/450] fold_5 | campi_042 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [430/450] fold_5 | campi_049 | Aleatória | k=5 | etapa=NL→IR | status=ok
# [431/450] fold_5 | campi_004 | Lexical | k=5 | etapa=NL→IR | status=ok
# [432/450] fold_5 | campi_008 | Lexical | k=5 | etapa=NL→IR | status=ok
# [433/450] fold_5 | campi_013 | Lexical | k=5 | etapa=NL→IR | status=ok
# [434/450] fold_5 | campi_015 | Lexical | k=5 | etapa=NL→IR | status=ok
# [435/450] fold_5 | campi_022 | Lexical | k=5 | etapa=NL→IR | status=ok
# [436/450] fold_5 | campi_029 | Lexical | k=5 | etapa=NL→IR | status=ok
# [437/450] fold_5 | campi_030 | Lexical | k=5 | etapa=NL→IR | status=ok
# [438/450] fold_5 | campi_038 | Lexical | k=5 | etapa=NL→IR | status=ok
# [439/450] fold_5 | campi_042 | Lexical | k=5 | etapa=NL→IR | status=ok
# [440/450] fold_5 | campi_049 | Lexical | k=5 | etapa=NL→IR | status=ok
# [441/450] fold_5 | campi_004 | Semântica | k=5 | etapa=NL→IR | status=ok
# [442/450] fold_5 | campi_008 | Semântica | k=5 | etapa=NL→IR | status=ok
# [443/450] fold_5 | campi_013 | Semântica | k=5 | etapa=NL→IR | status=ok
# [444/450] fold_5 | campi_015 | Semântica | k=5 | etapa=NL→IR | status=ok
# [445/450] fold_5 | campi_022 | Semântica | k=5 | etapa=NL→IR | status=ok
# [446/450] fold_5 | campi_029 | Semântica | k=5 | etapa=NL→IR | status=ok
# [447/450] fold_5 | campi_030 | Semântica | k=5 | etapa=NL→IR | status=ok
# [448/450] fold_5 | campi_038 | Semântica | k=5 | etapa=NL→IR | status=ok
# [449/450] fold_5 | campi_042 | Semântica | k=5 | etapa=NL→IR | status=ok
# [450/450] fold_5 | campi_049 | Semântica | k=5 | etapa=NL→IR | status=ok
#     <div style="font-weight:600;font-size:15px;margin:8px 0 6px;color:#f1f1f1;">
#         Tabela 9. Resumo da geração NL → IR
#     </div>
#     <div class="container_tabela_saida" style="display:inline-block;max-width:100%;overflow-x:auto;overflow-y: visible;border:none;margin:8px 0 12px;">
#         <style>
#             .container_tabela_saida table.tabela_saida {
#                 border-collapse:collapse !important;
#                 table-layout:auto !important;
#                 width:auto !important;
#                 font-family:Arial,sans-serif !important;
#                 font-size:13px !important;
#                 background:#111 !important;
#                 color:#f1f1f1 !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida thead th {
#                 position:sticky !important;
#                 top:0 !important;
#                 z-index:2 !important;
#                 background:#2b2b2b !important;
#                 color:#fff !important;
#                 padding:7px !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #777 !important;
#                 border-bottom:2px solid #888 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody td {
#                 padding:7px !important;
#                 vertical-align:top !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(even) td {background:#1b1b1b !important;}
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(odd) td {background:#111 !important;}
#         </style>
#         <table class="dataframe tabela_saida">
#   <thead>
#     <tr style="text-align: left;">
#       <th>etapa</th>
#       <th>requested</th>
#       <th>generated</th>
#       <th>reused</th>
#       <th>stale ignored</th>
#       <th>tokens do prompt</th>
#       <th>tokens gerados</th>
#       <th>tempo decorrido</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>NL→IR</td>
#       <td>450</td>
#       <td>450</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1350098</td>
#       <td>62577</td>
#       <td>59min 56s</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
#     <div style="font-weight:600;font-size:15px;margin:8px 0 6px;color:#f1f1f1;">
#         Tabela 10. Validade das IRs geradas por método e k
#     </div>
#     <div class="container_tabela_saida" style="display:inline-block;max-width:100%;overflow-x:auto;overflow-y: visible;border:none;margin:8px 0 12px;">
#         <style>
#             .container_tabela_saida table.tabela_saida {
#                 border-collapse:collapse !important;
#                 table-layout:auto !important;
#                 width:auto !important;
#                 font-family:Arial,sans-serif !important;
#                 font-size:13px !important;
#                 background:#111 !important;
#                 color:#f1f1f1 !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida thead th {
#                 position:sticky !important;
#                 top:0 !important;
#                 z-index:2 !important;
#                 background:#2b2b2b !important;
#                 color:#fff !important;
#                 padding:7px !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #777 !important;
#                 border-bottom:2px solid #888 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody td {
#                 padding:7px !important;
#                 vertical-align:top !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(even) td {background:#1b1b1b !important;}
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(odd) td {background:#111 !important;}
#         </style>
#         <table class="dataframe tabela_saida">
#   <thead>
#     <tr style="text-align: left;">
#       <th>método de seleção</th>
#       <th>rótulo do método</th>
#       <th>k</th>
#       <th>registros</th>
#       <th>IR extraída</th>
#       <th>validade da IR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>random_seed42</td>
#       <td>Aleatória</td>
#       <td>1</td>
#       <td>50</td>
#       <td>50</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <td>lexical_tfidf</td>
#       <td>Lexical</td>
#       <td>1</td>
#       <td>50</td>
#       <td>50</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <td>semantic_embeddings</td>
#       <td>Semântica</td>
#       <td>1</td>
#       <td>50</td>
#       <td>50</td>
#       <td>30</td>
#     </tr>
#     <tr>
#       <td>random_seed42</td>
#       <td>Aleatória</td>
#       <td>3</td>
#       <td>50</td>
#       <td>50</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <td>lexical_tfidf</td>
#       <td>Lexical</td>
#       <td>3</td>
#       <td>50</td>
#       <td>50</td>
#       <td>29</td>
#     </tr>
#     <tr>
#       <td>semantic_embeddings</td>
#       <td>Semântica</td>
#       <td>3</td>
#       <td>50</td>
#       <td>50</td>
#       <td>28</td>
#     </tr>
#     <tr>
#       <td>random_seed42</td>
#       <td>Aleatória</td>
#       <td>5</td>
#       <td>50</td>
#       <td>50</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <td>lexical_tfidf</td>
#       <td>Lexical</td>
#       <td>5</td>
#       <td>50</td>
#       <td>50</td>
#       <td>29</td>
#     </tr>
#     <tr>
#       <td>semantic_embeddings</td>
#       <td>Semântica</td>
#       <td>5</td>
#       <td>50</td>
#       <td>50</td>
#       <td>30</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
#     <div style="font-weight:600;font-size:15px;margin:8px 0 6px;color:#f1f1f1;">
#         Tabela 11. Últimas IRs validadas
#     </div>
#     <div class="container_tabela_saida" style="display:inline-block;max-width:100%;overflow-x:auto;max-height: 420px; overflow-y: auto;border:none;margin:8px 0 12px;">
#         <style>
#             .container_tabela_saida table.tabela_saida {
#                 border-collapse:collapse !important;
#                 table-layout:auto !important;
#                 width:auto !important;
#                 font-family:Arial,sans-serif !important;
#                 font-size:13px !important;
#                 background:#111 !important;
#                 color:#f1f1f1 !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida thead th {
#                 position:sticky !important;
#                 top:0 !important;
#                 z-index:2 !important;
#                 background:#2b2b2b !important;
#                 color:#fff !important;
#                 padding:7px !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #777 !important;
#                 border-bottom:2px solid #888 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody td {
#                 padding:7px !important;
#                 vertical-align:top !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(even) td {background:#1b1b1b !important;}
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(odd) td {background:#111 !important;}
#         </style>
#         <table class="dataframe tabela_saida">
#   <thead>
#     <tr style="text-align: left;">
#       <th>ID do fluxo</th>
#       <th>fold</th>
#       <th>ID</th>
#       <th>rótulo do método</th>
#       <th>k</th>
#       <th>IR extraída</th>
#       <th>validade da IR</th>
#       <th>ir errors</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>f3c|fold=5|id=campi_004|method=lexical_tfidf|k=5</td>
#       <td>5</td>
#       <td>campi_004</td>
#       <td>Lexical</td>
#       <td>5</td>
#       <td>sim</td>
#       <td>não</td>
#       <td>["$.operations[0]: {'items': [{'kind': 'middlebox', 'value': 'firewall'}], 'operator': 'block'} is not valid under any of the given schemas"]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=5|id=campi_008|method=lexical_tfidf|k=5</td>
#       <td>5</td>
#       <td>campi_008</td>
#       <td>Lexical</td>
#       <td>5</td>
#       <td>sim</td>
#       <td>não</td>
#       <td>["$.operations[0]: {'items': [{'kind': 'middlebox', 'value': 'firewall'}], 'operator': 'block'} is not valid under any of the given schemas"]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=5|id=campi_013|method=lexical_tfidf|k=5</td>
#       <td>5</td>
#       <td>campi_013</td>
#       <td>Lexical</td>
#       <td>5</td>
#       <td>sim</td>
#       <td>sim</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=5|id=campi_015|method=lexical_tfidf|k=5</td>
#       <td>5</td>
#       <td>campi_015</td>
#       <td>Lexical</td>
#       <td>5</td>
#       <td>sim</td>
#       <td>sim</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=5|id=campi_022|method=lexical_tfidf|k=5</td>
#       <td>5</td>
#       <td>campi_022</td>
#       <td>Lexical</td>
#       <td>5</td>
#       <td>sim</td>
#       <td>sim</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=5|id=campi_029|method=lexical_tfidf|k=5</td>
#       <td>5</td>
#       <td>campi_029</td>
#       <td>Lexical</td>
#       <td>5</td>
#       <td>sim</td>
#       <td>não</td>
#       <td>["$.operations[0]: {'items': [{'kind': 'middlebox', 'value': 'router'}], 'operator': 'block'} is not valid under any of the given schemas","$.scope: {'type': 'route', 'source': None, 'destination': None, 'targets': []} is not valid under any of the given schemas"]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=5|id=campi_030|method=lexical_tfidf|k=5</td>
#       <td>5</td>
#       <td>campi_030</td>
#       <td>Lexical</td>
#       <td>5</td>
#       <td>sim</td>
#       <td>sim</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=5|id=campi_038|method=lexical_tfidf|k=5</td>
#       <td>5</td>
#       <td>campi_038</td>
#       <td>Lexical</td>
#       <td>5</td>
#       <td>sim</td>
#       <td>não</td>
#       <td>["$.operations[0]: {'items': [{'kind': 'quota_policy', 'constraint': 'download', 'value': '30 mbps', 'unit': 'mbps'}], 'operator': 'set'} is not valid under any of the given schemas"]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=5|id=campi_042|method=lexical_tfidf|k=5</td>
#       <td>5</td>
#       <td>campi_042</td>
#       <td>Lexical</td>
#       <td>5</td>
#       <td>sim</td>
#       <td>não</td>
#       <td>["$.operations: [] should be non-empty","$.scope: {'type': 'route', 'source': None, 'destination': None, 'targets': []} is not valid under any of the given schemas"]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=5|id=campi_049|method=lexical_tfidf|k=5</td>
#       <td>5</td>
#       <td>campi_049</td>
#       <td>Lexical</td>
#       <td>5</td>
#       <td>sim</td>
#       <td>sim</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=5|id=campi_004|method=semantic_embeddings|k=5</td>
#       <td>5</td>
#       <td>campi_004</td>
#       <td>Semântica</td>
#       <td>5</td>
#       <td>sim</td>
#       <td>não</td>
#       <td>["$.operations[0]: {'items': [{'kind': 'middlebox', 'value': 'firewall'}], 'operator': 'block'} is not valid under any of the given schemas"]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=5|id=campi_008|method=semantic_embeddings|k=5</td>
#       <td>5</td>
#       <td>campi_008</td>
#       <td>Semântica</td>
#       <td>5</td>
#       <td>sim</td>
#       <td>não</td>
#       <td>["$.operations[0]: {'items': [{'kind': 'middlebox', 'value': 'firewall'}], 'operator': 'block'} is not valid under any of the given schemas"]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=5|id=campi_013|method=semantic_embeddings|k=5</td>
#       <td>5</td>
#       <td>campi_013</td>
#       <td>Semântica</td>
#       <td>5</td>
#       <td>sim</td>
#       <td>sim</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=5|id=campi_015|method=semantic_embeddings|k=5</td>
#       <td>5</td>
#       <td>campi_015</td>
#       <td>Semântica</td>
#       <td>5</td>
#       <td>sim</td>
#       <td>sim</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=5|id=campi_022|method=semantic_embeddings|k=5</td>
#       <td>5</td>
#       <td>campi_022</td>
#       <td>Semântica</td>
#       <td>5</td>
#       <td>sim</td>
#       <td>sim</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=5|id=campi_029|method=semantic_embeddings|k=5</td>
#       <td>5</td>
#       <td>campi_029</td>
#       <td>Semântica</td>
#       <td>5</td>
#       <td>sim</td>
#       <td>não</td>
#       <td>["$.operations[0]: {'items': [{'kind': 'middlebox', 'value': 'router'}], 'operator': 'block'} is not valid under any of the given schemas","$.scope: {'destination': None, 'source': None, 'targets': [], 'type': 'route'} is not valid under any of the given schemas"]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=5|id=campi_030|method=semantic_embeddings|k=5</td>
#       <td>5</td>
#       <td>campi_030</td>
#       <td>Semântica</td>
#       <td>5</td>
#       <td>sim</td>
#       <td>não</td>
#       <td>["$: 'intent_id' is a required property","$: 'operations' is a required property","$: 'scope' is a required property","$: 'temporal_constraint' is a required property","$: Additional properties are not allowed ('constraint', 'kind', 'unit', 'value' were unexpected)"]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=5|id=campi_038|method=semantic_embeddings|k=5</td>
#       <td>5</td>
#       <td>campi_038</td>
#       <td>Semântica</td>
#       <td>5</td>
#       <td>sim</td>
#       <td>sim</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <td>f3c|fold=5|id=campi_042|method=semantic_embeddings|k=5</td>
#       <td>5</td>
#       <td>campi_04
# Bloco 6 concluído.
# Prompts NL → IR: 450
# IRs extraídas: 450
# IRs válidas: 210
# Substituições pela IR de referência: 0
# Status: OK

# %% [markdown]
# ## Bloco 7 - Geração da Nile a partir da IR produzida
#
# ### Objetivo
#
# Este bloco executa o segundo estágio dos fluxos-base: IR gerada → Nile.
#
# ### Fonte da IR do teste
#
# O prompt recebe somente a saída produzida no Bloco 6:
#
# - objeto JSON canônico, quando a extração foi possível;
# - trecho JSON extraído, quando aplicável;
# - texto bruto, quando nenhum objeto pôde ser extraído.
#
# A IR de referência permanece disponível apenas para avaliação externa da validade do primeiro estágio e nunca é usada para substituir a IR gerada.
#
# ### Demonstrações
#
# Os mesmos IDs do primeiro estágio são apresentados no formato IR → Nile. A seleção continua restrita ao treino e sem equivalência formal com o teste.
#
# ### Auditoria
#
# O bloco confirma:
#
# - ausência da Nile de referência;
# - ausência de R1, R2 e R3 do teste;
# - procedência `generated` da IR;
# - ausência de placeholders;
# - compatibilidade com o limite de contexto.
#
# A IR gerada pode coincidir com a IR de referência quando o modelo acerta. Por isso, a auditoria não considera essa coincidência como vazamento: a barreira relevante é a procedência da IR, registrada pelo pipeline.
#
# ### Avaliação inicial
#
# A Nile gerada é extraída e avaliada. O resultado constitui a variante `sem_ac` e define a elegibilidade da primeira autocorreção.
#
# ### Resultado esperado
#
# O bloco produzirá 450 prompts, 450 gerações e 450 avaliações iniciais.

# %%
# ----------------------------------------------------------
# 7.1 Montagem e auditoria dos prompts IR → Nile
# ----------------------------------------------------------

ir_validation_by_pipeline = {
    record["pipeline_id"]: record
    for record in ir_validation_records
}

prompt_nile_records = []
token_nile_rows = []
for plan in active_plan_records:
    test_record = records_by_id[plan["id"]]
    ir_record = ir_validation_by_pipeline[plan["pipeline_id"]]
    demos = f3_common.build_demos(
        plan["demonstration_ids"],
        records_by_id,
        "C_IR_NILE",
    )
    prompt = f3_common.build_prompt_c_nile(
        template_nile,
        ir_record["ir_for_secondary"],
        demos,
    )
    prompt_tokens = count_chat_tokens(prompt)
    reserved_tokens = prompt_tokens + MAX_NEW_TOKENS_NILE
    context_ok = reserved_tokens <= CONTEXT_LIMIT

    leak_nile = test_record["nile"] in prompt
    leak_r1 = test_record["r1"] in prompt
    leak_r2 = test_record["r2"] in prompt
    leak_r3 = test_record["r3"] in prompt
    pending = bool(re.search(r"\{\{[A-Z0-9_]+\}\}", prompt))
    if leak_nile or leak_r1 or leak_r2 or leak_r3 or pending or not context_ok:
        raise ValueError(f"Falha de auditoria no prompt Nile de {plan['pipeline_id']}.")

    execution_id = plan["pipeline_id"] + "|stage=nile"
    prompt_sha256 = sha256_text(prompt)
    fingerprint = sha256_text(canonical_json({
        "execution_id": execution_id,
        "prompt_sha256": prompt_sha256,
        "generated_ir_sha256": sha256_text(ir_record["ir_for_secondary"]),
        "model_id": MODELO_HF_ID,
        "max_new_tokens": MAX_NEW_TOKENS_NILE,
        "do_sample": DO_SAMPLE,
    }))
    prompt_record = {
        **plan,
        "execution_id": execution_id,
        "stage": "ir_to_nile",
        "ir_source": "generated",
        "generated_ir_sha256": sha256_text(ir_record["ir_for_secondary"]),
        "prompt": prompt,
        "prompt_sha256": prompt_sha256,
        "prompt_tokens": prompt_tokens,
        "reserved_tokens": reserved_tokens,
        "context_ok": context_ok,
        "execution_fingerprint": fingerprint,
    }
    prompt_nile_records.append(prompt_record)
    token_nile_rows.append({
        "execution_id": execution_id,
        "pipeline_id": plan["pipeline_id"],
        "fold": plan["fold"],
        "id": plan["id"],
        "selection_method": plan["selection_method"],
        "selection_label": plan["selection_label"],
        "k": plan["k"],
        "prompt_tokens": prompt_tokens,
        "max_new_tokens": MAX_NEW_TOKENS_NILE,
        "reserved_tokens": reserved_tokens,
        "context_ok": context_ok,
    })
    prompt_audit_records.append({
        "execution_id": execution_id,
        "pipeline_id": plan["pipeline_id"],
        "stage": "ir_to_nile",
        "fold": plan["fold"],
        "id": plan["id"],
        "selection_method": plan["selection_method"],
        "k": plan["k"],
        "pending_placeholders": pending,
        "test_reference_nile_exposed": leak_nile,
        "test_reference_ir_exposed": None,
        "test_r1_exposed": leak_r1,
        "test_r2_exposed": leak_r2,
        "test_r3_exposed": leak_r3,
        "ir_source": "generated",
        "context_ok": context_ok,
    })

write_jsonl_gz(prompt_nile_records, PROMPTS_NILE_PATH)
token_audit_nile_df = pd.DataFrame(token_nile_rows)
token_audit_nile_df.to_csv(TOKEN_AUDIT_NILE_PATH, index=False, encoding="utf-8")


# ----------------------------------------------------------
# 7.2 Execução IR → Nile
# ----------------------------------------------------------

nile_generation_records, nile_generation_summary = execute_generation_stage(
    prompt_nile_records,
    CHECKPOINT_NILE_PATH,
    GENERATIONS_NILE_PATH,
    "IR→Nile",
    MAX_NEW_TOKENS_NILE,
)
nile_generation_by_pipeline = {
    record["pipeline_id"]: record
    for record in nile_generation_records
}
prompt_ir_by_pipeline = {record["pipeline_id"]: record for record in prompt_ir_records}
prompt_nile_by_pipeline = {record["pipeline_id"]: record for record in prompt_nile_records}
ir_generation_by_pipeline = {record["pipeline_id"]: record for record in ir_generation_records}


# ----------------------------------------------------------
# 7.3 Avaliação da Nile inicial
# ----------------------------------------------------------

initial_evaluation_records = []
for plan in active_plan_records:
    generation = nile_generation_by_pipeline[plan["pipeline_id"]]
    test_record = records_by_id[plan["id"]]
    evaluation = f3_common.evaluate_nile_output(
        test_record["nile"],
        generation["response_raw"],
        validator,
        nile_metrics,
    )
    initial_evaluation_records.append({
        "pipeline_id": plan["pipeline_id"],
        "fold": plan["fold"],
        "id": plan["id"],
        "selection_method": plan["selection_method"],
        "selection_label": plan["selection_label"],
        "k": plan["k"],
        "nile_initial": evaluation["nile"],
        "syntax_valid": bool(evaluation["psr"]),
        "validator_feedback": evaluation.get("validator_feedback", ""),
        "psr": int(evaluation["psr"]),
        "em": int(evaluation["em"]),
        "ed": int(evaluation["ed"]),
        "ned": float(evaluation["ned"]),
        "sla_s": int(evaluation["sla_s"]),
        "sla_f": float(evaluation["sla_f"]),
        "eligible_for_autocorrection": int(evaluation["psr"]) == 0,
        "response_secondary_raw": generation["response_raw"],
        "prompt_secondary_tokens": int(generation["prompt_tokens"]),
        "generated_secondary_tokens": int(generation["generated_tokens"]),
        "elapsed_secondary_seconds": float(generation["elapsed_seconds"]),
    })

initial_evaluation_df = pd.DataFrame(initial_evaluation_records)
initial_evaluation_df.to_csv(INITIAL_EVALUATION_PATH, index=False, encoding="utf-8")

initial_summary_df = (
    initial_evaluation_df.groupby(["selection_method", "selection_label", "k"], dropna=False)
    .agg(
        records=("id", "count"),
        syntax_valid=("syntax_valid", "sum"),
        psr=("psr", "mean"),
        em=("em", "mean"),
        ed=("ed", "mean"),
        ned=("ned", "mean"),
        sla_s=("sla_s", "mean"),
        sla_f=("sla_f", "mean"),
        eligible_for_autocorrection=("eligible_for_autocorrection", "sum"),
    )
    .reset_index()
)
initial_summary_df["_ordem_metodo"] = initial_summary_df["selection_method"].map(ORDEM_METODOS_MAPA)
initial_summary_df = (
    initial_summary_df
    .sort_values(["k", "_ordem_metodo"])
    .drop(columns="_ordem_metodo")
    .reset_index(drop=True)
)

exibir_tabela(pd.DataFrame([nile_generation_summary]), "Resumo da geração IR → Nile")
exibir_tabela(initial_summary_df, "Desempenho inicial sem autocorreção")

print("Bloco 7 concluído.")
print(f"Prompts IR → Nile: {len(prompt_nile_records)}")
print(f"Saídas sintaticamente válidas: {int(initial_evaluation_df['syntax_valid'].sum())}")
print(f"Elegíveis à primeira autocorreção: {int(initial_evaluation_df['eligible_for_autocorrection'].sum())}")
print("Status: OK")
# Out:
# F3-C IR→Nile: |                                    |   0.00% | 0/450 | decorrido=00:00 | restante=? |
# [001/450] fold_1 | campi_001 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [002/450] fold_1 | campi_002 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [003/450] fold_1 | campi_011 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [004/450] fold_1 | campi_012 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [005/450] fold_1 | campi_020 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [006/450] fold_1 | campi_023 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [007/450] fold_1 | campi_024 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [008/450] fold_1 | campi_027 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [009/450] fold_1 | campi_039 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [010/450] fold_1 | campi_044 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [011/450] fold_1 | campi_001 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [012/450] fold_1 | campi_002 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [013/450] fold_1 | campi_011 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [014/450] fold_1 | campi_012 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [015/450] fold_1 | campi_020 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [016/450] fold_1 | campi_023 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [017/450] fold_1 | campi_024 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [018/450] fold_1 | campi_027 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [019/450] fold_1 | campi_039 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [020/450] fold_1 | campi_044 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [021/450] fold_1 | campi_001 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [022/450] fold_1 | campi_002 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [023/450] fold_1 | campi_011 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [024/450] fold_1 | campi_012 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [025/450] fold_1 | campi_020 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [026/450] fold_1 | campi_023 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [027/450] fold_1 | campi_024 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [028/450] fold_1 | campi_027 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [029/450] fold_1 | campi_039 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [030/450] fold_1 | campi_044 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [031/450] fold_1 | campi_001 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [032/450] fold_1 | campi_002 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [033/450] fold_1 | campi_011 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [034/450] fold_1 | campi_012 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [035/450] fold_1 | campi_020 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [036/450] fold_1 | campi_023 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [037/450] fold_1 | campi_024 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [038/450] fold_1 | campi_027 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [039/450] fold_1 | campi_039 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [040/450] fold_1 | campi_044 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [041/450] fold_1 | campi_001 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [042/450] fold_1 | campi_002 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [043/450] fold_1 | campi_011 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [044/450] fold_1 | campi_012 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [045/450] fold_1 | campi_020 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [046/450] fold_1 | campi_023 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [047/450] fold_1 | campi_024 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [048/450] fold_1 | campi_027 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [049/450] fold_1 | campi_039 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [050/450] fold_1 | campi_044 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [051/450] fold_1 | campi_001 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [052/450] fold_1 | campi_002 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [053/450] fold_1 | campi_011 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [054/450] fold_1 | campi_012 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [055/450] fold_1 | campi_020 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [056/450] fold_1 | campi_023 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [057/450] fold_1 | campi_024 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [058/450] fold_1 | campi_027 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [059/450] fold_1 | campi_039 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [060/450] fold_1 | campi_044 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [061/450] fold_1 | campi_001 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [062/450] fold_1 | campi_002 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [063/450] fold_1 | campi_011 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [064/450] fold_1 | campi_012 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [065/450] fold_1 | campi_020 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [066/450] fold_1 | campi_023 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [067/450] fold_1 | campi_024 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [068/450] fold_1 | campi_027 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [069/450] fold_1 | campi_039 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [070/450] fold_1 | campi_044 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [071/450] fold_1 | campi_001 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [072/450] fold_1 | campi_002 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [073/450] fold_1 | campi_011 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [074/450] fold_1 | campi_012 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [075/450] fold_1 | campi_020 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [076/450] fold_1 | campi_023 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [077/450] fold_1 | campi_024 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [078/450] fold_1 | campi_027 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [079/450] fold_1 | campi_039 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [080/450] fold_1 | campi_044 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [081/450] fold_1 | campi_001 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [082/450] fold_1 | campi_002 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [083/450] fold_1 | campi_011 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [084/450] fold_1 | campi_012 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [085/450] fold_1 | campi_020 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [086/450] fold_1 | campi_023 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [087/450] fold_1 | campi_024 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [088/450] fold_1 | campi_027 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [089/450] fold_1 | campi_039 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [090/450] fold_1 | campi_044 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [091/450] fold_2 | campi_006 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [092/450] fold_2 | campi_009 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [093/450] fold_2 | campi_010 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [094/450] fold_2 | campi_017 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [095/450] fold_2 | campi_028 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [096/450] fold_2 | campi_031 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [097/450] fold_2 | campi_034 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [098/450] fold_2 | campi_041 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [099/450] fold_2 | campi_043 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [100/450] fold_2 | campi_048 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [101/450] fold_2 | campi_006 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [102/450] fold_2 | campi_009 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [103/450] fold_2 | campi_010 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [104/450] fold_2 | campi_017 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [105/450] fold_2 | campi_028 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [106/450] fold_2 | campi_031 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [107/450] fold_2 | campi_034 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [108/450] fold_2 | campi_041 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [109/450] fold_2 | campi_043 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [110/450] fold_2 | campi_048 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [111/450] fold_2 | campi_006 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [112/450] fold_2 | campi_009 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [113/450] fold_2 | campi_010 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [114/450] fold_2 | campi_017 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [115/450] fold_2 | campi_028 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [116/450] fold_2 | campi_031 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [117/450] fold_2 | campi_034 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [118/450] fold_2 | campi_041 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [119/450] fold_2 | campi_043 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [120/450] fold_2 | campi_048 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [121/450] fold_2 | campi_006 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [122/450] fold_2 | campi_009 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [123/450] fold_2 | campi_010 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [124/450] fold_2 | campi_017 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [125/450] fold_2 | campi_028 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [126/450] fold_2 | campi_031 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [127/450] fold_2 | campi_034 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [128/450] fold_2 | campi_041 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [129/450] fold_2 | campi_043 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [130/450] fold_2 | campi_048 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [131/450] fold_2 | campi_006 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [132/450] fold_2 | campi_009 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [133/450] fold_2 | campi_010 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [134/450] fold_2 | campi_017 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [135/450] fold_2 | campi_028 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [136/450] fold_2 | campi_031 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [137/450] fold_2 | campi_034 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [138/450] fold_2 | campi_041 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [139/450] fold_2 | campi_043 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [140/450] fold_2 | campi_048 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [141/450] fold_2 | campi_006 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [142/450] fold_2 | campi_009 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [143/450] fold_2 | campi_010 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [144/450] fold_2 | campi_017 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [145/450] fold_2 | campi_028 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [146/450] fold_2 | campi_031 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [147/450] fold_2 | campi_034 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [148/450] fold_2 | campi_041 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [149/450] fold_2 | campi_043 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [150/450] fold_2 | campi_048 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [151/450] fold_2 | campi_006 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [152/450] fold_2 | campi_009 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [153/450] fold_2 | campi_010 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [154/450] fold_2 | campi_017 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [155/450] fold_2 | campi_028 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [156/450] fold_2 | campi_031 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [157/450] fold_2 | campi_034 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [158/450] fold_2 | campi_041 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [159/450] fold_2 | campi_043 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [160/450] fold_2 | campi_048 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [161/450] fold_2 | campi_006 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [162/450] fold_2 | campi_009 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [163/450] fold_2 | campi_010 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [164/450] fold_2 | campi_017 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [165/450] fold_2 | campi_028 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [166/450] fold_2 | campi_031 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [167/450] fold_2 | campi_034 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [168/450] fold_2 | campi_041 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [169/450] fold_2 | campi_043 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [170/450] fold_2 | campi_048 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [171/450] fold_2 | campi_006 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [172/450] fold_2 | campi_009 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [173/450] fold_2 | campi_010 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [174/450] fold_2 | campi_017 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [175/450] fold_2 | campi_028 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [176/450] fold_2 | campi_031 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [177/450] fold_2 | campi_034 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [178/450] fold_2 | campi_041 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [179/450] fold_2 | campi_043 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [180/450] fold_2 | campi_048 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [181/450] fold_3 | campi_003 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [182/450] fold_3 | campi_007 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [183/450] fold_3 | campi_014 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [184/450] fold_3 | campi_018 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [185/450] fold_3 | campi_025 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [186/450] fold_3 | campi_026 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [187/450] fold_3 | campi_033 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [188/450] fold_3 | campi_035 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [189/450] fold_3 | campi_045 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [190/450] fold_3 | campi_047 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [191/450] fold_3 | campi_003 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [192/450] fold_3 | campi_007 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [193/450] fold_3 | campi_014 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [194/450] fold_3 | campi_018 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [195/450] fold_3 | campi_025 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [196/450] fold_3 | campi_026 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [197/450] fold_3 | campi_033 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [198/450] fold_3 | campi_035 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [199/450] fold_3 | campi_045 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [200/450] fold_3 | campi_047 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [201/450] fold_3 | campi_003 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [202/450] fold_3 | campi_007 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [203/450] fold_3 | campi_014 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [204/450] fold_3 | campi_018 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [205/450] fold_3 | campi_025 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [206/450] fold_3 | campi_026 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [207/450] fold_3 | campi_033 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [208/450] fold_3 | campi_035 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [209/450] fold_3 | campi_045 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [210/450] fold_3 | campi_047 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [211/450] fold_3 | campi_003 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [212/450] fold_3 | campi_007 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [213/450] fold_3 | campi_014 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [214/450] fold_3 | campi_018 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [215/450] fold_3 | campi_025 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [216/450] fold_3 | campi_026 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [217/450] fold_3 | campi_033 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [218/450] fold_3 | campi_035 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [219/450] fold_3 | campi_045 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [220/450] fold_3 | campi_047 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [221/450] fold_3 | campi_003 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [222/450] fold_3 | campi_007 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [223/450] fold_3 | campi_014 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [224/450] fold_3 | campi_018 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [225/450] fold_3 | campi_025 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [226/450] fold_3 | campi_026 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [227/450] fold_3 | campi_033 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [228/450] fold_3 | campi_035 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [229/450] fold_3 | campi_045 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [230/450] fold_3 | campi_047 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [231/450] fold_3 | campi_003 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [232/450] fold_3 | campi_007 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [233/450] fold_3 | campi_014 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [234/450] fold_3 | campi_018 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [235/450] fold_3 | campi_025 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [236/450] fold_3 | campi_026 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [237/450] fold_3 | campi_033 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [238/450] fold_3 | campi_035 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [239/450] fold_3 | campi_045 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [240/450] fold_3 | campi_047 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [241/450] fold_3 | campi_003 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [242/450] fold_3 | campi_007 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [243/450] fold_3 | campi_014 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [244/450] fold_3 | campi_018 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [245/450] fold_3 | campi_025 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [246/450] fold_3 | campi_026 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [247/450] fold_3 | campi_033 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [248/450] fold_3 | campi_035 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [249/450] fold_3 | campi_045 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [250/450] fold_3 | campi_047 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [251/450] fold_3 | campi_003 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [252/450] fold_3 | campi_007 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [253/450] fold_3 | campi_014 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [254/450] fold_3 | campi_018 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [255/450] fold_3 | campi_025 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [256/450] fold_3 | campi_026 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [257/450] fold_3 | campi_033 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [258/450] fold_3 | campi_035 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [259/450] fold_3 | campi_045 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [260/450] fold_3 | campi_047 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [261/450] fold_3 | campi_003 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [262/450] fold_3 | campi_007 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [263/450] fold_3 | campi_014 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [264/450] fold_3 | campi_018 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [265/450] fold_3 | campi_025 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [266/450] fold_3 | campi_026 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [267/450] fold_3 | campi_033 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [268/450] fold_3 | campi_035 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [269/450] fold_3 | campi_045 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [270/450] fold_3 | campi_047 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [271/450] fold_4 | campi_005 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [272/450] fold_4 | campi_016 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [273/450] fold_4 | campi_019 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [274/450] fold_4 | campi_021 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [275/450] fold_4 | campi_032 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [276/450] fold_4 | campi_036 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [277/450] fold_4 | campi_037 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [278/450] fold_4 | campi_040 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [279/450] fold_4 | campi_046 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [280/450] fold_4 | campi_050 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [281/450] fold_4 | campi_005 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [282/450] fold_4 | campi_016 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [283/450] fold_4 | campi_019 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [284/450] fold_4 | campi_021 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [285/450] fold_4 | campi_032 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [286/450] fold_4 | campi_036 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [287/450] fold_4 | campi_037 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [288/450] fold_4 | campi_040 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [289/450] fold_4 | campi_046 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [290/450] fold_4 | campi_050 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [291/450] fold_4 | campi_005 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [292/450] fold_4 | campi_016 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [293/450] fold_4 | campi_019 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [294/450] fold_4 | campi_021 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [295/450] fold_4 | campi_032 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [296/450] fold_4 | campi_036 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [297/450] fold_4 | campi_037 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [298/450] fold_4 | campi_040 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [299/450] fold_4 | campi_046 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [300/450] fold_4 | campi_050 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [301/450] fold_4 | campi_005 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [302/450] fold_4 | campi_016 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [303/450] fold_4 | campi_019 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [304/450] fold_4 | campi_021 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [305/450] fold_4 | campi_032 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [306/450] fold_4 | campi_036 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [307/450] fold_4 | campi_037 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [308/450] fold_4 | campi_040 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [309/450] fold_4 | campi_046 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [310/450] fold_4 | campi_050 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [311/450] fold_4 | campi_005 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [312/450] fold_4 | campi_016 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [313/450] fold_4 | campi_019 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [314/450] fold_4 | campi_021 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [315/450] fold_4 | campi_032 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [316/450] fold_4 | campi_036 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [317/450] fold_4 | campi_037 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [318/450] fold_4 | campi_040 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [319/450] fold_4 | campi_046 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [320/450] fold_4 | campi_050 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [321/450] fold_4 | campi_005 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [322/450] fold_4 | campi_016 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [323/450] fold_4 | campi_019 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [324/450] fold_4 | campi_021 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [325/450] fold_4 | campi_032 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [326/450] fold_4 | campi_036 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [327/450] fold_4 | campi_037 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [328/450] fold_4 | campi_040 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [329/450] fold_4 | campi_046 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [330/450] fold_4 | campi_050 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [331/450] fold_4 | campi_005 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [332/450] fold_4 | campi_016 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [333/450] fold_4 | campi_019 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [334/450] fold_4 | campi_021 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [335/450] fold_4 | campi_032 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [336/450] fold_4 | campi_036 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [337/450] fold_4 | campi_037 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [338/450] fold_4 | campi_040 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [339/450] fold_4 | campi_046 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [340/450] fold_4 | campi_050 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [341/450] fold_4 | campi_005 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [342/450] fold_4 | campi_016 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [343/450] fold_4 | campi_019 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [344/450] fold_4 | campi_021 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [345/450] fold_4 | campi_032 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [346/450] fold_4 | campi_036 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [347/450] fold_4 | campi_037 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [348/450] fold_4 | campi_040 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [349/450] fold_4 | campi_046 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [350/450] fold_4 | campi_050 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [351/450] fold_4 | campi_005 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [352/450] fold_4 | campi_016 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [353/450] fold_4 | campi_019 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [354/450] fold_4 | campi_021 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [355/450] fold_4 | campi_032 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [356/450] fold_4 | campi_036 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [357/450] fold_4 | campi_037 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [358/450] fold_4 | campi_040 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [359/450] fold_4 | campi_046 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [360/450] fold_4 | campi_050 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [361/450] fold_5 | campi_004 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [362/450] fold_5 | campi_008 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [363/450] fold_5 | campi_013 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [364/450] fold_5 | campi_015 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [365/450] fold_5 | campi_022 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [366/450] fold_5 | campi_029 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [367/450] fold_5 | campi_030 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [368/450] fold_5 | campi_038 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [369/450] fold_5 | campi_042 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [370/450] fold_5 | campi_049 | Aleatória | k=1 | etapa=IR→Nile | status=ok
# [371/450] fold_5 | campi_004 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [372/450] fold_5 | campi_008 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [373/450] fold_5 | campi_013 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [374/450] fold_5 | campi_015 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [375/450] fold_5 | campi_022 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [376/450] fold_5 | campi_029 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [377/450] fold_5 | campi_030 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [378/450] fold_5 | campi_038 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [379/450] fold_5 | campi_042 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [380/450] fold_5 | campi_049 | Lexical | k=1 | etapa=IR→Nile | status=ok
# [381/450] fold_5 | campi_004 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [382/450] fold_5 | campi_008 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [383/450] fold_5 | campi_013 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [384/450] fold_5 | campi_015 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [385/450] fold_5 | campi_022 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [386/450] fold_5 | campi_029 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [387/450] fold_5 | campi_030 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [388/450] fold_5 | campi_038 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [389/450] fold_5 | campi_042 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [390/450] fold_5 | campi_049 | Semântica | k=1 | etapa=IR→Nile | status=ok
# [391/450] fold_5 | campi_004 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [392/450] fold_5 | campi_008 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [393/450] fold_5 | campi_013 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [394/450] fold_5 | campi_015 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [395/450] fold_5 | campi_022 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [396/450] fold_5 | campi_029 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [397/450] fold_5 | campi_030 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [398/450] fold_5 | campi_038 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [399/450] fold_5 | campi_042 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [400/450] fold_5 | campi_049 | Aleatória | k=3 | etapa=IR→Nile | status=ok
# [401/450] fold_5 | campi_004 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [402/450] fold_5 | campi_008 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [403/450] fold_5 | campi_013 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [404/450] fold_5 | campi_015 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [405/450] fold_5 | campi_022 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [406/450] fold_5 | campi_029 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [407/450] fold_5 | campi_030 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [408/450] fold_5 | campi_038 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [409/450] fold_5 | campi_042 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [410/450] fold_5 | campi_049 | Lexical | k=3 | etapa=IR→Nile | status=ok
# [411/450] fold_5 | campi_004 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [412/450] fold_5 | campi_008 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [413/450] fold_5 | campi_013 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [414/450] fold_5 | campi_015 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [415/450] fold_5 | campi_022 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [416/450] fold_5 | campi_029 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [417/450] fold_5 | campi_030 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [418/450] fold_5 | campi_038 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [419/450] fold_5 | campi_042 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [420/450] fold_5 | campi_049 | Semântica | k=3 | etapa=IR→Nile | status=ok
# [421/450] fold_5 | campi_004 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [422/450] fold_5 | campi_008 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [423/450] fold_5 | campi_013 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [424/450] fold_5 | campi_015 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [425/450] fold_5 | campi_022 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [426/450] fold_5 | campi_029 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [427/450] fold_5 | campi_030 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [428/450] fold_5 | campi_038 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [429/450] fold_5 | campi_042 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [430/450] fold_5 | campi_049 | Aleatória | k=5 | etapa=IR→Nile | status=ok
# [431/450] fold_5 | campi_004 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [432/450] fold_5 | campi_008 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [433/450] fold_5 | campi_013 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [434/450] fold_5 | campi_015 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [435/450] fold_5 | campi_022 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [436/450] fold_5 | campi_029 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [437/450] fold_5 | campi_030 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [438/450] fold_5 | campi_038 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [439/450] fold_5 | campi_042 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [440/450] fold_5 | campi_049 | Lexical | k=5 | etapa=IR→Nile | status=ok
# [441/450] fold_5 | campi_004 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [442/450] fold_5 | campi_008 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [443/450] fold_5 | campi_013 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [444/450] fold_5 | campi_015 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [445/450] fold_5 | campi_022 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [446/450] fold_5 | campi_029 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [447/450] fold_5 | campi_030 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [448/450] fold_5 | campi_038 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [449/450] fold_5 | campi_042 | Semântica | k=5 | etapa=IR→Nile | status=ok
# [450/450] fold_5 | campi_049 | Semântica | k=5 | etapa=IR→Nile | status=ok
#     <div style="font-weight:600;font-size:15px;margin:8px 0 6px;color:#f1f1f1;">
#         Tabela 12. Resumo da geração IR → Nile
#     </div>
#     <div class="container_tabela_saida" style="display:inline-block;max-width:100%;overflow-x:auto;overflow-y: visible;border:none;margin:8px 0 12px;">
#         <style>
#             .container_tabela_saida table.tabela_saida {
#                 border-collapse:collapse !important;
#                 table-layout:auto !important;
#                 width:auto !important;
#                 font-family:Arial,sans-serif !important;
#                 font-size:13px !important;
#                 background:#111 !important;
#                 color:#f1f1f1 !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida thead th {
#                 position:sticky !important;
#                 top:0 !important;
#                 z-index:2 !important;
#                 background:#2b2b2b !important;
#                 color:#fff !important;
#                 padding:7px !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #777 !important;
#                 border-bottom:2px solid #888 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody td {
#                 padding:7px !important;
#                 vertical-align:top !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(even) td {background:#1b1b1b !important;}
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(odd) td {background:#111 !important;}
#         </style>
#         <table class="dataframe tabela_saida">
#   <thead>
#     <tr style="text-align: left;">
#       <th>etapa</th>
#       <th>requested</th>
#       <th>generated</th>
#       <th>reused</th>
#       <th>stale ignored</th>
#       <th>tokens do prompt</th>
#       <th>tokens gerados</th>
#       <th>tempo decorrido</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>IR→Nile</td>
#       <td>450</td>
#       <td>450</td>
#       <td>0</td>
#       <td>0</td>
#       <td>395638</td>
#       <td>11208</td>
#       <td>10min 17s</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
#     <div style="font-weight:600;font-size:15px;margin:8px 0 6px;color:#f1f1f1;">
#         Tabela 13. Desempenho inicial sem autocorreção
#     </div>
#     <div class="container_tabela_saida" style="display:inline-block;max-width:100%;overflow-x:auto;overflow-y: visible;border:none;margin:8px 0 12px;">
#         <style>
#             .container_tabela_saida table.tabela_saida {
#                 border-collapse:collapse !important;
#                 table-layout:auto !important;
#                 width:auto !important;
#                 font-family:Arial,sans-serif !important;
#                 font-size:13px !important;
#                 background:#111 !important;
#                 color:#f1f1f1 !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida thead th {
#                 position:sticky !important;
#                 top:0 !important;
#                 z-index:2 !important;
#                 background:#2b2b2b !important;
#                 color:#fff !important;
#                 padding:7px !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #777 !important;
#                 border-bottom:2px solid #888 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody td {
#                 padding:7px !important;
#                 vertical-align:top !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(even) td {background:#1b1b1b !important;}
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(odd) td {background:#111 !important;}
#         </style>
#         <table class="dataframe tabela_saida">
#   <thead>
#     <tr style="text-align: left;">
#       <th>método de seleção</th>
#       <th>rótulo do método</th>
#       <th>k</th>
#       <th>registros</th>
#       <th>validade sintática</th>
#       <th>PSR</th>
#       <th>EM</th>
#       <th>ED</th>
#       <th>NED</th>
#       <th>SLA-S</th>
#       <th>SLA-F</th>
#       <th>elegível à autocorreção</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>random_seed42</td>
#       <td>Aleatória</td>
#       <td>1</td>
#       <td>50</td>
#       <td>10</td>
#       <td>0.20</td>
#       <td>0.00</td>
#       <td>63.46</td>
#       <td>0.551855</td>
#       <td>0.00</td>
#       <td>0.084707</td>
#       <td>40</td>
#     </tr>
#     <tr>
#       <td>lexical_tfidf</td>
#       <td>Lexical</td>
#       <td>1</td>
#       <td>50</td>
#       <td>34</td>
#       <td>0.68</td>
#       <td>0.08</td>
#       <td>36.50</td>
#       <td>0.305886</td>
#       <td>0.12</td>
#       <td>0.486414</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <td>semantic_embeddings</td>
#       <td>Semântica</td>
#       <td>1</td>
#       <td>50</td>
#       <td>26</td>
#       <td>0.52</td>
#       <td>0.06</td>
#       <td>35.20</td>
#       <td>0.316237</td>
#       <td>0.06</td>
#       <td>0.357904</td>
#       <td>24</td>
#     </tr>
#     <tr>
#       <td>random_seed42</td>
#       <td>Aleatória</td>
#       <td>3</td>
#       <td>50</td>
#       <td>6</td>
#       <td>0.12</td>
#       <td>0.00</td>
#       <td>53.16</td>
#       <td>0.471629</td>
#       <td>0.02</td>
#       <td>0.086919</td>
#       <td>44</td>
#     </tr>
#     <tr>
#       <td>lexical_tfidf</td>
#       <td>Lexical</td>
#       <td>3</td>
#       <td>50</td>
#       <td>30</td>
#       <td>0.60</td>
#       <td>0.14</td>
#       <td>28.74</td>
#       <td>0.254165</td>
#       <td>0.16</td>
#       <td>0.449426</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <td>semantic_embeddings</td>
#       <td>Semântica</td>
#       <td>3</td>
#       <td>50</td>
#       <td>29</td>
#       <td>0.58</td>
#       <td>0.16</td>
#       <td>30.08</td>
#       <td>0.264613</td>
#       <td>0.16</td>
#       <td>0.460576</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <td>random_seed42</td>
#       <td>Aleatória</td>
#       <td>5</td>
#       <td>50</td>
#       <td>12</td>
#       <td>0.24</td>
#       <td>0.00</td>
#       <td>46.60</td>
#       <td>0.418113</td>
#       <td>0.00</td>
#       <td>0.154091</td>
#       <td>38</td>
#     </tr>
#     <tr>
#       <td>lexical_tfidf</td>
#       <td>Lexical</td>
#       <td>5</td>
#       <td>50</td>
#       <td>30</td>
#       <td>0.60</td>
#       <td>0.18</td>
#       <td>27.44</td>
#       <td>0.248303</td>
#       <td>0.18</td>
#       <td>0.482991</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <td>semantic_embeddings</td>
#       <td>Semântica</td>
#       <td>5</td>
#       <td>50</td>
#       <td>31</td>
#       <td>0.62</td>
#       <td>0.18</td>
#       <td>31.66</td>
#       <td>0.282831</td>
#       <td>0.18</td>
#       <td>0.477730</td>
#       <td>19</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
# Bloco 7 concluído.
# Prompts IR → Nile: 450
# Saídas sintaticamente válidas: 208
# Elegíveis à primeira autocorreção: 242
# Status: OK

# %% [markdown]
# ## Bloco 8 - Primeira autocorreção e consolidação dos 900 resultados
#
# ### Objetivo
#
# Este bloco produz a variante `primeira_ac` e consolida as duas variantes da F3-C no schema comum da Fase 3.
#
# ### Elegibilidade
#
# A autocorreção é criada somente quando a Nile inicial possui `PSR=0`. Saídas aceitas pelo parser são preservadas sem uma nova chamada ao modelo.
#
# ### Conteúdo do prompt
#
# O modelo recebe:
#
# - entrada em linguagem natural;
# - IR produzida no primeiro estágio;
# - Nile rejeitada;
# - feedback do validador Nile;
# - as mesmas demonstrações IR → Nile da condição.
#
# Não são fornecidas a IR de referência, a Nile de referência ou justificativas do teste. A IR não é corrigida nesta etapa.
#
# ### Consolidação
#
# Para cada fluxo-base são criados dois registros:
#
# - `sem_ac`, com a Nile inicial;
# - `primeira_ac`, com a Nile corrigida ou preservada.
#
# Todos os registros são validados pelo JSON Schema comum. As métricas são recalculadas sobre a Nile efetivamente avaliada.
#
# ### Resultado esperado
#
# A execução oficial produzirá 900 registros completos. O número de chamadas de autocorreção corresponderá exatamente ao número de Nile iniciais com `PSR=0`.
#
# ### Ordem das variantes
#
# Nas tabelas comparativas, a variante `sem_ac` é apresentada antes de `primeira_ac`, preservando a sequência natural do experimento: resultado inicial seguido do resultado após a primeira autocorreção.

# %%
# ----------------------------------------------------------
# 8.1 Montagem e auditoria dos prompts de autocorreção
# ----------------------------------------------------------

initial_by_pipeline = {
    record["pipeline_id"]: record
    for record in initial_evaluation_records
}
eligible_plans = [
    plan
    for plan in active_plan_records
    if initial_by_pipeline[plan["pipeline_id"]]["eligible_for_autocorrection"]
]

prompt_ac_records = []
token_ac_rows = []
for plan in eligible_plans:
    test_record = records_by_id[plan["id"]]
    ir_record = ir_validation_by_pipeline[plan["pipeline_id"]]
    initial = initial_by_pipeline[plan["pipeline_id"]]
    demos = f3_common.build_demos(
        plan["demonstration_ids"],
        records_by_id,
        "C_IR_NILE",
    )
    auxiliary = (
        "Representação Intermediária gerada pelo modelo aluno:\n"
        + ir_record["ir_for_secondary"]
    )
    prompt = f3_common.build_prompt_autocorrection(
        template_autocorrection,
        test_record["nl"],
        auxiliary,
        initial["nile_initial"],
        initial["validator_feedback"] or "Saída rejeitada pelo parser Nile.",
        demos,
    )
    prompt_tokens = count_chat_tokens(prompt)
    reserved_tokens = prompt_tokens + MAX_NEW_TOKENS_NILE
    context_ok = reserved_tokens <= CONTEXT_LIMIT

    leak_nile = test_record["nile"] in prompt
    leak_r1 = test_record["r1"] in prompt
    leak_r2 = test_record["r2"] in prompt
    leak_r3 = test_record["r3"] in prompt
    pending = bool(re.search(r"\{\{[A-Z0-9_]+\}\}", prompt))
    if leak_nile or leak_r1 or leak_r2 or leak_r3 or pending or not context_ok:
        raise ValueError(f"Falha de auditoria no prompt de autocorreção de {plan['pipeline_id']}.")

    execution_id = plan["pipeline_id"] + "|stage=autocorrection"
    prompt_sha256 = sha256_text(prompt)
    fingerprint = sha256_text(canonical_json({
        "execution_id": execution_id,
        "prompt_sha256": prompt_sha256,
        "initial_nile_sha256": sha256_text(initial["nile_initial"]),
        "feedback_sha256": sha256_text(initial["validator_feedback"]),
        "generated_ir_sha256": sha256_text(ir_record["ir_for_secondary"]),
        "model_id": MODELO_HF_ID,
        "max_new_tokens": MAX_NEW_TOKENS_NILE,
        "do_sample": DO_SAMPLE,
    }))
    prompt_record = {
        **plan,
        "execution_id": execution_id,
        "stage": "autocorrection",
        "ir_source": "generated",
        "initial_nile_sha256": sha256_text(initial["nile_initial"]),
        "prompt": prompt,
        "prompt_sha256": prompt_sha256,
        "prompt_tokens": prompt_tokens,
        "reserved_tokens": reserved_tokens,
        "context_ok": context_ok,
        "execution_fingerprint": fingerprint,
    }
    prompt_ac_records.append(prompt_record)
    token_ac_rows.append({
        "execution_id": execution_id,
        "pipeline_id": plan["pipeline_id"],
        "fold": plan["fold"],
        "id": plan["id"],
        "selection_method": plan["selection_method"],
        "selection_label": plan["selection_label"],
        "k": plan["k"],
        "prompt_tokens": prompt_tokens,
        "max_new_tokens": MAX_NEW_TOKENS_NILE,
        "reserved_tokens": reserved_tokens,
        "context_ok": context_ok,
    })
    prompt_audit_records.append({
        "execution_id": execution_id,
        "pipeline_id": plan["pipeline_id"],
        "stage": "autocorrection",
        "fold": plan["fold"],
        "id": plan["id"],
        "selection_method": plan["selection_method"],
        "k": plan["k"],
        "pending_placeholders": pending,
        "test_reference_nile_exposed": leak_nile,
        "test_reference_ir_exposed": None,
        "test_r1_exposed": leak_r1,
        "test_r2_exposed": leak_r2,
        "test_r3_exposed": leak_r3,
        "ir_source": "generated",
        "context_ok": context_ok,
    })

write_jsonl_gz(prompt_ac_records, PROMPTS_AC_PATH)
token_audit_ac_df = pd.DataFrame(token_ac_rows)
if token_audit_ac_df.empty:
    token_audit_ac_df = pd.DataFrame(columns=[
        "execution_id", "pipeline_id", "fold", "id",
        "selection_method", "selection_label", "k",
        "prompt_tokens", "max_new_tokens", "reserved_tokens", "context_ok",
    ])
token_audit_ac_df.to_csv(TOKEN_AUDIT_AC_PATH, index=False, encoding="utf-8")


# ----------------------------------------------------------
# 8.2 Execução da primeira autocorreção
# ----------------------------------------------------------

if prompt_ac_records:
    ac_generation_records, ac_generation_summary = execute_generation_stage(
        prompt_ac_records,
        CHECKPOINT_AC_PATH,
        GENERATIONS_AC_PATH,
        "autocorreção",
        MAX_NEW_TOKENS_NILE,
    )
else:
    ac_generation_records = []
    ac_generation_summary = {
        "stage": "autocorreção",
        "requested": 0,
        "generated": 0,
        "reused": 0,
        "stale_ignored": 0,
        "prompt_tokens": 0,
        "generated_tokens": 0,
        "elapsed_seconds": 0.0,
    }
    write_jsonl_gz([], GENERATIONS_AC_PATH)

ac_generation_by_pipeline = {
    record["pipeline_id"]: record
    for record in ac_generation_records
}
prompt_ac_by_pipeline = {
    record["pipeline_id"]: record
    for record in prompt_ac_records
}


# ----------------------------------------------------------
# 8.3 Construção e validação dos 900 registros finais
# ----------------------------------------------------------

result_records = []
comparison_rows = []
for plan in active_plan_records:
    pipeline_id = plan["pipeline_id"]
    test_record = records_by_id[plan["id"]]
    ir_record = ir_validation_by_pipeline[pipeline_id]
    initial = initial_by_pipeline[pipeline_id]
    prompt_ir_record = prompt_ir_by_pipeline[pipeline_id]
    prompt_nile_record = prompt_nile_by_pipeline[pipeline_id]
    ir_generation = ir_generation_by_pipeline[pipeline_id]
    nile_generation = nile_generation_by_pipeline[pipeline_id]

    sem_record = f3_common.make_result_record(
        strategy=ESTRATEGIA,
        variant="sem_ac",
        fold=int(plan["fold"]),
        id=plan["id"],
        k=int(plan["k"]),
        selection_method=plan["selection_method"],
        selection_label=plan["selection_label"],
        demonstration_ids=list(plan["demonstration_ids"]),
        demonstration_scores=list(plan["demonstration_scores"]),
        nl=test_record["nl"],
        reference_nile=test_record["nile"],
        prompt_primary=prompt_ir_record["prompt"],
        response_primary_raw=ir_generation["response_raw"],
        prompt_secondary=prompt_nile_record["prompt"],
        response_secondary_raw=nile_generation["response_raw"],
        prompt_autocorrection=None,
        response_autocorrection_raw=None,
        generated_ir=ir_record["generated_ir"],
        generated_ir_text=ir_record["generated_ir_text"] or ir_record["ir_for_secondary"],
        ir_valid=bool(ir_record["ir_valid"]),
        ir_errors=list(ir_record["ir_errors"]),
        nile_initial=initial["nile_initial"],
        nile_corrected=None,
        nile_evaluated=initial["nile_initial"],
        syntax_valid=bool(initial["syntax_valid"]),
        validator_feedback=initial["validator_feedback"],
        autocorrection_applied=False,
        attempt=1,
        psr=int(initial["psr"]),
        em=int(initial["em"]),
        ed=int(initial["ed"]),
        ned=float(initial["ned"]),
        sla_s=int(initial["sla_s"]),
        sla_f=float(initial["sla_f"]),
        prompt_primary_tokens=int(ir_generation["prompt_tokens"]),
        prompt_secondary_tokens=int(nile_generation["prompt_tokens"]),
        prompt_autocorrection_tokens=None,
        generated_primary_tokens=int(ir_generation["generated_tokens"]),
        generated_secondary_tokens=int(nile_generation["generated_tokens"]),
        generated_autocorrection_tokens=None,
        elapsed_primary_seconds=float(ir_generation["elapsed_seconds"]),
        elapsed_secondary_seconds=float(nile_generation["elapsed_seconds"]),
        elapsed_autocorrection_seconds=None,
        status="completed",
        error=None,
    )
    errors = sorted(result_validator.iter_errors(sem_record), key=lambda error: list(error.path))
    if errors:
        raise ValueError(
            f"Resultado sem_ac inválido em {pipeline_id}: "
            + " | ".join(error.message for error in errors[:5])
        )
    result_records.append(sem_record)

    eligible = bool(initial["eligible_for_autocorrection"])
    if eligible:
        ac_generation = ac_generation_by_pipeline[pipeline_id]
        ac_prompt = prompt_ac_by_pipeline[pipeline_id]
        corrected_evaluation = f3_common.evaluate_nile_output(
            test_record["nile"],
            ac_generation["response_raw"],
            validator,
            nile_metrics,
        )
        final_eval = corrected_evaluation
        nile_corrected = corrected_evaluation["nile"]
        prompt_autocorrection = ac_prompt["prompt"]
        response_autocorrection = ac_generation["response_raw"]
        prompt_autocorrection_tokens = int(ac_generation["prompt_tokens"])
        generated_autocorrection_tokens = int(ac_generation["generated_tokens"])
        elapsed_autocorrection_seconds = float(ac_generation["elapsed_seconds"])
        attempt = 2
    else:
        final_eval = initial
        nile_corrected = None
        prompt_autocorrection = None
        response_autocorrection = None
        prompt_autocorrection_tokens = None
        generated_autocorrection_tokens = None
        elapsed_autocorrection_seconds = None
        attempt = 1

    ac_record = f3_common.make_result_record(
        strategy=ESTRATEGIA,
        variant="primeira_ac",
        fold=int(plan["fold"]),
        id=plan["id"],
        k=int(plan["k"]),
        selection_method=plan["selection_method"],
        selection_label=plan["selection_label"],
        demonstration_ids=list(plan["demonstration_ids"]),
        demonstration_scores=list(plan["demonstration_scores"]),
        nl=test_record["nl"],
        reference_nile=test_record["nile"],
        prompt_primary=prompt_ir_record["prompt"],
        response_primary_raw=ir_generation["response_raw"],
        prompt_secondary=prompt_nile_record["prompt"],
        response_secondary_raw=nile_generation["response_raw"],
        prompt_autocorrection=prompt_autocorrection,
        response_autocorrection_raw=response_autocorrection,
        generated_ir=ir_record["generated_ir"],
        generated_ir_text=ir_record["generated_ir_text"] or ir_record["ir_for_secondary"],
        ir_valid=bool(ir_record["ir_valid"]),
        ir_errors=list(ir_record["ir_errors"]),
        nile_initial=initial["nile_initial"],
        nile_corrected=nile_corrected,
        nile_evaluated=final_eval["nile"] if eligible else initial["nile_initial"],
        syntax_valid=bool(final_eval["psr"]),
        validator_feedback=final_eval.get("validator_feedback", ""),
        autocorrection_applied=eligible,
        attempt=attempt,
        psr=int(final_eval["psr"]),
        em=int(final_eval["em"]),
        ed=int(final_eval["ed"]),
        ned=float(final_eval["ned"]),
        sla_s=int(final_eval["sla_s"]),
        sla_f=float(final_eval["sla_f"]),
        prompt_primary_tokens=int(ir_generation["prompt_tokens"]),
        prompt_secondary_tokens=int(nile_generation["prompt_tokens"]),
        prompt_autocorrection_tokens=prompt_autocorrection_tokens,
        generated_primary_tokens=int(ir_generation["generated_tokens"]),
        generated_secondary_tokens=int(nile_generation["generated_tokens"]),
        generated_autocorrection_tokens=generated_autocorrection_tokens,
        elapsed_primary_seconds=float(ir_generation["elapsed_seconds"]),
        elapsed_secondary_seconds=float(nile_generation["elapsed_seconds"]),
        elapsed_autocorrection_seconds=elapsed_autocorrection_seconds,
        status="completed",
        error=None,
    )
    errors = sorted(result_validator.iter_errors(ac_record), key=lambda error: list(error.path))
    if errors:
        raise ValueError(
            f"Resultado primeira_ac inválido em {pipeline_id}: "
            + " | ".join(error.message for error in errors[:5])
        )
    result_records.append(ac_record)

    comparison_rows.append({
        "pipeline_id": pipeline_id,
        "fold": plan["fold"],
        "id": plan["id"],
        "selection_method": plan["selection_method"],
        "selection_label": plan["selection_label"],
        "k": plan["k"],
        "ir_valid": bool(ir_record["ir_valid"]),
        "autocorrection_applied": eligible,
        "psr_before": int(initial["psr"]),
        "psr_after": int(final_eval["psr"]),
        "em_before": int(initial["em"]),
        "em_after": int(final_eval["em"]),
        "ed_before": int(initial["ed"]),
        "ed_after": int(final_eval["ed"]),
        "ned_before": float(initial["ned"]),
        "ned_after": float(final_eval["ned"]),
        "sla_s_before": int(initial["sla_s"]),
        "sla_s_after": int(final_eval["sla_s"]),
        "sla_f_before": float(initial["sla_f"]),
        "sla_f_after": float(final_eval["sla_f"]),
        "syntax_recovered": int(initial["psr"] == 0 and final_eval["psr"] == 1),
    })

expected_active_results = len(active_plan_records) * 2
if len(result_records) != expected_active_results:
    raise ValueError("Quantidade de resultados consolidados divergente.")

write_jsonl(result_records, RESULTS_JSONL_PATH)
results_df = pd.DataFrame(result_records)
results_df.to_csv(RESULTS_CSV_PATH, index=False, encoding="utf-8")
comparison_df = pd.DataFrame(comparison_rows)
comparison_df.to_csv(COMPARISON_PATH, index=False, encoding="utf-8")
prompt_audit_df = pd.DataFrame(prompt_audit_records)
prompt_audit_df.to_csv(PROMPT_AUDIT_PATH, index=False, encoding="utf-8")

if prompt_audit_df["pending_placeholders"].astype(bool).any():
    raise ValueError("Há placeholders pendentes nos prompts.")
for column in [
    "test_reference_nile_exposed",
    "test_r1_exposed",
    "test_r2_exposed",
    "test_r3_exposed",
]:
    if prompt_audit_df[column].fillna(False).astype(bool).any():
        raise ValueError(f"Há exposição detectada em {column}.")
if not prompt_audit_df["context_ok"].astype(bool).all():
    raise ValueError("Há prompt fora do limite de contexto.")

variant_counts = (
    results_df
    .groupby("variant")
    .size()
    .reset_index(name="records")
)
variant_counts["_ordem_variante"] = (
    variant_counts["variant"]
    .map(ORDEM_VARIANTES_MAPA)
)
variant_counts = (
    variant_counts
    .sort_values("_ordem_variante")
    .drop(columns="_ordem_variante")
    .reset_index(drop=True)
)

exibir_tabela(pd.DataFrame([ac_generation_summary]), "Resumo da primeira autocorreção")
exibir_tabela(variant_counts, "Registros consolidados por variante")

print("Bloco 8 concluído.")
print(f"Elegíveis à autocorreção: {len(eligible_plans)}")
print(f"Autocorreções executadas: {len(ac_generation_records)}")
print(f"Resultados consolidados: {len(result_records)}")
print("Exposição de referências do teste: 0")
print("Status: OK")
# Out:
# F3-C autocorreção: |                                    |   0.00% | 0/242 | decorrido=00:00 | restante=? |
# [001/242] fold_1 | campi_001 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [002/242] fold_1 | campi_020 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [003/242] fold_1 | campi_023 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [004/242] fold_1 | campi_024 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [005/242] fold_1 | campi_027 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [006/242] fold_1 | campi_039 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [007/242] fold_1 | campi_044 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [008/242] fold_1 | campi_001 | Lexical | k=1 | etapa=autocorreção | status=ok
# [009/242] fold_1 | campi_011 | Lexical | k=1 | etapa=autocorreção | status=ok
# [010/242] fold_1 | campi_023 | Lexical | k=1 | etapa=autocorreção | status=ok
# [011/242] fold_1 | campi_024 | Lexical | k=1 | etapa=autocorreção | status=ok
# [012/242] fold_1 | campi_027 | Lexical | k=1 | etapa=autocorreção | status=ok
# [013/242] fold_1 | campi_044 | Lexical | k=1 | etapa=autocorreção | status=ok
# [014/242] fold_1 | campi_001 | Semântica | k=1 | etapa=autocorreção | status=ok
# [015/242] fold_1 | campi_002 | Semântica | k=1 | etapa=autocorreção | status=ok
# [016/242] fold_1 | campi_011 | Semântica | k=1 | etapa=autocorreção | status=ok
# [017/242] fold_1 | campi_020 | Semântica | k=1 | etapa=autocorreção | status=ok
# [018/242] fold_1 | campi_023 | Semântica | k=1 | etapa=autocorreção | status=ok
# [019/242] fold_1 | campi_024 | Semântica | k=1 | etapa=autocorreção | status=ok
# [020/242] fold_1 | campi_044 | Semântica | k=1 | etapa=autocorreção | status=ok
# [021/242] fold_1 | campi_001 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [022/242] fold_1 | campi_002 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [023/242] fold_1 | campi_011 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [024/242] fold_1 | campi_020 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [025/242] fold_1 | campi_023 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [026/242] fold_1 | campi_024 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [027/242] fold_1 | campi_027 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [028/242] fold_1 | campi_039 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [029/242] fold_1 | campi_001 | Lexical | k=3 | etapa=autocorreção | status=ok
# [030/242] fold_1 | campi_002 | Lexical | k=3 | etapa=autocorreção | status=ok
# [031/242] fold_1 | campi_011 | Lexical | k=3 | etapa=autocorreção | status=ok
# [032/242] fold_1 | campi_023 | Lexical | k=3 | etapa=autocorreção | status=ok
# [033/242] fold_1 | campi_027 | Lexical | k=3 | etapa=autocorreção | status=ok
# [034/242] fold_1 | campi_044 | Lexical | k=3 | etapa=autocorreção | status=ok
# [035/242] fold_1 | campi_001 | Semântica | k=3 | etapa=autocorreção | status=ok
# [036/242] fold_1 | campi_002 | Semântica | k=3 | etapa=autocorreção | status=ok
# [037/242] fold_1 | campi_023 | Semântica | k=3 | etapa=autocorreção | status=ok
# [038/242] fold_1 | campi_024 | Semântica | k=3 | etapa=autocorreção | status=ok
# [039/242] fold_1 | campi_044 | Semântica | k=3 | etapa=autocorreção | status=ok
# [040/242] fold_1 | campi_002 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [041/242] fold_1 | campi_011 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [042/242] fold_1 | campi_020 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [043/242] fold_1 | campi_023 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [044/242] fold_1 | campi_024 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [045/242] fold_1 | campi_027 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [046/242] fold_1 | campi_039 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [047/242] fold_1 | campi_002 | Lexical | k=5 | etapa=autocorreção | status=ok
# [048/242] fold_1 | campi_011 | Lexical | k=5 | etapa=autocorreção | status=ok
# [049/242] fold_1 | campi_023 | Lexical | k=5 | etapa=autocorreção | status=ok
# [050/242] fold_1 | campi_044 | Lexical | k=5 | etapa=autocorreção | status=ok
# [051/242] fold_1 | campi_001 | Semântica | k=5 | etapa=autocorreção | status=ok
# [052/242] fold_1 | campi_002 | Semântica | k=5 | etapa=autocorreção | status=ok
# [053/242] fold_1 | campi_011 | Semântica | k=5 | etapa=autocorreção | status=ok
# [054/242] fold_1 | campi_020 | Semântica | k=5 | etapa=autocorreção | status=ok
# [055/242] fold_1 | campi_023 | Semântica | k=5 | etapa=autocorreção | status=ok
# [056/242] fold_1 | campi_044 | Semântica | k=5 | etapa=autocorreção | status=ok
# [057/242] fold_2 | campi_006 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [058/242] fold_2 | campi_009 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [059/242] fold_2 | campi_010 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [060/242] fold_2 | campi_028 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [061/242] fold_2 | campi_031 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [062/242] fold_2 | campi_034 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [063/242] fold_2 | campi_041 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [064/242] fold_2 | campi_041 | Lexical | k=1 | etapa=autocorreção | status=ok
# [065/242] fold_2 | campi_010 | Semântica | k=1 | etapa=autocorreção | status=ok
# [066/242] fold_2 | campi_017 | Semântica | k=1 | etapa=autocorreção | status=ok
# [067/242] fold_2 | campi_041 | Semântica | k=1 | etapa=autocorreção | status=ok
# [068/242] fold_2 | campi_043 | Semântica | k=1 | etapa=autocorreção | status=ok
# [069/242] fold_2 | campi_048 | Semântica | k=1 | etapa=autocorreção | status=ok
# [070/242] fold_2 | campi_006 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [071/242] fold_2 | campi_009 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [072/242] fold_2 | campi_028 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [073/242] fold_2 | campi_031 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [074/242] fold_2 | campi_041 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [075/242] fold_2 | campi_043 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [076/242] fold_2 | campi_028 | Lexical | k=3 | etapa=autocorreção | status=ok
# [077/242] fold_2 | campi_031 | Lexical | k=3 | etapa=autocorreção | status=ok
# [078/242] fold_2 | campi_041 | Lexical | k=3 | etapa=autocorreção | status=ok
# [079/242] fold_2 | campi_017 | Semântica | k=3 | etapa=autocorreção | status=ok
# [080/242] fold_2 | campi_031 | Semântica | k=3 | etapa=autocorreção | status=ok
# [081/242] fold_2 | campi_041 | Semântica | k=3 | etapa=autocorreção | status=ok
# [082/242] fold_2 | campi_043 | Semântica | k=3 | etapa=autocorreção | status=ok
# [083/242] fold_2 | campi_009 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [084/242] fold_2 | campi_028 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [085/242] fold_2 | campi_031 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [086/242] fold_2 | campi_041 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [087/242] fold_2 | campi_043 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [088/242] fold_2 | campi_028 | Lexical | k=5 | etapa=autocorreção | status=ok
# [089/242] fold_2 | campi_031 | Lexical | k=5 | etapa=autocorreção | status=ok
# [090/242] fold_2 | campi_041 | Lexical | k=5 | etapa=autocorreção | status=ok
# [091/242] fold_2 | campi_043 | Lexical | k=5 | etapa=autocorreção | status=ok
# [092/242] fold_2 | campi_028 | Semântica | k=5 | etapa=autocorreção | status=ok
# [093/242] fold_2 | campi_043 | Semântica | k=5 | etapa=autocorreção | status=ok
# [094/242] fold_3 | campi_003 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [095/242] fold_3 | campi_014 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [096/242] fold_3 | campi_018 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [097/242] fold_3 | campi_025 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [098/242] fold_3 | campi_026 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [099/242] fold_3 | campi_033 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [100/242] fold_3 | campi_035 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [101/242] fold_3 | campi_045 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [102/242] fold_3 | campi_026 | Lexical | k=1 | etapa=autocorreção | status=ok
# [103/242] fold_3 | campi_045 | Lexical | k=1 | etapa=autocorreção | status=ok
# [104/242] fold_3 | campi_007 | Semântica | k=1 | etapa=autocorreção | status=ok
# [105/242] fold_3 | campi_025 | Semântica | k=1 | etapa=autocorreção | status=ok
# [106/242] fold_3 | campi_026 | Semântica | k=1 | etapa=autocorreção | status=ok
# [107/242] fold_3 | campi_045 | Semântica | k=1 | etapa=autocorreção | status=ok
# [108/242] fold_3 | campi_003 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [109/242] fold_3 | campi_007 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [110/242] fold_3 | campi_014 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [111/242] fold_3 | campi_018 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [112/242] fold_3 | campi_025 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [113/242] fold_3 | campi_026 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [114/242] fold_3 | campi_033 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [115/242] fold_3 | campi_035 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [116/242] fold_3 | campi_045 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [117/242] fold_3 | campi_047 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [118/242] fold_3 | campi_025 | Lexical | k=3 | etapa=autocorreção | status=ok
# [119/242] fold_3 | campi_026 | Lexical | k=3 | etapa=autocorreção | status=ok
# [120/242] fold_3 | campi_045 | Lexical | k=3 | etapa=autocorreção | status=ok
# [121/242] fold_3 | campi_047 | Lexical | k=3 | etapa=autocorreção | status=ok
# [122/242] fold_3 | campi_025 | Semântica | k=3 | etapa=autocorreção | status=ok
# [123/242] fold_3 | campi_033 | Semântica | k=3 | etapa=autocorreção | status=ok
# [124/242] fold_3 | campi_045 | Semântica | k=3 | etapa=autocorreção | status=ok
# [125/242] fold_3 | campi_047 | Semântica | k=3 | etapa=autocorreção | status=ok
# [126/242] fold_3 | campi_003 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [127/242] fold_3 | campi_007 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [128/242] fold_3 | campi_018 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [129/242] fold_3 | campi_025 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [130/242] fold_3 | campi_026 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [131/242] fold_3 | campi_033 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [132/242] fold_3 | campi_035 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [133/242] fold_3 | campi_047 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [134/242] fold_3 | campi_026 | Lexical | k=5 | etapa=autocorreção | status=ok
# [135/242] fold_3 | campi_033 | Lexical | k=5 | etapa=autocorreção | status=ok
# [136/242] fold_3 | campi_045 | Lexical | k=5 | etapa=autocorreção | status=ok
# [137/242] fold_3 | campi_047 | Lexical | k=5 | etapa=autocorreção | status=ok
# [138/242] fold_3 | campi_033 | Semântica | k=5 | etapa=autocorreção | status=ok
# [139/242] fold_3 | campi_045 | Semântica | k=5 | etapa=autocorreção | status=ok
# [140/242] fold_3 | campi_047 | Semântica | k=5 | etapa=autocorreção | status=ok
# [141/242] fold_4 | campi_005 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [142/242] fold_4 | campi_016 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [143/242] fold_4 | campi_019 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [144/242] fold_4 | campi_021 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [145/242] fold_4 | campi_032 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [146/242] fold_4 | campi_036 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [147/242] fold_4 | campi_037 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [148/242] fold_4 | campi_040 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [149/242] fold_4 | campi_046 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [150/242] fold_4 | campi_050 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [151/242] fold_4 | campi_032 | Lexical | k=1 | etapa=autocorreção | status=ok
# [152/242] fold_4 | campi_005 | Semântica | k=1 | etapa=autocorreção | status=ok
# [153/242] fold_4 | campi_032 | Semântica | k=1 | etapa=autocorreção | status=ok
# [154/242] fold_4 | campi_050 | Semântica | k=1 | etapa=autocorreção | status=ok
# [155/242] fold_4 | campi_005 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [156/242] fold_4 | campi_016 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [157/242] fold_4 | campi_019 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [158/242] fold_4 | campi_021 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [159/242] fold_4 | campi_032 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [160/242] fold_4 | campi_036 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [161/242] fold_4 | campi_037 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [162/242] fold_4 | campi_040 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [163/242] fold_4 | campi_046 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [164/242] fold_4 | campi_050 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [165/242] fold_4 | campi_021 | Lexical | k=3 | etapa=autocorreção | status=ok
# [166/242] fold_4 | campi_032 | Lexical | k=3 | etapa=autocorreção | status=ok
# [167/242] fold_4 | campi_050 | Lexical | k=3 | etapa=autocorreção | status=ok
# [168/242] fold_4 | campi_032 | Semântica | k=3 | etapa=autocorreção | status=ok
# [169/242] fold_4 | campi_005 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [170/242] fold_4 | campi_016 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [171/242] fold_4 | campi_019 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [172/242] fold_4 | campi_021 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [173/242] fold_4 | campi_032 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [174/242] fold_4 | campi_036 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [175/242] fold_4 | campi_037 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [176/242] fold_4 | campi_040 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [177/242] fold_4 | campi_046 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [178/242] fold_4 | campi_032 | Lexical | k=5 | etapa=autocorreção | status=ok
# [179/242] fold_4 | campi_046 | Lexical | k=5 | etapa=autocorreção | status=ok
# [180/242] fold_4 | campi_050 | Lexical | k=5 | etapa=autocorreção | status=ok
# [181/242] fold_4 | campi_032 | Semântica | k=5 | etapa=autocorreção | status=ok
# [182/242] fold_4 | campi_050 | Semântica | k=5 | etapa=autocorreção | status=ok
# [183/242] fold_5 | campi_004 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [184/242] fold_5 | campi_008 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [185/242] fold_5 | campi_015 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [186/242] fold_5 | campi_029 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [187/242] fold_5 | campi_030 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [188/242] fold_5 | campi_038 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [189/242] fold_5 | campi_042 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [190/242] fold_5 | campi_049 | Aleatória | k=1 | etapa=autocorreção | status=ok
# [191/242] fold_5 | campi_004 | Lexical | k=1 | etapa=autocorreção | status=ok
# [192/242] fold_5 | campi_008 | Lexical | k=1 | etapa=autocorreção | status=ok
# [193/242] fold_5 | campi_029 | Lexical | k=1 | etapa=autocorreção | status=ok
# [194/242] fold_5 | campi_038 | Lexical | k=1 | etapa=autocorreção | status=ok
# [195/242] fold_5 | campi_042 | Lexical | k=1 | etapa=autocorreção | status=ok
# [196/242] fold_5 | campi_049 | Lexical | k=1 | etapa=autocorreção | status=ok
# [197/242] fold_5 | campi_004 | Semântica | k=1 | etapa=autocorreção | status=ok
# [198/242] fold_5 | campi_008 | Semântica | k=1 | etapa=autocorreção | status=ok
# [199/242] fold_5 | campi_029 | Semântica | k=1 | etapa=autocorreção | status=ok
# [200/242] fold_5 | campi_042 | Semântica | k=1 | etapa=autocorreção | status=ok
# [201/242] fold_5 | campi_049 | Semântica | k=1 | etapa=autocorreção | status=ok
# [202/242] fold_5 | campi_004 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [203/242] fold_5 | campi_008 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [204/242] fold_5 | campi_013 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [205/242] fold_5 | campi_015 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [206/242] fold_5 | campi_022 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [207/242] fold_5 | campi_029 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [208/242] fold_5 | campi_030 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [209/242] fold_5 | campi_038 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [210/242] fold_5 | campi_042 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [211/242] fold_5 | campi_049 | Aleatória | k=3 | etapa=autocorreção | status=ok
# [212/242] fold_5 | campi_004 | Lexical | k=3 | etapa=autocorreção | status=ok
# [213/242] fold_5 | campi_008 | Lexical | k=3 | etapa=autocorreção | status=ok
# [214/242] fold_5 | campi_029 | Lexical | k=3 | etapa=autocorreção | status=ok
# [215/242] fold_5 | campi_038 | Lexical | k=3 | etapa=autocorreção | status=ok
# [216/242] fold_5 | campi_004 | Semântica | k=3 | etapa=autocorreção | status=ok
# [217/242] fold_5 | campi_008 | Semântica | k=3 | etapa=autocorreção | status=ok
# [218/242] fold_5 | campi_015 | Semântica | k=3 | etapa=autocorreção | status=ok
# [219/242] fold_5 | campi_029 | Semântica | k=3 | etapa=autocorreção | status=ok
# [220/242] fold_5 | campi_038 | Semântica | k=3 | etapa=autocorreção | status=ok
# [221/242] fold_5 | campi_042 | Semântica | k=3 | etapa=autocorreção | status=ok
# [222/242] fold_5 | campi_049 | Semântica | k=3 | etapa=autocorreção | status=ok
# [223/242] fold_5 | campi_004 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [224/242] fold_5 | campi_008 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [225/242] fold_5 | campi_015 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [226/242] fold_5 | campi_022 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [227/242] fold_5 | campi_029 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [228/242] fold_5 | campi_030 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [229/242] fold_5 | campi_038 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [230/242] fold_5 | campi_042 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [231/242] fold_5 | campi_049 | Aleatória | k=5 | etapa=autocorreção | status=ok
# [232/242] fold_5 | campi_004 | Lexical | k=5 | etapa=autocorreção | status=ok
# [233/242] fold_5 | campi_008 | Lexical | k=5 | etapa=autocorreção | status=ok
# [234/242] fold_5 | campi_029 | Lexical | k=5 | etapa=autocorreção | status=ok
# [235/242] fold_5 | campi_038 | Lexical | k=5 | etapa=autocorreção | status=ok
# [236/242] fold_5 | campi_042 | Lexical | k=5 | etapa=autocorreção | status=ok
# [237/242] fold_5 | campi_004 | Semântica | k=5 | etapa=autocorreção | status=ok
# [238/242] fold_5 | campi_008 | Semântica | k=5 | etapa=autocorreção | status=ok
# [239/242] fold_5 | campi_029 | Semântica | k=5 | etapa=autocorreção | status=ok
# [240/242] fold_5 | campi_030 | Semântica | k=5 | etapa=autocorreção | status=ok
# [241/242] fold_5 | campi_042 | Semântica | k=5 | etapa=autocorreção | status=ok
# [242/242] fold_5 | campi_049 | Semântica | k=5 | etapa=autocorreção | status=ok
#     <div style="font-weight:600;font-size:15px;margin:8px 0 6px;color:#f1f1f1;">
#         Tabela 14. Resumo da primeira autocorreção
#     </div>
#     <div class="container_tabela_saida" style="display:inline-block;max-width:100%;overflow-x:auto;overflow-y: visible;border:none;margin:8px 0 12px;">
#         <style>
#             .container_tabela_saida table.tabela_saida {
#                 border-collapse:collapse !important;
#                 table-layout:auto !important;
#                 width:auto !important;
#                 font-family:Arial,sans-serif !important;
#                 font-size:13px !important;
#                 background:#111 !important;
#                 color:#f1f1f1 !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida thead th {
#                 position:sticky !important;
#                 top:0 !important;
#                 z-index:2 !important;
#                 background:#2b2b2b !important;
#                 color:#fff !important;
#                 padding:7px !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #777 !important;
#                 border-bottom:2px solid #888 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody td {
#                 padding:7px !important;
#                 vertical-align:top !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(even) td {background:#1b1b1b !important;}
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(odd) td {background:#111 !important;}
#         </style>
#         <table class="dataframe tabela_saida">
#   <thead>
#     <tr style="text-align: left;">
#       <th>etapa</th>
#       <th>requested</th>
#       <th>generated</th>
#       <th>reused</th>
#       <th>stale ignored</th>
#       <th>tokens do prompt</th>
#       <th>tokens gerados</th>
#       <th>tempo decorrido</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>autocorreção</td>
#       <td>242</td>
#       <td>242</td>
#       <td>0</td>
#       <td>0</td>
#       <td>255782</td>
#       <td>5374</td>
#       <td>05min 16s</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
#     <div style="font-weight:600;font-size:15px;margin:8px 0 6px;color:#f1f1f1;">
#         Tabela 15. Registros consolidados por variante
#     </div>
#     <div class="container_tabela_saida" style="display:inline-block;max-width:100%;overflow-x:auto;overflow-y: visible;border:none;margin:8px 0 12px;">
#         <style>
#             .container_tabela_saida table.tabela_saida {
#                 border-collapse:collapse !important;
#                 table-layout:auto !important;
#                 width:auto !important;
#                 font-family:Arial,sans-serif !important;
#                 font-size:13px !important;
#                 background:#111 !important;
#                 color:#f1f1f1 !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida thead th {
#                 position:sticky !important;
#                 top:0 !important;
#                 z-index:2 !important;
#                 background:#2b2b2b !important;
#                 color:#fff !important;
#                 padding:7px !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #777 !important;
#                 border-bottom:2px solid #888 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody td {
#                 padding:7px !important;
#                 vertical-align:top !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(even) td {background:#1b1b1b !important;}
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(odd) td {background:#111 !important;}
#         </style>
#         <table class="dataframe tabela_saida">
#   <thead>
#     <tr style="text-align: left;">
#       <th>variante</th>
#       <th>registros</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>sem_ac</td>
#       <td>450</td>
#     </tr>
#     <tr>
#       <td>primeira_ac</td>
#       <td>450</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
# Bloco 8 concluído.
# Elegíveis à autocorreção: 242
# Autocorreções executadas: 242
# Resultados consolidados: 900
# Exposição de referências do teste: 0
# Status: OK

# %% [markdown]
# ## Bloco 9 - Tabelas, comparações e gráficos
#
# ### Objetivo
#
# Este bloco organiza os resultados da F3-C para análise metodológica e posterior consolidação na F4.
#
# ### Resumos produzidos
#
# São construídos:
#
# - desempenho por variante, método e `k`;
# - desempenho por fold, variante, método e `k`;
# - validade da IR por método e `k`;
# - auditoria operacional dos três estágios;
# - saídas inválidas sem autocorreção;
# - saídas ainda inválidas após a primeira autocorreção;
# - comparação individual antes e depois da autocorreção;
# - ganhos agregados;
# - análise pelos 50 exemplos.
#
# ### Ordem oficial
#
# As tabelas e gráficos seguem sempre:
#
# ```text
# Aleatória
# Lexical
# Semântica
# ```
#
# Os valores de `k` aparecem em ordem crescente. A variante sem autocorreção é apresentada antes da primeira autocorreção.
#
# ### Gráficos
#
# São gerados doze gráficos independentes:
#
# - seis métricas para `sem_ac`;
# - seis métricas para `primeira_ac`.
#
# Cada gráfico apresenta as três linhas dos métodos para `k=1`, `k=3` e `k=5`.
#
# ### Resultado esperado
#
# Os arquivos tabulares e visuais permitirão avaliar tanto o efeito da IR quanto o ganho específico da primeira autocorreção.

# %%
# ----------------------------------------------------------
# 9.1 Resumos por condição e por fold
# ----------------------------------------------------------

summary_df = (
    results_df.groupby(
        ["variant", "selection_method", "selection_label", "k"],
        dropna=False,
    )
    .agg(
        records=("id", "count"),
        ir_valid=("ir_valid", "sum"),
        psr=("psr", "mean"),
        em=("em", "mean"),
        ed=("ed", "mean"),
        ned=("ned", "mean"),
        sla_s=("sla_s", "mean"),
        sla_f=("sla_f", "mean"),
        syntax_valid=("syntax_valid", "sum"),
        autocorrection_applied=("autocorrection_applied", "sum"),
        prompt_primary_tokens=("prompt_primary_tokens", "mean"),
        prompt_secondary_tokens=("prompt_secondary_tokens", "mean"),
        prompt_autocorrection_tokens=("prompt_autocorrection_tokens", "mean"),
        generated_primary_tokens=("generated_primary_tokens", "mean"),
        generated_secondary_tokens=("generated_secondary_tokens", "mean"),
        generated_autocorrection_tokens=("generated_autocorrection_tokens", "mean"),
        elapsed_primary_seconds=("elapsed_primary_seconds", "mean"),
        elapsed_secondary_seconds=("elapsed_secondary_seconds", "mean"),
        elapsed_autocorrection_seconds=("elapsed_autocorrection_seconds", "mean"),
    )
    .reset_index()
)
summary_df["_ordem_variante"] = summary_df["variant"].map(ORDEM_VARIANTES_MAPA)
summary_df["_ordem_metodo"] = summary_df["selection_method"].map(ORDEM_METODOS_MAPA)
summary_df = (
    summary_df
    .sort_values(["_ordem_variante", "k", "_ordem_metodo"])
    .drop(columns=["_ordem_variante", "_ordem_metodo"])
    .reset_index(drop=True)
)
summary_df.to_csv(SUMMARY_PATH, index=False, encoding="utf-8")

summary_fold_df = (
    results_df.groupby(
        ["fold", "variant", "selection_method", "selection_label", "k"],
        dropna=False,
    )
    .agg(
        records=("id", "count"),
        ir_valid=("ir_valid", "sum"),
        psr=("psr", "mean"),
        em=("em", "mean"),
        ed=("ed", "mean"),
        ned=("ned", "mean"),
        sla_s=("sla_s", "mean"),
        sla_f=("sla_f", "mean"),
    )
    .reset_index()
)
summary_fold_df["_ordem_variante"] = summary_fold_df["variant"].map(ORDEM_VARIANTES_MAPA)
summary_fold_df["_ordem_metodo"] = summary_fold_df["selection_method"].map(ORDEM_METODOS_MAPA)
summary_fold_df = (
    summary_fold_df
    .sort_values(["fold", "_ordem_variante", "k", "_ordem_metodo"])
    .drop(columns=["_ordem_variante", "_ordem_metodo"])
    .reset_index(drop=True)
)
summary_fold_df.to_csv(SUMMARY_FOLD_PATH, index=False, encoding="utf-8")

ir_summary_df = (
    ir_validation_df.groupby(["selection_method", "selection_label", "k"], dropna=False)
    .agg(
        records=("id", "count"),
        ir_extracted=("ir_extracted", "sum"),
        ir_valid=("ir_valid", "sum"),
    )
    .reset_index()
)
ir_summary_df["ir_valid_rate"] = ir_summary_df["ir_valid"] / ir_summary_df["records"]
ir_summary_df["_ordem_metodo"] = ir_summary_df["selection_method"].map(ORDEM_METODOS_MAPA)
ir_summary_df = (
    ir_summary_df
    .sort_values(["k", "_ordem_metodo"])
    .drop(columns="_ordem_metodo")
    .reset_index(drop=True)
)
ir_summary_df.to_csv(IR_SUMMARY_PATH, index=False, encoding="utf-8")


# ----------------------------------------------------------
# 9.2 Saídas inválidas, comparação e ganhos
# ----------------------------------------------------------

invalid_sem_ac_df = results_df.loc[
    (results_df["variant"] == "sem_ac")
    & (~results_df["syntax_valid"].astype(bool))
].copy()
invalid_primeira_ac_df = results_df.loc[
    (results_df["variant"] == "primeira_ac")
    & (~results_df["syntax_valid"].astype(bool))
].copy()

for frame in [invalid_sem_ac_df, invalid_primeira_ac_df]:
    frame["_ordem_metodo"] = frame["selection_method"].map(ORDEM_METODOS_MAPA)
    frame.sort_values(["fold", "k", "_ordem_metodo", "id"], inplace=True)
    frame.drop(columns="_ordem_metodo", inplace=True)

invalid_sem_ac_df.to_csv(INVALID_SEM_AC_PATH, index=False, encoding="utf-8")
invalid_primeira_ac_df.to_csv(INVALID_PRIMEIRA_AC_PATH, index=False, encoding="utf-8")

final_ac_eligible_df = results_df.loc[
    (results_df["variant"] == "primeira_ac")
    & (results_df["psr"] == 0)
].copy()
final_ac_eligible_df["_ordem_metodo"] = final_ac_eligible_df["selection_method"].map(ORDEM_METODOS_MAPA)
final_ac_eligible_df = (
    final_ac_eligible_df
    .sort_values(["fold", "k", "_ordem_metodo", "id"])
    .drop(columns="_ordem_metodo")
    .reset_index(drop=True)
)
final_ac_eligible_df.to_csv(FINAL_AC_ELIGIBLE_PATH, index=False, encoding="utf-8")

gains_df = (
    comparison_df.groupby(["selection_method", "selection_label", "k"], dropna=False)
    .agg(
        records=("id", "count"),
        autocorrections=("autocorrection_applied", "sum"),
        syntax_recovered=("syntax_recovered", "sum"),
        psr_before=("psr_before", "mean"),
        psr_after=("psr_after", "mean"),
        em_before=("em_before", "mean"),
        em_after=("em_after", "mean"),
        ed_before=("ed_before", "mean"),
        ed_after=("ed_after", "mean"),
        ned_before=("ned_before", "mean"),
        ned_after=("ned_after", "mean"),
        sla_s_before=("sla_s_before", "mean"),
        sla_s_after=("sla_s_after", "mean"),
        sla_f_before=("sla_f_before", "mean"),
        sla_f_after=("sla_f_after", "mean"),
    )
    .reset_index()
)
for metric in METRICAS:
    gains_df[f"delta_{metric}"] = gains_df[f"{metric}_after"] - gains_df[f"{metric}_before"]
gains_df["_ordem_metodo"] = gains_df["selection_method"].map(ORDEM_METODOS_MAPA)
gains_df = (
    gains_df
    .sort_values(["k", "_ordem_metodo"])
    .drop(columns="_ordem_metodo")
    .reset_index(drop=True)
)
gains_df.to_csv(GAINS_PATH, index=False, encoding="utf-8")


# ----------------------------------------------------------
# 9.3 Análise por exemplo e auditoria de execução
# ----------------------------------------------------------

analysis_long_df = (
    results_df.groupby(["id", "variant"], dropna=False)
    .agg(
        records=("k", "count"),
        ir_valid_rate=("ir_valid", "mean"),
        psr=("psr", "mean"),
        em=("em", "mean"),
        ed=("ed", "mean"),
        ned=("ned", "mean"),
        sla_s=("sla_s", "mean"),
        sla_f=("sla_f", "mean"),
    )
    .reset_index()
)
analysis_example_df = analysis_long_df.pivot(index="id", columns="variant")
analysis_example_df.columns = [f"{metric}_{variant}" for metric, variant in analysis_example_df.columns]
analysis_example_df = analysis_example_df.reset_index().sort_values("id").reset_index(drop=True)
analysis_example_df.to_csv(ANALYSIS_EXAMPLE_PATH, index=False, encoding="utf-8")

execution_audit_df = (
    comparison_df.groupby(["selection_method", "selection_label", "k"], dropna=False)
    .agg(
        records=("id", "count"),
        ir_valid=("ir_valid", "sum"),
        syntax_valid_before=("psr_before", "sum"),
        syntax_valid_after=("psr_after", "sum"),
        autocorrections=("autocorrection_applied", "sum"),
        syntax_recovered=("syntax_recovered", "sum"),
    )
    .reset_index()
)
execution_audit_df["_ordem_metodo"] = execution_audit_df["selection_method"].map(ORDEM_METODOS_MAPA)
execution_audit_df = (
    execution_audit_df
    .sort_values(["k", "_ordem_metodo"])
    .drop(columns="_ordem_metodo")
    .reset_index(drop=True)
)
execution_audit_df.to_csv(EXECUTION_AUDIT_PATH, index=False, encoding="utf-8")


# ----------------------------------------------------------
# 9.4 Tabelas principais
# ----------------------------------------------------------

summary_sem_df = summary_df.loc[summary_df["variant"] == "sem_ac"].copy()
summary_ac_df = summary_df.loc[summary_df["variant"] == "primeira_ac"].copy()

exibir_tabela(ir_summary_df, "Validade das IRs por método e k")
exibir_tabela(summary_sem_df, "Desempenho da F3-C sem autocorreção")
exibir_tabela(summary_ac_df, "Desempenho da F3-C com primeira autocorreção")
exibir_tabela(gains_df, "Ganhos da primeira autocorreção", altura_px=420)
exibir_tabela(summary_fold_df, "Desempenho por fold, variante, método e k", altura_px=520)


# ----------------------------------------------------------
# 9.5 Gráficos das métricas
# ----------------------------------------------------------

import matplotlib.pyplot as plt
import numpy as np

LIMITES_EIXO_Y = {
    "psr": (-0.03, 1.03),
    "em": (-0.03, 1.03),
    "ed": (0.0, 100.0),
    "ned": (-0.03, 1.03),
    "sla_s": (-0.03, 1.03),
    "sla_f": (-0.03, 1.03),
}

TICKS_EIXO_Y = {
    "psr": np.arange(0.0, 1.01, 0.2),
    "em": np.arange(0.0, 1.01, 0.2),
    "ed": np.arange(0.0, 100.1, 20.0),
    "ned": np.arange(0.0, 1.01, 0.2),
    "sla_s": np.arange(0.0, 1.01, 0.2),
    "sla_f": np.arange(0.0, 1.01, 0.2),
}


# ----------------------------------------------------------
# 9.5.1 Auditoria dos limites fixos
# ----------------------------------------------------------

auditoria_limites = []

for metric in METRICAS:
    limite_inferior, limite_superior = LIMITES_EIXO_Y[metric]
    valor_minimo = float(summary_df[metric].min())
    valor_maximo = float(summary_df[metric].max())

    dentro_do_limite = (
        valor_minimo >= limite_inferior
        and valor_maximo <= limite_superior
    )

    auditoria_limites.append({
        "métrica": ROTULOS_METRICAS[metric],
        "mínimo observado": valor_minimo,
        "máximo observado": valor_maximo,
        "limite inferior": limite_inferior,
        "limite superior": limite_superior,
        "dentro do limite": dentro_do_limite,
    })

auditoria_limites_df = pd.DataFrame(auditoria_limites)

if not auditoria_limites_df["dentro do limite"].all():
    metricas_fora = auditoria_limites_df.loc[
        ~auditoria_limites_df["dentro do limite"],
        "métrica",
    ].astype(str).tolist()

    raise ValueError(
        "Há métricas fora dos limites gráficos padronizados: "
        + ", ".join(metricas_fora)
        + ". Os limites devem ser revistos de forma global para "
        "todas as estratégias antes da geração dos gráficos."
    )

exibir_tabela(
    auditoria_limites_df,
    "Auditoria dos limites fixos dos gráficos",
)


# ----------------------------------------------------------
# 9.5.2 Geração dos gráficos padronizados
# ----------------------------------------------------------

GRAFICOS_PATHS = {}

for variant in ORDEM_VARIANTES_EXIBICAO:
    variant_df = summary_df.loc[
        summary_df["variant"] == variant
    ].copy()

    for metric in METRICAS:
        fig, ax = plt.subplots(figsize=(8.5, 5.2))

        for method in ORDEM_METODOS_EXIBICAO:
            method_df = (
                variant_df.loc[
                    variant_df["selection_method"] == method
                ]
                .sort_values("k")
            )

            if method_df.empty:
                continue

            ax.plot(
                method_df["k"],
                method_df[metric],
                marker="o",
                linewidth=2,
                label=ROTULOS_METODOS[method],
                color=CORES_METODOS[method],
            )

        ax.set_title(
            f"F3-C {ROTULOS_VARIANTES[variant]} - "
            f"{ROTULOS_METRICAS[metric]} por método e k"
        )
        ax.set_xlabel("k")
        ax.set_ylabel(ROTULOS_METRICAS[metric])
        ax.set_xticks(K_FEWSHOT)

        limite_inferior, limite_superior = LIMITES_EIXO_Y[metric]
        ax.set_ylim(limite_inferior, limite_superior)
        ax.set_yticks(TICKS_EIXO_Y[metric])

        ax.grid(True, alpha=0.25)
        ax.legend()
        fig.tight_layout()

        graph_path = (
            GRAFICOS_DIR
            / f"f3c_{variant}_{metric}.png"
        )
        fig.savefig(
            graph_path,
            dpi=160,
            bbox_inches="tight",
        )
        plt.show()
        plt.close(fig)

        GRAFICOS_PATHS[(variant, metric)] = graph_path


print("Bloco 9 concluído.")
print(f"Condições resumidas: {len(summary_df)}")
print(f"Gráficos produzidos: {len(GRAFICOS_PATHS)}")
print(
    "Escalas fixas aplicadas: "
    "PSR, EM, NED, SLA-S e SLA-F de 0 a 1; "
    "ED de 0 a 100."
)
print(
    "Elegíveis à autocorreção final por PSR=0: "
    f"{len(final_ac_eligible_df)}"
)
print("Status: OK")
# Out:
#     <div style="font-weight:600;font-size:15px;margin:8px 0 6px;color:#f1f1f1;">
#         Tabela 16. Validade das IRs por método e k
#     </div>
#     <div class="container_tabela_saida" style="display:inline-block;max-width:100%;overflow-x:auto;overflow-y: visible;border:none;margin:8px 0 12px;">
#         <style>
#             .container_tabela_saida table.tabela_saida {
#                 border-collapse:collapse !important;
#                 table-layout:auto !important;
#                 width:auto !important;
#                 font-family:Arial,sans-serif !important;
#                 font-size:13px !important;
#                 background:#111 !important;
#                 color:#f1f1f1 !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida thead th {
#                 position:sticky !important;
#                 top:0 !important;
#                 z-index:2 !important;
#                 background:#2b2b2b !important;
#                 color:#fff !important;
#                 padding:7px !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #777 !important;
#                 border-bottom:2px solid #888 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody td {
#                 padding:7px !important;
#                 vertical-align:top !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(even) td {background:#1b1b1b !important;}
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(odd) td {background:#111 !important;}
#         </style>
#         <table class="dataframe tabela_saida">
#   <thead>
#     <tr style="text-align: left;">
#       <th>método de seleção</th>
#       <th>rótulo do método</th>
#       <th>k</th>
#       <th>registros</th>
#       <th>IR extraída</th>
#       <th>validade da IR</th>
#       <th>ir valid rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>random_seed42</td>
#       <td>Aleatória</td>
#       <td>1</td>
#       <td>50</td>
#       <td>50</td>
#       <td>11</td>
#       <td>0.22</td>
#     </tr>
#     <tr>
#       <td>lexical_tfidf</td>
#       <td>Lexical</td>
#       <td>1</td>
#       <td>50</td>
#       <td>50</td>
#       <td>35</td>
#       <td>0.70</td>
#     </tr>
#     <tr>
#       <td>semantic_embeddings</td>
#       <td>Semântica</td>
#       <td>1</td>
#       <td>50</td>
#       <td>50</td>
#       <td>30</td>
#       <td>0.60</td>
#     </tr>
#     <tr>
#       <td>random_seed42</td>
#       <td>Aleatória</td>
#       <td>3</td>
#       <td>50</td>
#       <td>50</td>
#       <td>5</td>
#       <td>0.10</td>
#     </tr>
#     <tr>
#       <td>lexical_tfidf</td>
#       <td>Lexical</td>
#       <td>3</td>
#       <td>50</td>
#       <td>50</td>
#       <td>29</td>
#       <td>0.58</td>
#     </tr>
#     <tr>
#       <td>semantic_embeddings</td>
#       <td>Semântica</td>
#       <td>3</td>
#       <td>50</td>
#       <td>50</td>
#       <td>28</td>
#       <td>0.56</td>
#     </tr>
#     <tr>
#       <td>random_seed42</td>
#       <td>Aleatória</td>
#       <td>5</td>
#       <td>50</td>
#       <td>50</td>
#       <td>13</td>
#       <td>0.26</td>
#     </tr>
#     <tr>
#       <td>lexical_tfidf</td>
#       <td>Lexical</td>
#       <td>5</td>
#       <td>50</td>
#       <td>50</td>
#       <td>29</td>
#       <td>0.58</td>
#     </tr>
#     <tr>
#       <td>semantic_embeddings</td>
#       <td>Semântica</td>
#       <td>5</td>
#       <td>50</td>
#       <td>50</td>
#       <td>30</td>
#       <td>0.60</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
#     <div style="font-weight:600;font-size:15px;margin:8px 0 6px;color:#f1f1f1;">
#         Tabela 17. Desempenho da F3-C sem autocorreção
#     </div>
#     <div class="container_tabela_saida" style="display:inline-block;max-width:100%;overflow-x:auto;overflow-y: visible;border:none;margin:8px 0 12px;">
#         <style>
#             .container_tabela_saida table.tabela_saida {
#                 border-collapse:collapse !important;
#                 table-layout:auto !important;
#                 width:auto !important;
#                 font-family:Arial,sans-serif !important;
#                 font-size:13px !important;
#                 background:#111 !important;
#                 color:#f1f1f1 !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida thead th {
#                 position:sticky !important;
#                 top:0 !important;
#                 z-index:2 !important;
#                 background:#2b2b2b !important;
#                 color:#fff !important;
#                 padding:7px !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #777 !important;
#                 border-bottom:2px solid #888 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody td {
#                 padding:7px !important;
#                 vertical-align:top !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(even) td {background:#1b1b1b !important;}
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(odd) td {background:#111 !important;}
#         </style>
#         <table class="dataframe tabela_saida">
#   <thead>
#     <tr style="text-align: left;">
#       <th>variante</th>
#       <th>método de seleção</th>
#       <th>rótulo do método</th>
#       <th>k</th>
#       <th>registros</th>
#       <th>validade da IR</th>
#       <th>PSR</th>
#       <th>EM</th>
#       <th>ED</th>
#       <th>NED</th>
#       <th>SLA-S</th>
#       <th>SLA-F</th>
#       <th>validade sintática</th>
#       <th>autocorreção aplicada</th>
#       <th>prompt primary tokens</th>
#       <th>prompt secondary tokens</th>
#       <th>prompt autocorrection tokens</th>
#       <th>generated primary tokens</th>
#       <th>generated secondary tokens</th>
#       <th>generated autocorrection tokens</th>
#       <th>tempo médio NL → IR</th>
#       <th>tempo médio IR → Nile</th>
#       <th>tempo médio de autocorreção</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>sem_ac</td>
#       <td>random_seed42</td>
#       <td>Aleatória</td>
#       <td>1</td>
#       <td>50</td>
#       <td>11</td>
#       <td>0.20</td>
#       <td>0.00</td>
#       <td>63.46</td>
#       <td>0.551855</td>
#       <td>0.00</td>
#       <td>0.084707</td>
#       <td>10</td>
#       <td>0</td>
#       <td>2776.68</td>
#       <td>643.90</td>
#       <td>-</td>
#       <td>129.44</td>
#       <td>23.06</td>
#       <td>-</td>
#       <td>07s</td>
#       <td>01s</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <td>sem_ac</td>
#       <td>lexical_tfidf</td>
#       <td>Lexical</td>
#       <td>1</td>
#       <td>50</td>
#       <td>35</td>
#       <td>0.68</td>
#       <td>0.08</td>
#       <td>36.50</td>
#       <td>0.305886</td>
#       <td>0.12</td>
#       <td>0.486414</td>
#       <td>34</td>
#       <td>0</td>
#       <td>2776.18</td>
#       <td>650.74</td>
#       <td>-</td>
#       <td>145.76</td>
#       <td>27.32</td>
#       <td>-</td>
#       <td>08s</td>
#       <td>01s</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <td>sem_ac</td>
#       <td>semantic_embeddings</td>
#       <td>Semântica</td>
#       <td>1</td>
#       <td>50</td>
#       <td>30</td>
#       <td>0.52</td>
#       <td>0.06</td>
#       <td>35.20</td>
#       <td>0.316237</td>
#       <td>0.06</td>
#       <td>0.357904</td>
#       <td>26</td>
#       <td>0</td>
#       <td>2778.20</td>
#       <td>652.06</td>
#       <td>-</td>
#       <td>143.10</td>
#       <td>26.92</td>
#       <td>-</td>
#       <td>08s</td>
#       <td>01s</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <td>sem_ac</td>
#       <td>random_seed42</td>
#       <td>Aleatória</td>
#       <td>3</td>
#       <td>50</td>
#       <td>5</td>
#       <td>0.12</td>
#       <td>0.00</td>
#       <td>53.16</td>
#       <td>0.471629</td>
#       <td>0.02</td>
#       <td>0.086919</td>
#       <td>6</td>
#       <td>0</td>
#       <td>2996.34</td>
#       <td>863.08</td>
#       <td>-</td>
#       <td>128.46</td>
#       <td>21.32</td>
#       <td>-</td>
#       <td>08s</td>
#       <td>01s</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <td>sem_ac</td>
#       <td>lexical_tfidf</td>
#       <td>Lexical</td>
#       <td>3</td>
#       <td>50</td>
#       <td>29</td>
#       <td>0.60</td>
#       <td>0.14</td>
#       <td>28.74</td>
#       <td>0.254165</td>
#       <td>0.16</td>
#       <td>0.449426</td>
#       <td>30</td>
#       <td>0</td>
#       <td>2999.62</td>
#       <td>882.94</td>
#       <td>-</td>
#       <td>148.08</td>
#       <td>27.68</td>
#       <td>-</td>
#       <td>08s</td>
#       <td>02s</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <td>sem_ac</td>
#       <td>semantic_embeddings</td>
#       <td>Semântica</td>
#       <td>3</td>
#       <td>50</td>
#       <td>28</td>
#       <td>0.58</td>
#       <td>0.16</td>
#       <td>30.08</td>
#       <td>0.264613</td>
#       <td>0.16</td>
#       <td>0.460576</td>
#       <td>29</td>
#       <td>0</td>
#       <td>3003.02</td>
#       <td>887.08</td>
#       <td>-</td>
#       <td>143.28</td>
#       <td>26.06</td>
#       <td>-</td>
#       <td>08s</td>
#       <td>01s</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <td>sem_ac</td>
#       <td>random_seed42</td>
#       <td>Aleatória</td>
#       <td>5</td>
#       <td>50</td>
#       <td>13</td>
#       <td>0.24</td>
#       <td>0.00</td>
#       <td>46.60</td>
#       <td>0.418113</td>
#       <td>0.00</td>
#       <td>0.154091</td>
#       <td>12</td>
#       <td>0</td>
#       <td>3219.72</td>
#       <td>1095.70</td>
#       <td>-</td>
#       <td>127.50</td>
#       <td>21.46</td>
#       <td>-</td>
#       <td>08s</td>
#       <td>01s</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <td>sem_ac</td>
#       <td>lexical_tfidf</td>
#       <td>Lexical</td>
#       <td>5</td>
#       <td>50</td>
#       <td>29</td>
#       <td>0.60</td>
#       <td>0.18</td>
#       <td>27.44</td>
#       <td>0.248303</td>
#       <td>0.18</td>
#       <td>0.482991</td>
#       <td>30</td>
#       <td>0</td>
#       <td>3220.32</td>
#       <td>1109.84</td>
#       <td>-</td>
#       <td>145.58</td>
#       <td>24.86</td>
#       <td>-</td>
#       <td>08s</td>
#       <td>01s</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <td>sem_ac</td>
#       <td>semantic_embeddings</td>
#       <td>Semântica</td>
#       <td>5</td>
#       <td>50</td>
#       <td>30</td>
#       <td>0.62</td>
#       <td>0.18</td>
#       <td>31.66</td>
#       <td>0.282831</td>
#       <td>0.18</td>
#       <td>0.477730</td>
#       <td>31</td>
#       <td>0</td>
#       <td>3231.88</td>
#       <td>1127.42</td>
#       <td>-</td>
#       <td>140.34</td>
#       <td>25.48</td>
#       <td>-</td>
#       <td>08s</td>
#       <td>01s</td>
#       <td>-</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
#     <div style="font-weight:600;font-size:15px;margin:8px 0 6px;color:#f1f1f1;">
#         Tabela 18. Desempenho da F3-C com primeira autocorreção
#     </div>
#     <div class="container_tabela_saida" style="display:inline-block;max-width:100%;overflow-x:auto;overflow-y: visible;border:none;margin:8px 0 12px;">
#         <style>
#             .container_tabela_saida table.tabela_saida {
#                 border-collapse:collapse !important;
#                 table-layout:auto !important;
#                 width:auto !important;
#                 font-family:Arial,sans-serif !important;
#                 font-size:13px !important;
#                 background:#111 !important;
#                 color:#f1f1f1 !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida thead th {
#                 position:sticky !important;
#                 top:0 !important;
#                 z-index:2 !important;
#                 background:#2b2b2b !important;
#                 color:#fff !important;
#                 padding:7px !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #777 !important;
#                 border-bottom:2px solid #888 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody td {
#                 padding:7px !important;
#                 vertical-align:top !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(even) td {background:#1b1b1b !important;}
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(odd) td {background:#111 !important;}
#         </style>
#         <table class="dataframe tabela_saida">
#   <thead>
#     <tr style="text-align: left;">
#       <th>variante</th>
#       <th>método de seleção</th>
#       <th>rótulo do método</th>
#       <th>k</th>
#       <th>registros</th>
#       <th>validade da IR</th>
#       <th>PSR</th>
#       <th>EM</th>
#       <th>ED</th>
#       <th>NED</th>
#       <th>SLA-S</th>
#       <th>SLA-F</th>
#       <th>validade sintática</th>
#       <th>autocorreção aplicada</th>
#       <th>prompt primary tokens</th>
#       <th>prompt secondary tokens</th>
#       <th>prompt autocorrection tokens</th>
#       <th>generated primary tokens</th>
#       <th>generated secondary tokens</th>
#       <th>generated autocorrection tokens</th>
#       <th>tempo médio NL → IR</th>
#       <th>tempo médio IR → Nile</th>
#       <th>tempo médio de autocorreção</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>primeira_ac</td>
#       <td>random_seed42</td>
#       <td>Aleatória</td>
#       <td>1</td>
#       <td>50</td>
#       <td>11</td>
#       <td>0.20</td>
#       <td>0.00</td>
#       <td>64.90</td>
#       <td>0.566357</td>
#       <td>0.00</td>
#       <td>0.084707</td>
#       <td>10</td>
#       <td>40</td>
#       <td>2776.68</td>
#       <td>643.90</td>
#       <td>829.450000</td>
#       <td>129.44</td>
#       <td>23.06</td>
#       <td>20.175000</td>
#       <td>07s</td>
#       <td>01s</td>
#       <td>01s</td>
#     </tr>
#     <tr>
#       <td>primeira_ac</td>
#       <td>lexical_tfidf</td>
#       <td>Lexical</td>
#       <td>1</td>
#       <td>50</td>
#       <td>35</td>
#       <td>0.68</td>
#       <td>0.08</td>
#       <td>38.54</td>
#       <td>0.310388</td>
#       <td>0.12</td>
#       <td>0.486414</td>
#       <td>34</td>
#       <td>16</td>
#       <td>2776.18</td>
#       <td>650.74</td>
#       <td>846.000000</td>
#       <td>145.76</td>
#       <td>27.32</td>
#       <td>25.437500</td>
#       <td>08s</td>
#       <td>01s</td>
#       <td>01s</td>
#     </tr>
#     <tr>
#       <td>primeira_ac</td>
#       <td>semantic_embeddings</td>
#       <td>Semântica</td>
#       <td>1</td>
#       <td>50</td>
#       <td>30</td>
#       <td>0.52</td>
#       <td>0.06</td>
#       <td>35.54</td>
#       <td>0.315692</td>
#       <td>0.06</td>
#       <td>0.357904</td>
#       <td>26</td>
#       <td>24</td>
#       <td>2778.20</td>
#       <td>652.06</td>
#       <td>841.875000</td>
#       <td>143.10</td>
#       <td>26.92</td>
#       <td>23.458333</td>
#       <td>08s</td>
#       <td>01s</td>
#       <td>01s</td>
#     </tr>
#     <tr>
#       <td>primeira_ac</td>
#       <td>random_seed42</td>
#       <td>Aleatória</td>
#       <td>3</td>
#       <td>50</td>
#       <td>5</td>
#       <td>0.14</td>
#       <td>0.00</td>
#       <td>56.76</td>
#       <td>0.484135</td>
#       <td>0.02</td>
#       <td>0.088919</td>
#       <td>7</td>
#       <td>44</td>
#       <td>2996.34</td>
#       <td>863.08</td>
#       <td>1056.000000</td>
#       <td>128.46</td>
#       <td>21.32</td>
#       <td>22.318182</td>
#       <td>08s</td>
#       <td>01s</td>
#       <td>01s</td>
#     </tr>
#     <tr>
#       <td>primeira_ac</td>
#       <td>lexical_tfidf</td>
#       <td>Lexical</td>
#       <td>3</td>
#       <td>50</td>
#       <td>29</td>
#       <td>0.62</td>
#       <td>0.14</td>
#       <td>28.86</td>
#       <td>0.250986</td>
#       <td>0.16</td>
#       <td>0.449426</td>
#       <td>31</td>
#       <td>20</td>
#       <td>2999.62</td>
#       <td>882.94</td>
#       <td>1059.350000</td>
#       <td>148.08</td>
#       <td>27.68</td>
#       <td>22.500000</td>
#       <td>08s</td>
#       <td>02s</td>
#       <td>01s</td>
#     </tr>
#     <tr>
#       <td>primeira_ac</td>
#       <td>semantic_embeddings</td>
#       <td>Semântica</td>
#       <td>3</td>
#       <td>50</td>
#       <td>28</td>
#       <td>0.60</td>
#       <td>0.16</td>
#       <td>31.16</td>
#       <td>0.266317</td>
#       <td>0.16</td>
#       <td>0.478354</td>
#       <td>30</td>
#       <td>21</td>
#       <td>3003.02</td>
#       <td>887.08</td>
#       <td>1054.428571</td>
#       <td>143.28</td>
#       <td>26.06</td>
#       <td>21.857143</td>
#       <td>08s</td>
#       <td>01s</td>
#       <td>01s</td>
#     </tr>
#     <tr>
#       <td>primeira_ac</td>
#       <td>random_seed42</td>
#       <td>Aleatória</td>
#       <td>5</td>
#       <td>50</td>
#       <td>13</td>
#       <td>0.26</td>
#       <td>0.00</td>
#       <td>48.36</td>
#       <td>0.423036</td>
#       <td>0.00</td>
#       <td>0.156091</td>
#       <td>13</td>
#       <td>38</td>
#       <td>3219.72</td>
#       <td>1095.70</td>
#       <td>1290.052632</td>
#       <td>127.50</td>
#       <td>21.46</td>
#       <td>23.210526</td>
#       <td>08s</td>
#       <td>01s</td>
#       <td>01s</td>
#     </tr>
#     <tr>
#       <td>primeira_ac</td>
#       <td>lexical_tfidf</td>
#       <td>Lexical</td>
#       <td>5</td>
#       <td>50</td>
#       <td>29</td>
#       <td>0.64</td>
#       <td>0.18</td>
#       <td>26.40</td>
#       <td>0.237710</td>
#       <td>0.18</td>
#       <td>0.507657</td>
#       <td>32</td>
#       <td>20</td>
#       <td>3220.32</td>
#       <td>1109.84</td>
#       <td>1283.200000</td>
#       <td>145.58</td>
#       <td>24.86</td>
#       <td>20.450000</td>
#       <td>08s</td>
#       <td>01s</td>
#       <td>01s</td>
#     </tr>
#     <tr>
#       <td>primeira_ac</td>
#       <td>semantic_embeddings</td>
#       <td>Semântica</td>
#       <td>5</td>
#       <td>50</td>
#       <td>30</td>
#       <td>0.62</td>
#       <td>0.18</td>
#       <td>32.08</td>
#       <td>0.282946</td>
#       <td>0.18</td>
#       <td>0.477730</td>
#       <td>31</td>
#       <td>19</td>
#       <td>3231.88</td>
#       <td>1127.42</td>
#       <td>1283.315789</td>
#       <td>140.34</td>
#       <td>25.48</td>
#       <td>21.842105</td>
#       <td>08s</td>
#       <td>01s</td>
#       <td>01s</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
#     <div style="font-weight:600;font-size:15px;margin:8px 0 6px;color:#f1f1f1;">
#         Tabela 19. Ganhos da primeira autocorreção
#     </div>
#     <div class="container_tabela_saida" style="display:inline-block;max-width:100%;overflow-x:auto;max-height: 420px; overflow-y: auto;border:none;margin:8px 0 12px;">
#         <style>
#             .container_tabela_saida table.tabela_saida {
#                 border-collapse:collapse !important;
#                 table-layout:auto !important;
#                 width:auto !important;
#                 font-family:Arial,sans-serif !important;
#                 font-size:13px !important;
#                 background:#111 !important;
#                 color:#f1f1f1 !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida thead th {
#                 position:sticky !important;
#                 top:0 !important;
#                 z-index:2 !important;
#                 background:#2b2b2b !important;
#                 color:#fff !important;
#                 padding:7px !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #777 !important;
#                 border-bottom:2px solid #888 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody td {
#                 padding:7px !important;
#                 vertical-align:top !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(even) td {background:#1b1b1b !important;}
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(odd) td {background:#111 !important;}
#         </style>
#         <table class="dataframe tabela_saida">
#   <thead>
#     <tr style="text-align: left;">
#       <th>método de seleção</th>
#       <th>rótulo do método</th>
#       <th>k</th>
#       <th>registros</th>
#       <th>autocorrections</th>
#       <th>syntax recovered</th>
#       <th>psr before</th>
#       <th>psr after</th>
#       <th>em before</th>
#       <th>em after</th>
#       <th>ed before</th>
#       <th>ed after</th>
#       <th>ned before</th>
#       <th>ned after</th>
#       <th>sla s before</th>
#       <th>sla s after</th>
#       <th>sla f before</th>
#       <th>sla f after</th>
#       <th>delta psr</th>
#       <th>delta em</th>
#       <th>delta ed</th>
#       <th>delta ned</th>
#       <th>delta sla s</th>
#       <th>delta sla f</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>random_seed42</td>
#       <td>Aleatória</td>
#       <td>1</td>
#       <td>50</td>
#       <td>40</td>
#       <td>0</td>
#       <td>0.20</td>
#       <td>0.20</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>63.46</td>
#       <td>64.90</td>
#       <td>0.551855</td>
#       <td>0.566357</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.084707</td>
#       <td>0.084707</td>
#       <td>0.00</td>
#       <td>0.0</td>
#       <td>1.44</td>
#       <td>0.014502</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>lexical_tfidf</td>
#       <td>Lexical</td>
#       <td>1</td>
#       <td>50</td>
#       <td>16</td>
#       <td>0</td>
#       <td>0.68</td>
#       <td>0.68</td>
#       <td>0.08</td>
#       <td>0.08</td>
#       <td>36.50</td>
#       <td>38.54</td>
#       <td>0.305886</td>
#       <td>0.310388</td>
#       <td>0.12</td>
#       <td>0.12</td>
#       <td>0.486414</td>
#       <td>0.486414</td>
#       <td>0.00</td>
#       <td>0.0</td>
#       <td>2.04</td>
#       <td>0.004501</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>semantic_embeddings</td>
#       <td>Semântica</td>
#       <td>1</td>
#       <td>50</td>
#       <td>24</td>
#       <td>0</td>
#       <td>0.52</td>
#       <td>0.52</td>
#       <td>0.06</td>
#       <td>0.06</td>
#       <td>35.20</td>
#       <td>35.54</td>
#       <td>0.316237</td>
#       <td>0.315692</td>
#       <td>0.06</td>
#       <td>0.06</td>
#       <td>0.357904</td>
#       <td>0.357904</td>
#       <td>0.00</td>
#       <td>0.0</td>
#       <td>0.34</td>
#       <td>-0.000545</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>random_seed42</td>
#       <td>Aleatória</td>
#       <td>3</td>
#       <td>50</td>
#       <td>44</td>
#       <td>1</td>
#       <td>0.12</td>
#       <td>0.14</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>53.16</td>
#       <td>56.76</td>
#       <td>0.471629</td>
#       <td>0.484135</td>
#       <td>0.02</td>
#       <td>0.02</td>
#       <td>0.086919</td>
#       <td>0.088919</td>
#       <td>0.02</td>
#       <td>0.0</td>
#       <td>3.60</td>
#       <td>0.012506</td>
#       <td>0.0</td>
#       <td>0.002000</td>
#     </tr>
#     <tr>
#       <td>lexical_tfidf</td>
#       <td>Lexical</td>
#       <td>3</td>
#       <td>50</td>
#       <td>20</td>
#       <td>1</td>
#       <td>0.60</td>
#       <td>0.62</td>
#       <td>0.14</td>
#       <td>0.14</td>
#       <td>28.74</td>
#       <td>28.86</td>
#       <td>0.254165</td>
#       <td>0.250986</td>
#       <td>0.16</td>
#       <td>0.16</td>
#       <td>0.449426</td>
#       <td>0.449426</td>
#       <td>0.02</td>
#       <td>0.0</td>
#       <td>0.12</td>
#       <td>-0.003178</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>semantic_embeddings</td>
#       <td>Semântica</td>
#       <td>3</td>
#       <td>50</td>
#       <td>21</td>
#       <td>1</td>
#       <td>0.58</td>
#       <td>0.60</td>
#       <td>0.16</td>
#       <td>0.16</td>
#       <td>30.08</td>
#       <td>31.16</td>
#       <td>0.264613</td>
#       <td>0.266317</td>
#       <td>0.16</td>
#       <td>0.16</td>
#       <td>0.460576</td>
#       <td>0.478354</td>
#       <td>0.02</td>
#       <td>0.0</td>
#       <td>1.08</td>
#       <td>0.001705</td>
#       <td>0.0</td>
#       <td>0.017778</td>
#     </tr>
#     <tr>
#       <td>random_seed42</td>
#       <td>Aleatória</td>
#       <td>5</td>
#       <td>50</td>
#       <td>38</td>
#       <td>1</td>
#       <td>0.24</td>
#       <td>0.26</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>46.60</td>
#       <td>48.36</td>
#       <td>0.418113</td>
#       <td>0.423036</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.154091</td>
#       <td>0.156091</td>
#       <td>0.02</td>
#       <td>0.0</td>
#       <td>1.76</td>
#       <td>0.004923</td>
#       <td>0.0</td>
#       <td>0.002000</td>
#     </tr>
#     <tr>
#       <td>lexical_tfidf</td>
#       <td>Lexical</td>
#       <td>5</td>
#       <td>50</td>
#       <td>20</td>
#       <td>2</td>
#       <td>0.60</td>
#       <td>0.64</td>
#       <td>0.18</td>
#       <td>0.18</td>
#       <td>27.44</td>
#       <td>26.40</td>
#       <td>0.248303</td>
#       <td>0.237710</td>
#       <td>0.18</td>
#       <td>0.18</td>
#       <td>0.482991</td>
#       <td>0.507657</td>
#       <td>0.04</td>
#       <td>0.0</td>
#       <td>-1.04</td>
#       <td>-0.010593</td>
#       <td>0.0</td>
#       <td>0.024667</td>
#     </tr>
#     <tr>
#       <td>semantic_embeddings</td>
#       <td>Semântica</td>
#       <td>5</td>
#       <td>50</td>
#       <td>19</td>
#       <td>0</td>
#       <td>0.62</td>
#       <td>0.62</td>
#       <td>0.18</td>
#       <td>0.18</td>
#       <td>31.66</td>
#       <td>32.08</td>
#       <td>0.282831</td>
#       <td>0.282946</td>
#       <td>0.18</td>
#       <td>0.18</td>
#       <td>0.477730</td>
#       <td>0.477730</td>
#       <td>0.00</td>
#       <td>0.0</td>
#       <td>0.42</td>
#       <td>0.000115</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
#     <div style="font-weight:600;font-size:15px;margin:8px 0 6px;color:#f1f1f1;">
#         Tabela 20. Desempenho por fold, variante, método e k
#     </div>
#     <div class="container_tabela_saida" style="display:inline-block;max-width:100%;overflow-x:auto;max-height: 520px; overflow-y: auto;border:none;margin:8px 0 12px;">
#         <style>
#             .container_tabela_saida table.tabela_saida {
#                 border-collapse:collapse !important;
#                 table-layout:auto !important;
#                 width:auto !important;
#                 font-family:Arial,sans-serif !important;
#                 font-size:13px !important;
#                 background:#111 !important;
#                 color:#f1f1f1 !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida thead th {
#                 position:sticky !important;
#                 top:0 !important;
#                 z-index:2 !important;
#                 background:#2b2b2b !important;
#                 color:#fff !important;
#                 padding:7px !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #777 !important;
#                 border-bottom:2px solid #888 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody td {
#                 padding:7px !important;
#                 vertical-align:top !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(even) td {background:#1b1b1b !important;}
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(odd) td {background:#111 !important;}
#         </style>
#         <table class="dataframe tabela_saida">
#   <thead>
#     <tr style="text-align: left;">
#       <th>fold</th>
#       <th>variante</th>
#       <th>método de seleção</th>
#       <th>rótulo do método</th>
#       <th>k</th>
#       <th>registros</th>
#       <th>validade da IR</th>
#       <th>PSR</th>
#       <th>EM</th>
#       <th>ED</th>
#       <th>NED</th>
#       <th>SLA-S</th>
#       <th>SLA-F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>sem_ac</td>
#       <td>random_seed42</td>
#       <td>Aleatória</td>
#       <td>1</td>
#       <td>10</td>
#       <td>3</td>
#       <td>0.3</td>
#       <td>0.0</td>
#       <td>71.4</td>
#       <td>0.555327</td>
#       <td>0.0</td>
#       <td>0.105556</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>sem_ac</td>
#       <td>lexical_tfidf</td>
#       <td>Lexical</td>
#       <td>1</td>
#       <td>10</td>
#       <td>6</td>
#       <td>0.4</td>
#       <td>0.1</td>
#       <td>44.7</td>
#       <td>0.355865</td>
#       <td>0.1</td>
#       <td>0.345707</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>sem_ac</td>
#       <td>semantic_embeddings</td>
#       <td>Semântica</td>
#       <td>1</td>
#       <td>10</td>
#       <td>6</td>
#       <td>0.3</td>
#       <td>0.0</td>
#       <td>36.8</td>
#       <td>0.338561</td>
#       <td>0.0</td>
#       <td>0.191162</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>sem_ac</td>
#       <td>random_seed42</td>
#       <td>Aleatória</td>
#       <td>3</td>
#       <td>10</td>
#       <td>1</td>
#       <td>0.2</td>
#       <td>0.0</td>
#       <td>56.4</td>
#       <td>0.487045</td>
#       <td>0.1</td>
#       <td>0.155556</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>sem_ac</td>
#       <td>lexical_tfidf</td>
#       <td>Lexical</td>
#       <td>3</td>
#       <td>10</td>
#       <td>4</td>
#       <td>0.4</td>
#       <td>0.1</td>
#       <td>37.2</td>
#       <td>0.351397</td>
#       <td>0.1</td>
#       <td>0.299675</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>sem_ac</td>
#       <td>semantic_embeddings</td>
#       <td>Semântica</td>
#       <td>3</td>
#       <td>10</td>
#       <td>6</td>
#       <td>0.5</td>
#       <td>0.1</td>
#       <td>32.0</td>
#       <td>0.324814</td>
#       <td>0.1</td>
#       <td>0.339646</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>sem_ac</td>
#       <td>random_seed42</td>
#       <td>Aleatória</td>
#       <td>5</td>
#       <td>10</td>
#       <td>3</td>
#       <td>0.3</td>
#       <td>0.0</td>
#       <td>52.5</td>
#       <td>0.431867</td>
#       <td>0.0</td>
#       <td>0.122222</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>sem_ac</td>
#       <td>lexical_tfidf</td>
#       <td>Lexical</td>
#       <td>5</td>
#       <td>10</td>
#       <td>5</td>
#       <td>0.6</td>
#       <td>0.1</td>
#       <td>28.7</td>
#       <td>0.287822</td>
#       <td>0.1</td>
#       <td>0.339448</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>sem_ac</td>
#       <td>semantic_embeddings</td>
#       <td>Semântica</td>
#       <td>5</td>
#       <td>10</td>
#       <td>4</td>
#       <td>0.4</td>
#       <td>0.1</td>
#       <td>39.4</td>
#       <td>0.414576</td>
#       <td>0.1</td>
#       <td>0.300487</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>primeira_ac</td>
#       <td>random_seed42</td>
#       <td>Aleatória</td>
#       <td>1</td>
#       <td>10</td>
#       <td>3</td>
#       <td>0.3</td>
#       <td>0.0</td>
#       <td>73.1</td>
#       <td>0.575855</td>
#       <td>0.0</td>
#       <td>0.105556</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>primeira_ac</td>
#       <td>lexical_tfidf</td>
#       <td>Lexical</td>
#       <td>1</td>
#       <td>10</td>
#       <td>6</td>
#       <td>0.4</td>
#       <td>0.1</td>
#       <td>52.8</td>
#       <td>0.367704</td>
#       <td>0.1</td>
#       <td>0.345707</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>primeira_ac</td>
#       <td>semantic_embeddings</td>
#       <td>Semântica</td>
#       <td>1</td>
#       <td>10</td>
#       <td>6</td>
#       <td>0.3</td>
#       <td>0.0</td>
#       <td>37.9</td>
#       <td>0.346767</td>
#       <td>0.0</td>
#       <td>0.191162</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>primeira_ac</td>
#       <td>random_seed42</td>
#       <td>Aleatória</td>
#       <td>3</td>
#       <td>10</td>
#       <td>1</td>
#       <td>0.3</td>
#       <td>0.0</td>
#       <td>66.3</td>
#       <td>0.494054</td>
#       <td>0.1</td>
#       <td>0.165556</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>primeira_ac</td>
#       <td>lexical_tfidf</td>
#       <td>Lexical</td>
#       <td>3</td>
#       <td>10</td>
#       <td>4</td>
#       <td>0.4</td>
#       <td>0.1</td>
#       <td>36.1</td>
#       <td>0.351351</td>
#       <td>0.1</td>
#       <td>0.299675</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>primeira_ac</td>
#       <td>semantic_embeddings</td>
#       <td>Semântica</td>
#       <td>3</td>
#       <td>10</td>
#       <td>6</td>
#       <td>0.5</td>
#       <td>0.1</td>
#       <td>34.6</td>
#       <td>0.320921</td>
#       <td>0.1</td>
#       <td>0.339646</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>primeira_ac</td>
#       <td>random_seed42</td>
#       <td>Aleatória</td>
#       <td>5</td>
#       <td>10</td>
#       <td>3</td>
#       <td>0.3</td>
#       <td>0.0</td>
#       <td>58.4</td>
#       <td>0.446998</td>
#       <td>0.0</td>
#       <td>0.122222</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>primeira_ac</td>
#       <td>lexical_tfidf</td>
#       <td>Lexical</td>
#       <td>5</td>
#       <td>10</td>
#       <td>5</td>
#       <td>0.7</td>
#       <td>0.1</td>
#       <td>25.9</td>
#       <td>0.246924</td>
#       <td>0.1</td>
#       <td>0.422781</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>primeira_ac</td>
#       <td>semantic_embeddings</td>
#       <td>Semântica</td>
#       <td>5</td>
#       <td>10</td>
#       <td>4</td>
#       <td>0.4</td>
#       <td>0.1</td>
#       <td>39.6</td>
#       <td>0.403950</td>
#       <td>0.1</td>
#       <td>0.300487</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>sem_ac</td>
#       <td>random_seed42</td>
#       <td>Aleatória</td>
#       <td>1</td>
#       <td>10</td>
#       <td>4</td>
#       <td>0.3</td>
#       <td>0.0</td>
#       <td>50.0</td>
#       <td>0.461695</td>
#       <td>0.0</td>
#       <td>0.154343</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>sem_ac</td>
#       <td>lexical_tfidf</td>
#       <td>Lexical</td>
#       <td>1</td>
#       <td>10</td>
#       <td>8</td>
#       <td>0.
#     <div style="font-weight:600;font-size:15px;margin:8px 0 6px;color:#f1f1f1;">
#         Tabela 21. Auditoria dos limites fixos dos gráficos
#     </div>
#     <div class="container_tabela_saida" style="display:inline-block;max-width:100%;overflow-x:auto;overflow-y: visible;border:none;margin:8px 0 12px;">
#         <style>
#             .container_tabela_saida table.tabela_saida {
#                 border-collapse:collapse !important;
#                 table-layout:auto !important;
#                 width:auto !important;
#                 font-family:Arial,sans-serif !important;
#                 font-size:13px !important;
#                 background:#111 !important;
#                 color:#f1f1f1 !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida thead th {
#                 position:sticky !important;
#                 top:0 !important;
#                 z-index:2 !important;
#                 background:#2b2b2b !important;
#                 color:#fff !important;
#                 padding:7px !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #777 !important;
#                 border-bottom:2px solid #888 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody td {
#                 padding:7px !important;
#                 vertical-align:top !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(even) td {background:#1b1b1b !important;}
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(odd) td {background:#111 !important;}
#         </style>
#         <table class="dataframe tabela_saida">
#   <thead>
#     <tr style="text-align: left;">
#       <th>métrica</th>
#       <th>mínimo observado</th>
#       <th>máximo observado</th>
#       <th>limite inferior</th>
#       <th>limite superior</th>
#       <th>dentro do limite</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>PSR</td>
#       <td>0.120000</td>
#       <td>0.680000</td>
#       <td>-0.03</td>
#       <td>1.03</td>
#       <td>sim</td>
#     </tr>
#     <tr>
#       <td>EM</td>
#       <td>0.000000</td>
#       <td>0.180000</td>
#       <td>-0.03</td>
#       <td>1.03</td>
#       <td>sim</td>
#     </tr>
#     <tr>
#       <td>ED</td>
#       <td>26.400000</td>
#       <td>64.900000</td>
#       <td>0.00</td>
#       <td>100.00</td>
#       <td>sim</td>
#     </tr>
#     <tr>
#       <td>NED</td>
#       <td>0.237710</td>
#       <td>0.566357</td>
#       <td>-0.03</td>
#       <td>1.03</td>
#       <td>sim</td>
#     </tr>
#     <tr>
#       <td>SLA-S</td>
#       <td>0.000000</td>
#       <td>0.180000</td>
#       <td>-0.03</td>
#       <td>1.03</td>
#       <td>sim</td>
#     </tr>
#     <tr>
#       <td>SLA-F</td>
#       <td>0.084707</td>
#       <td>0.507657</td>
#       <td>-0.03</td>
#       <td>1.03</td>
#       <td>sim</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
# Bloco 9 concluído.
# Condições resumidas: 18
# Gráficos produzidos: 12
# Escalas fixas aplicadas: PSR, EM, NED, SLA-S e SLA-F de 0 a 1; ED de 0 a 100.
# Elegíveis à autocorreção final por PSR=0: 236
# Status: OK

# %% [markdown]
# ## Bloco 10 - Barreiras finais, manifesto e empacotamento
#
# ### Objetivo
#
# Este bloco encerra a F3-C e cria o pacote operacional utilizado na consolidação e na autocorreção final.
#
# ### Barreiras quantitativas
#
# A execução oficial exige:
#
# - 450 fluxos planejados;
# - 450 prompts e gerações NL → IR;
# - 450 prompts e gerações IR → Nile;
# - autocorreções em quantidade idêntica às Nile iniciais com `PSR=0`;
# - 900 resultados finais;
# - 18 condições de 50 registros;
# - 90 combinações por fold;
# - 50 IDs na análise por exemplo;
# - doze gráficos.
#
# ### Barreiras de consistência
#
# O bloco confirma:
#
# - igualdade entre tokens auditados e tokens registrados na inferência;
# - limite de contexto em todos os estágios;
# - conformidade dos 900 registros com o JSON Schema;
# - duas variantes para cada fluxo-base;
# - preservação exata da Nile e das métricas quando nenhuma autocorreção foi aplicada;
# - mesma IR gerada nas duas variantes;
# - nenhuma exposição de referência nos prompts;
# - hashes de todos os artefatos.
#
# ### Pacote final
#
# O arquivo produzido é:
#
# ```text
# f3c_traducao_com_ir.zip
# ```
#
# O ZIP não contém pasta externa repetida. As saídas da variante `primeira_ac` que permanecem com `PSR=0` são registradas separadamente como candidatas à etapa complementar de autocorreção final.
#
# ### Resultado esperado
#
# A F3-C só é considerada concluída quando o pacote pode ser reaberto, sua estrutura corresponde ao manifesto e todos os hashes conferem.

# %%
# ----------------------------------------------------------
# 10.1 Barreiras finais da execução oficial
# ----------------------------------------------------------

if MODO_TESTE_RAPIDO:
    raise RuntimeError(
        "O modo de teste rápido está ativo. Desative-o e execute os Blocos 6 a 10 "
        "para produzir o pacote oficial da F3-C."
    )

if len(plan_records) != TOTAL_FLUXOS_BASE_ESPERADO:
    raise ValueError("O pacote oficial exige 450 fluxos-base.")
if len(prompt_ir_records) != TOTAL_FLUXOS_BASE_ESPERADO:
    raise ValueError("A quantidade de prompts IR é divergente.")
if len(ir_generation_records) != TOTAL_FLUXOS_BASE_ESPERADO:
    raise ValueError("A quantidade de gerações IR é divergente.")
if len(ir_validation_records) != TOTAL_FLUXOS_BASE_ESPERADO:
    raise ValueError("A quantidade de validações IR é divergente.")
if len(prompt_nile_records) != TOTAL_FLUXOS_BASE_ESPERADO:
    raise ValueError("A quantidade de prompts Nile é divergente.")
if len(nile_generation_records) != TOTAL_FLUXOS_BASE_ESPERADO:
    raise ValueError("A quantidade de gerações Nile é divergente.")
if len(initial_evaluation_records) != TOTAL_FLUXOS_BASE_ESPERADO:
    raise ValueError("A quantidade de avaliações iniciais é divergente.")

expected_autocorrections = int(initial_evaluation_df["eligible_for_autocorrection"].sum())
if len(prompt_ac_records) != expected_autocorrections:
    raise ValueError("A quantidade de prompts de autocorreção é divergente.")
if len(ac_generation_records) != expected_autocorrections:
    raise ValueError("A quantidade de gerações de autocorreção é divergente.")
if len(result_records) != TOTAL_REGISTROS_ESPERADO:
    raise ValueError("O pacote oficial exige 900 resultados.")
if len(summary_df) != TOTAL_CONDICOES_ESPERADO or not summary_df["records"].eq(50).all():
    raise ValueError("O resumo não contém 18 condições de 50 registros.")
if len(summary_fold_df) != TOTAL_FOLDS_ESPERADO * TOTAL_CONDICOES_ESPERADO:
    raise ValueError("O resumo por fold não possui 90 combinações.")
if len(ir_summary_df) != TOTAL_CONDICOES_BASE or not ir_summary_df["records"].eq(50).all():
    raise ValueError("O resumo da IR não contém nove condições de 50 registros.")
if len(analysis_example_df) != TOTAL_EXEMPLOS_ESPERADO:
    raise ValueError("A análise por exemplo deve conter 50 IDs.")
if len(GRAFICOS_PATHS) != 12:
    raise ValueError("A F3-C deve produzir doze gráficos.")


def assert_token_consistency(prompt_records_stage, generation_records_stage, max_new_tokens):
    prompt_map = {
        str(record["execution_id"]): int(record["prompt_tokens"])
        for record in prompt_records_stage
    }
    generation_map = {
        str(record["execution_id"]): int(record["prompt_tokens"])
        for record in generation_records_stage
    }
    if prompt_map != generation_map:
        raise ValueError("A auditoria de tokens diverge da inferência.")
    if prompt_map and max(prompt_map.values()) + max_new_tokens > CONTEXT_LIMIT:
        raise ValueError("Há prompt fora do limite de contexto.")


assert_token_consistency(prompt_ir_records, ir_generation_records, MAX_NEW_TOKENS_IR)
assert_token_consistency(prompt_nile_records, nile_generation_records, MAX_NEW_TOKENS_NILE)
assert_token_consistency(prompt_ac_records, ac_generation_records, MAX_NEW_TOKENS_NILE)

if results_df["status"].ne("completed").any():
    raise ValueError("Há resultados não concluídos.")
if results_df["strategy"].ne(ESTRATEGIA).any():
    raise ValueError("Há resultado associado a outra estratégia.")

for record in result_records:
    errors = sorted(result_validator.iter_errors(record), key=lambda error: list(error.path))
    if errors:
        raise ValueError("Há resultado incompatível com o schema comum.")

result_key_map = {}
for record in result_records:
    key = (
        int(record["fold"]),
        str(record["id"]),
        str(record["selection_method"]),
        int(record["k"]),
        str(record["variant"]),
    )
    if key in result_key_map:
        raise ValueError(f"Resultado duplicado para {key}.")
    result_key_map[key] = record

for plan in plan_records:
    base = (
        int(plan["fold"]),
        str(plan["id"]),
        str(plan["selection_method"]),
        int(plan["k"]),
    )
    sem = result_key_map[(*base, "sem_ac")]
    ac = result_key_map[(*base, "primeira_ac")]
    if canonical_json(sem["generated_ir"]) != canonical_json(ac["generated_ir"]):
        raise ValueError(f"A IR diverge entre variantes para {base}.")
    eligible = int(sem["psr"]) == 0
    if bool(ac["autocorrection_applied"]) != eligible:
        raise ValueError(f"Decisão de autocorreção divergente para {base}.")
    if not eligible:
        if ac["nile_evaluated"] != sem["nile_evaluated"]:
            raise ValueError(f"Saída preservada foi alterada para {base}.")
        for metric in METRICAS:
            if not np.isclose(float(ac[metric]), float(sem[metric]), rtol=0, atol=1e-12):
                raise ValueError(f"Métrica preservada foi alterada para {base}: {metric}.")

if prompt_audit_df["pending_placeholders"].astype(bool).any():
    raise ValueError("Há placeholders pendentes.")
for column in [
    "test_reference_nile_exposed",
    "test_r1_exposed",
    "test_r2_exposed",
    "test_r3_exposed",
]:
    if prompt_audit_df[column].fillna(False).astype(bool).any():
        raise ValueError(f"Há exposição de referência em {column}.")
if not prompt_audit_df["context_ok"].astype(bool).all():
    raise ValueError("Há prompt fora do contexto.")


# ----------------------------------------------------------
# 10.2 Configuração consolidada
# ----------------------------------------------------------

def stage_token_stats(token_df):
    if token_df.empty:
        return {"prompts": 0, "min": None, "max": None, "max_reserved": None}
    return {
        "prompts": int(len(token_df)),
        "min": int(token_df["prompt_tokens"].min()),
        "max": int(token_df["prompt_tokens"].max()),
        "max_reserved": int(token_df["reserved_tokens"].max()),
    }


config_final = {
    **configuracao_inicial,
    "inputs": {
        "f3_modelo_source": str(FONTE_F3_MODELO["path"]),
        "f3_modelo_source_type": FONTE_F3_MODELO["type"],
        "f3_modelo_manifest_sha256": f3_modelo_manifest_sha256,
    },
    "student_model": {
        "name": MODELO_ALUNO,
        "model_id": MODELO_HF_ID,
        "source_used": str(MODEL_SOURCE),
        "source_type": MODEL_SOURCE_TYPE,
        "device": model_device,
        "dtype": model_dtype,
        "context_limit": CONTEXT_LIMIT,
        "do_sample": DO_SAMPLE,
        "max_new_tokens_ir": MAX_NEW_TOKENS_IR,
        "max_new_tokens_nile": MAX_NEW_TOKENS_NILE,
    },
    "observed": {
        "base_pipelines": int(len(plan_records)),
        "final_results": int(len(result_records)),
        "ir_valid": int(ir_validation_df["ir_valid"].sum()),
        "nile_syntax_valid_before": int(
            results_df.loc[results_df["variant"] == "sem_ac", "syntax_valid"].sum()
        ),
        "nile_syntax_valid_after": int(
            results_df.loc[results_df["variant"] == "primeira_ac", "syntax_valid"].sum()
        ),
        "autocorrections_applied": expected_autocorrections,
        "syntax_recovered": int(comparison_df["syntax_recovered"].sum()),
        "final_autocorrection_eligible": int(len(final_ac_eligible_df)),
        "tokens": {
            "nl_to_ir": stage_token_stats(token_audit_ir_df),
            "ir_to_nile": stage_token_stats(token_audit_nile_df),
            "autocorrection": stage_token_stats(token_audit_ac_df),
        },
    },
}
write_json(config_final, CONFIG_PATH)


# ----------------------------------------------------------
# 10.3 Inventário e manifesto
# ----------------------------------------------------------

clean_runtime_caches(F3C_DIR)

package_files = [
    CONFIG_PATH,
    PLANO_PATH,
    PROMPTS_IR_PATH,
    TOKEN_AUDIT_IR_PATH,
    GENERATIONS_IR_PATH,
    IR_VALIDATION_PATH,
    PROMPTS_NILE_PATH,
    TOKEN_AUDIT_NILE_PATH,
    GENERATIONS_NILE_PATH,
    INITIAL_EVALUATION_PATH,
    PROMPTS_AC_PATH,
    TOKEN_AUDIT_AC_PATH,
    GENERATIONS_AC_PATH,
    PROMPT_AUDIT_PATH,
    RESULTS_JSONL_PATH,
    RESULTS_CSV_PATH,
    SUMMARY_PATH,
    SUMMARY_FOLD_PATH,
    IR_SUMMARY_PATH,
    INVALID_SEM_AC_PATH,
    INVALID_PRIMEIRA_AC_PATH,
    FINAL_AC_ELIGIBLE_PATH,
    ANALYSIS_EXAMPLE_PATH,
    EXECUTION_AUDIT_PATH,
    COMPARISON_PATH,
    GAINS_PATH,
    *[GRAFICOS_PATHS[(variant, metric)] for variant in ORDEM_VARIANTES_EXIBICAO for metric in METRICAS],
]

missing_files = [str(path) for path in package_files if not Path(path).is_file()]
if missing_files:
    raise FileNotFoundError("Arquivos finais ausentes: " + ", ".join(missing_files))

file_inventory = []
for path in package_files:
    path = Path(path)
    relative = (
        "graficos/" + path.name
        if path.is_relative_to(GRAFICOS_DIR)
        else path.relative_to(PACOTE_DIR).as_posix()
    )
    file_inventory.append({
        "file": relative,
        "size_bytes": int(path.stat().st_size),
        "sha256": sha256_file(path),
    })

manifest = {
    "phase": FASE,
    "strategy": ESTRATEGIA,
    "variants": VARIANTES,
    "description": NOME_ESTRATEGIA,
    "created_at_utc": datetime.now(timezone.utc).isoformat(),
    "dataset": DATASET,
    "inputs": {
        "f3_modelo_manifest_sha256": f3_modelo_manifest_sha256,
        "f0_manifest_sha256": f3_modelo_manifest.get("inputs", {}).get("f0_manifest_sha256"),
        "f1_manifest_sha256": f3_modelo_manifest.get("inputs", {}).get("f1_manifest_sha256"),
        "f2_manifest_sha256": f3_modelo_manifest.get("inputs", {}).get("f2_manifest_sha256"),
    },
    "experimental_design": {
        "folds": TOTAL_FOLDS_ESPERADO,
        "examples": TOTAL_EXEMPLOS_ESPERADO,
        "base_conditions": TOTAL_CONDICOES_BASE,
        "conditions": TOTAL_CONDICOES_ESPERADO,
        "base_pipelines": TOTAL_FLUXOS_BASE_ESPERADO,
        "records": TOTAL_REGISTROS_ESPERADO,
        "k_values": K_FEWSHOT,
        "selection_methods": METODOS_FEWSHOT,
        "formal_equivalent_demonstrations_excluded": True,
    },
    "model": config_final["student_model"],
    "metrics": {
        "names": ["PSR", "EM", "ED", "NED", "SLA-S", "SLA-F"],
        "internal_fields": METRICAS,
        "embedding_metric_used": False,
    },
    "method": {
        "teacher_model_used": False,
        "fine_tuning_used": False,
        "intermediate_representation_used": True,
        "reference_ir_used_for_test_inference": False,
        "generated_ir_used_for_secondary_stage": True,
        "generated_ir_replaced_when_invalid": False,
        "rationales_used_in_prompt": False,
        "autocorrection_used": True,
        "autocorrection_attempt": 1,
        "autocorrection_only_for_syntax_invalid_nile": True,
        "ir_autocorrection_used": False,
        "same_few_shot_ids_across_stages": True,
        "test_reference_exposed": False,
        "checkpoint_resume_enabled": True,
    },
    "results": {
        "ir_valid": int(ir_validation_df["ir_valid"].sum()),
        "autocorrections_applied": expected_autocorrections,
        "syntax_valid_before": config_final["observed"]["nile_syntax_valid_before"],
        "syntax_valid_after": config_final["observed"]["nile_syntax_valid_after"],
        "syntax_recovered": config_final["observed"]["syntax_recovered"],
        "final_autocorrection_eligible": config_final["observed"]["final_autocorrection_eligible"],
        "summary": summary_df.to_dict(orient="records"),
    },
    "environment": {
        "python": platform.python_version(),
        "platform": platform.platform(),
        "packages": {
            "torch": package_version("torch"),
            "transformers": package_version("transformers"),
            "accelerate": package_version("accelerate"),
            "pandas": package_version("pandas"),
            "numpy": package_version("numpy"),
            "lark": package_version("lark"),
            "jsonschema": package_version("jsonschema"),
            "matplotlib": package_version("matplotlib"),
            "tqdm": package_version("tqdm"),
        },
    },
    "files": file_inventory,
}
write_json(manifest, MANIFEST_PATH)


# ----------------------------------------------------------
# 10.4 Criação e verificação do ZIP
# ----------------------------------------------------------

if ZIP_FINAL_PATH.exists():
    ZIP_FINAL_PATH.unlink()

with zipfile.ZipFile(ZIP_FINAL_PATH, "w", compression=zipfile.ZIP_DEFLATED) as package:
    for path, item in zip(package_files, file_inventory):
        package.write(path, arcname=item["file"])
    package.write(MANIFEST_PATH, arcname="manifest.json")

with zipfile.ZipFile(ZIP_FINAL_PATH, "r") as package:
    members = [name for name in package.namelist() if not name.endswith("/")]
    expected_members = [item["file"] for item in file_inventory] + ["manifest.json"]
    if sorted(members) != sorted(expected_members):
        raise ValueError("A estrutura do ZIP diverge do manifesto.")

    manifest_zip = json.loads(package.read("manifest.json").decode("utf-8"))
    for item in manifest_zip["files"]:
        payload = package.read(item["file"])
        if len(payload) != int(item["size_bytes"]):
            raise ValueError(f"Tamanho divergente no ZIP: {item['file']}.")
        if hashlib.sha256(payload).hexdigest() != item["sha256"]:
            raise ValueError(f"Hash divergente no ZIP: {item['file']}.")

final_summary_df = pd.DataFrame([
    {"item": "fluxos-base", "value": len(plan_records), "status": "OK"},
    {"item": "resultados finais", "value": len(result_records), "status": "OK"},
    {"item": "IRs válidas", "value": int(ir_validation_df["ir_valid"].sum()), "status": "OK"},
    {"item": "autocorreções aplicadas", "value": expected_autocorrections, "status": "OK"},
    {"item": "elegíveis à autocorreção final", "value": len(final_ac_eligible_df), "status": "OK"},
    {"item": "arquivos no ZIP", "value": len(expected_members), "status": "OK"},
])

exibir_tabela(final_summary_df, "Resumo final da F3-C")

print("Bloco 10 concluído.")
print(f"Pacote final: {ZIP_FINAL_PATH}")
print(f"Arquivos no ZIP: {len(expected_members)}")
print("Manifesto e hashes: confirmados")
print("F3-C concluída e pronta para auditoria pós-execução.")
print("Status: OK")
# Out:
#     <div style="font-weight:600;font-size:15px;margin:8px 0 6px;color:#f1f1f1;">
#         Tabela 22. Resumo final da F3-C
#     </div>
#     <div class="container_tabela_saida" style="display:inline-block;max-width:100%;overflow-x:auto;overflow-y: visible;border:none;margin:8px 0 12px;">
#         <style>
#             .container_tabela_saida table.tabela_saida {
#                 border-collapse:collapse !important;
#                 table-layout:auto !important;
#                 width:auto !important;
#                 font-family:Arial,sans-serif !important;
#                 font-size:13px !important;
#                 background:#111 !important;
#                 color:#f1f1f1 !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida thead th {
#                 position:sticky !important;
#                 top:0 !important;
#                 z-index:2 !important;
#                 background:#2b2b2b !important;
#                 color:#fff !important;
#                 padding:7px !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #777 !important;
#                 border-bottom:2px solid #888 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody td {
#                 padding:7px !important;
#                 vertical-align:top !important;
#                 text-align:left !important;
#                 white-space:nowrap !important;
#                 border:1px solid #555 !important;
#             }
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(even) td {background:#1b1b1b !important;}
#             .container_tabela_saida table.tabela_saida tbody tr:nth-child(odd) td {background:#111 !important;}
#         </style>
#         <table class="dataframe tabela_saida">
#   <thead>
#     <tr style="text-align: left;">
#       <th>item</th>
#       <th>valor</th>
#       <th>status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>fluxos-base</td>
#       <td>450</td>
#       <td>OK</td>
#     </tr>
#     <tr>
#       <td>resultados finais</td>
#       <td>900</td>
#       <td>OK</td>
#     </tr>
#     <tr>
#       <td>IRs válidas</td>
#       <td>210</td>
#       <td>OK</td>
#     </tr>
#     <tr>
#       <td>autocorreções aplicadas</td>
#       <td>242</td>
#       <td>OK</td>
#     </tr>
#     <tr>
#       <td>elegíveis à autocorreção final</td>
#       <td>236</td>
#       <td>OK</td>
#     </tr>
#     <tr>
#       <td>arquivos no ZIP</td>
#       <td>39</td>
#       <td>OK</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
# Bloco 10 concluído.
# Pacote final: /kaggle/working/f3c_traducao_com_ir.zip
# Arquivos no ZIP: 39
# Manifesto e hashes: confirmados
# F3-C concluída e pronta para auditoria pós-execução.
# Status: OK
